# %%
import import_ipynb
from preprocessing import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# X:  6400
# X_train:  4480
# X_test:  1280
# X_val:  640
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 627,   45, 2240, 1568], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 627,   45, 2240, 1568], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# Unique Values: [0 1 2 3]
# Frequency Values: [ 627   45 2240 1568]
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo
model = DecisionTreeClassifier(random_state = SEED)
metrics = model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.68125
# accuracy
# 0.68125
#
# f1_macro
# 0.5989278752436648
#
# precision
# 0.607394926465574
#
# recall
# 0.5930183531746032
#
# confusion_matrix
# [[ 41   0  16  33]
#  [  0   3   2   1]
#  [ 15   1 249  55]
#  [ 18   2  61 143]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5541    0.4556    0.5000        90
#  Moderate_Demented     0.5000    0.5000    0.5000         6
#       Non_Demented     0.7591    0.7781    0.7685       320
# Very_Mild_Demented     0.6164    0.6384    0.6272       224
#
#           accuracy                         0.6813       640
#          macro avg     0.6074    0.5930    0.5989       640
#       weighted avg     0.6779    0.6813    0.6788       640

# %%
# Criando o modelo
model = ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.65625
# accuracy
# 0.65625
#
# f1_macro
# 0.5163653039832286
#
# precision
# 0.5482430926916221
#
# recall
# 0.5003720238095237
#
# confusion_matrix
# [[ 45   1  19  25]
#  [  1   1   2   2]
#  [ 20   1 250  49]
#  [ 19   0  81 124]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5294    0.5000    0.5143        90
#  Moderate_Demented     0.3333    0.1667    0.2222         6
#       Non_Demented     0.7102    0.7812    0.7440       320
# Very_Mild_Demented     0.6200    0.5536    0.5849       224
#
#           accuracy                         0.6562       640
#          macro avg     0.5482    0.5004    0.5164       640
#       weighted avg     0.6497    0.6562    0.6511       640
# {'accuracy': 0.65625,
#  'f1_macro': 0.5163653039832286,
#  'precision': 0.5482430926916221,
#  'recall': 0.5003720238095237,
#  'confusion_matrix': array([[ 45,   1,  19,  25],
#         [  1,   1,   2,   2],
#         [ 20,   1, 250,  49],
#         [ 19,   0,  81, 124]], dtype=int64)}

# %%
# Criando o modelo de Random Forest
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.86875
# accuracy
# 0.86875
#
# f1_macro
# 0.7913142257152439
#
# precision
# 0.9293467234733213
#
# recall
# 0.7244543650793651
#
# confusion_matrix
# [[ 53   0  14  23]
#  [  0   3   2   1]
#  [  0   0 316   4]
#  [  0   0  40 184]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.5889    0.7413        90
#  Moderate_Demented     1.0000    0.5000    0.6667         6
#       Non_Demented     0.8495    0.9875    0.9133       320
# Very_Mild_Demented     0.8679    0.8214    0.8440       224
#
#           accuracy                         0.8688       640
#          macro avg     0.9293    0.7245    0.7913       640
#       weighted avg     0.8785    0.8688    0.8625       640
# {'accuracy': 0.86875,
#  'f1_macro': 0.7913142257152439,
#  'precision': 0.9293467234733213,
#  'recall': 0.7244543650793651,
#  'confusion_matrix': array([[ 53,   0,  14,  23],
#         [  0,   3,   2,   1],
#         [  0,   0, 316,   4],
#         [  0,   0,  40, 184]], dtype=int64)}

# %%
# Criando o modelo de Random Forest hiperparametros
model = RandomForestClassifier(random_state = SEED, n_jobs = -1, n_estimators = 250)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.8734375
# accuracy
# 0.8734375
#
# f1_macro
# 0.7514946310551751
#
# precision
# 0.9326202972976375
#
# recall
# 0.6849206349206349
#
# confusion_matrix
# [[ 52   0  16  22]
#  [  0   2   2   2]
#  [  0   0 318   2]
#  [  0   0  37 187]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.5778    0.7324        90
#  Moderate_Demented     1.0000    0.3333    0.5000         6
#       Non_Demented     0.8525    0.9938    0.9177       320
# Very_Mild_Demented     0.8779    0.8348    0.8558       224
#
#           accuracy                         0.8734       640
#          macro avg     0.9326    0.6849    0.7515       640
#       weighted avg     0.8836    0.8734    0.8661       640
# {'accuracy': 0.8734375,
#  'f1_macro': 0.7514946310551751,
#  'precision': 0.9326202972976375,
#  'recall': 0.6849206349206349,
#  'confusion_matrix': array([[ 52,   0,  16,  22],
#         [  0,   2,   2,   2],
#         [  0,   0, 318,   2],
#         [  0,   0,  37, 187]], dtype=int64)}

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.94375
# accuracy
# 0.94375
#
# f1_macro
# 0.9528219666137334
#
# precision
# 0.9595417303590894
#
# recall
# 0.9475322420634921
#
# confusion_matrix
# [[ 82   0   4   4]
#  [  0   6   0   0]
#  [  0   0 317   3]
#  [  5   0  20 199]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9425    0.9111    0.9266        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.9296    0.9906    0.9592       320
# Very_Mild_Demented     0.9660    0.8884    0.9256       224
#
#           accuracy                         0.9437       640
#          macro avg     0.9595    0.9475    0.9528       640
#       weighted avg     0.9448    0.9437    0.9432       640
# {'accuracy': 0.94375,
#  'f1_macro': 0.9528219666137334,
#  'precision': 0.9595417303590894,
#  'recall': 0.9475322420634921,
#  'confusion_matrix': array([[ 82,   0,   4,   4],
#         [  0,   6,   0,   0],
#         [  0,   0, 317,   3],
#         [  5,   0,  20, 199]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.9125
# accuracy
# 0.9125
#
# f1_macro
# 0.9063363931142251
#
# precision
# 0.9406156146421989
#
# recall
# 0.878360615079365
#
# confusion_matrix
# [[ 77   0   6   7]
#  [  0   5   1   0]
#  [  1   0 311   8]
#  [  4   0  29 191]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9390    0.8556    0.8953        90
#  Moderate_Demented     1.0000    0.8333    0.9091         6
#       Non_Demented     0.8963    0.9719    0.9325       320
# Very_Mild_Demented     0.9272    0.8527    0.8884       224
#
#           accuracy                         0.9125       640
#          macro avg     0.9406    0.8784    0.9063       640
#       weighted avg     0.9141    0.9125    0.9116       640
# {'accuracy': 0.9125,
#  'f1_macro': 0.9063363931142251,
#  'precision': 0.9406156146421989,
#  'recall': 0.878360615079365,
#  'confusion_matrix': array([[ 77,   0,   6,   7],
#         [  0,   5,   1,   0],
#         [  1,   0, 311,   8],
#         [  4,   0,  29, 191]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.8828125
# accuracy
# 0.8828125
#
# f1_macro
# 0.9068497174147845
#
# precision
# 0.9143948756833782
#
# recall
# 0.9003968253968254
#
# confusion_matrix
# [[ 76   0   6   8]
#  [  0   6   0   0]
#  [  2   0 298  20]
#  [  6   0  33 185]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9048    0.8444    0.8736        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.8843    0.9313    0.9072       320
# Very_Mild_Demented     0.8685    0.8259    0.8467       224
#
#           accuracy                         0.8828       640
#          macro avg     0.9144    0.9004    0.9068       640
#       weighted avg     0.8827    0.8828    0.8821       640
# {'accuracy': 0.8828125,
#  'f1_macro': 0.9068497174147845,
#  'precision': 0.9143948756833782,
#  'recall': 0.9003968253968254,
#  'confusion_matrix': array([[ 76,   0,   6,   8],
#         [  0,   6,   0,   0],
#         [  2,   0, 298,  20],
#         [  6,   0,  33, 185]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.4515625
# accuracy
# 0.4515625
#
# f1_macro
# 0.30401317364588093
#
# precision
# 0.3012956476908355
#
# recall
# 0.32306547619047615
#
# confusion_matrix
# [[ 39   0  29  22]
#  [  3   0   1   2]
#  [ 51   0 192  77]
#  [ 61   0 105  58]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2532    0.4333    0.3197        90
#  Moderate_Demented     0.0000    0.0000    0.0000         6
#       Non_Demented     0.5872    0.6000    0.5935       320
# Very_Mild_Demented     0.3648    0.2589    0.3029       224
#
#           accuracy                         0.4516       640
#          macro avg     0.3013    0.3231    0.3040       640
#       weighted avg     0.4569    0.4516    0.4477       640
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.4515625,
#  'f1_macro': 0.30401317364588093,
#  'precision': 0.3012956476908355,
#  'recall': 0.32306547619047615,
#  'confusion_matrix': array([[ 39,   0,  29,  22],
#         [  3,   0,   1,   2],
#         [ 51,   0, 192,  77],
#         [ 61,   0, 105,  58]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.503125
# accuracy
# 0.503125
#
# f1_macro
# 0.38001747184536805
#
# precision
# 0.3700027094411793
#
# recall
# 0.44892113095238095
#
# confusion_matrix
# [[ 48   3  11  28]
#  [  3   2   1   0]
#  [ 45   7 213  55]
#  [ 62  10  93  59]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3038    0.5333    0.3871        90
#  Moderate_Demented     0.0909    0.3333    0.1429         6
#       Non_Demented     0.6698    0.6656    0.6677       320
# Very_Mild_Demented     0.4155    0.2634    0.3224       224
#
#           accuracy                         0.5031       640
#          macro avg     0.3700    0.4489    0.3800       640
#       weighted avg     0.5239    0.5031    0.5025       640
# {'accuracy': 0.503125,
#  'f1_macro': 0.38001747184536805,
#  'precision': 0.3700027094411793,
#  'recall': 0.44892113095238095,
#  'confusion_matrix': array([[ 48,   3,  11,  28],
#         [  3,   2,   1,   0],
#         [ 45,   7, 213,  55],
#         [ 62,  10,  93,  59]], dtype=int64)}

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.7140625
# accuracy
# 0.7140625
#
# f1_macro
# 0.4610431001580184
#
# precision
# 0.5678699188870658
#
# recall
# 0.44883432539682533
#
# confusion_matrix
# [[ 22   0  24  44]
#  [  0   0   2   4]
#  [  1   0 292  27]
#  [  2   0  79 143]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8800    0.2444    0.3826        90
#  Moderate_Demented     0.0000    0.0000    0.0000         6
#       Non_Demented     0.7355    0.9125    0.8145       320
# Very_Mild_Demented     0.6560    0.6384    0.6471       224
#
#           accuracy                         0.7141       640
#          macro avg     0.5679    0.4488    0.4610       640
#       weighted avg     0.7211    0.7141    0.6875       640
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.7140625,
#  'f1_macro': 0.4610431001580184,
#  'precision': 0.5678699188870658,
#  'recall': 0.44883432539682533,
#  'confusion_matrix': array([[ 22,   0,  24,  44],
#         [  0,   0,   2,   4],
#         [  1,   0, 292,  27],
#         [  2,   0,  79, 143]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(class_weight = "balanced",  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.7203125
# accuracy
# 0.7203125
#
# f1_macro
# 0.7766096710289376
#
# precision
# 0.7661141058132586
#
# recall
# 0.812078373015873
#
# confusion_matrix
# [[ 79   0   5   6]
#  [  0   6   0   0]
#  [ 40   0 230  50]
#  [ 32   0  46 146]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5232    0.8778    0.6556        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.8185    0.7188    0.7654       320
# Very_Mild_Demented     0.7228    0.6518    0.6854       224
#
#           accuracy                         0.7203       640
#          macro avg     0.7661    0.8121    0.7766       640
#       weighted avg     0.7452    0.7203    0.7242       640
# {'accuracy': 0.7203125,
#  'f1_macro': 0.7766096710289376,
#  'precision': 0.7661141058132586,
#  'recall': 0.812078373015873,
#  'confusion_matrix': array([[ 79,   0,   5,   6],
#         [  0,   6,   0,   0],
#         [ 40,   0, 230,  50],
#         [ 32,   0,  46, 146]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(gamma = "auto", class_weight = "balanced",  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.5390625
# accuracy
# 0.5390625
#
# f1_macro
# 0.6219645549996478
#
# precision
# 0.6244044266635593
#
# recall
# 0.6570808531746032
#
# confusion_matrix
# [[ 59   0   9  22]
#  [  0   6   0   0]
#  [ 57   0 207  56]
#  [ 70   0  81  73]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3172    0.6556    0.4275        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.6970    0.6469    0.6710       320
# Very_Mild_Demented     0.4834    0.3259    0.3893       224
#
#           accuracy                         0.5391       640
#          macro avg     0.6244    0.6571    0.6220       640
#       weighted avg     0.5717    0.5391    0.5413       640
# {'accuracy': 0.5390625,
#  'f1_macro': 0.6219645549996478,
#  'precision': 0.6244044266635593,
#  'recall': 0.6570808531746032,
#  'confusion_matrix': array([[ 59,   0,   9,  22],
#         [  0,   6,   0,   0],
#         [ 57,   0, 207,  56],
#         [ 70,   0,  81,  73]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.9734375
# accuracy
# 0.9734375
#
# f1_macro
# 0.9760285838645202
#
# precision
# 0.9826451015475406
#
# recall
# 0.9700644841269842
#
# confusion_matrix
# [[ 83   0   3   4]
#  [  0   6   0   0]
#  [  0   0 318   2]
#  [  1   0   7 216]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9881    0.9222    0.9540        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.9695    0.9938    0.9815       320
# Very_Mild_Demented     0.9730    0.9643    0.9686       224
#
#           accuracy                         0.9734       640
#          macro avg     0.9826    0.9701    0.9760       640
#       weighted avg     0.9736    0.9734    0.9733       640
# {'accuracy': 0.9734375,
#  'f1_macro': 0.9760285838645202,
#  'precision': 0.9826451015475406,
#  'recall': 0.9700644841269842,
#  'confusion_matrix': array([[ 83,   0,   3,   4],
#         [  0,   6,   0,   0],
#         [  0,   0, 318,   2],
#         [  1,   0,   7, 216]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.8765625
# accuracy
# 0.8765625
#
# f1_macro
# 0.8960585187801718
#
# precision
# 0.9262114713128556
#
# recall
# 0.8766493055555555
#
# confusion_matrix
# [[ 65   0  10  15]
#  [  0   6   0   0]
#  [  0   0 301  19]
#  [  1   0  34 189]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9848    0.7222    0.8333        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.8725    0.9406    0.9053       320
# Very_Mild_Demented     0.8475    0.8438    0.8456       224
#
#           accuracy                         0.8766       640
#          macro avg     0.9262    0.8766    0.8961       640
#       weighted avg     0.8807    0.8766    0.8752       640
# {'accuracy': 0.8765625,
#  'f1_macro': 0.8960585187801718,
#  'precision': 0.9262114713128556,
#  'recall': 0.8766493055555555,
#  'confusion_matrix': array([[ 65,   0,  10,  15],
#         [  0,   6,   0,   0],
#         [  0,   0, 301,  19],
#         [  1,   0,  34, 189]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.321875
# accuracy
# 0.321875
#
# f1_macro
# 0.2302079864986067
#
# precision
# 0.2296995078449947
#
# recall
# 0.23091517857142857
#
# confusion_matrix
# [[ 27   0  62   1]
#  [  2   0   2   2]
#  [ 25   0 131 164]
#  [ 34   0 142  48]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3068    0.3000    0.3034        90
#  Moderate_Demented     0.0000    0.0000    0.0000         6
#       Non_Demented     0.3887    0.4094    0.3988       320
# Very_Mild_Demented     0.2233    0.2143    0.2187       224
#
#           accuracy                         0.3219       640
#          macro avg     0.2297    0.2309    0.2302       640
#       weighted avg     0.3156    0.3219    0.3186       640
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.321875,
#  'f1_macro': 0.2302079864986067,
#  'precision': 0.2296995078449947,
#  'recall': 0.23091517857142857,
#  'confusion_matrix': array([[ 27,   0,  62,   1],
#         [  2,   0,   2,   2],
#         [ 25,   0, 131, 164],
#         [ 34,   0, 142,  48]], dtype=int64)}

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.953125
# accuracy
# 0.953125
#
# f1_macro
# 0.9100482746290006
#
# precision
# 0.9713538556538733
#
# recall
# 0.8674727182539683
#
# confusion_matrix
# [[ 79   0   3   8]
#  [  0   4   1   1]
#  [  0   0 319   1]
#  [  1   0  15 208]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9875    0.8778    0.9294        90
#  Moderate_Demented     1.0000    0.6667    0.8000         6
#       Non_Demented     0.9438    0.9969    0.9696       320
# Very_Mild_Demented     0.9541    0.9286    0.9412       224
#
#           accuracy                         0.9531       640
#          macro avg     0.9714    0.8675    0.9100       640
#       weighted avg     0.9541    0.9531    0.9524       640
# {'accuracy': 0.953125,
#  'f1_macro': 0.9100482746290006,
#  'precision': 0.9713538556538733,
#  'recall': 0.8674727182539683,
#  'confusion_matrix': array([[ 79,   0,   3,   8],
#         [  0,   4,   1,   1],
#         [  0,   0, 319,   1],
#         [  1,   0,  15, 208]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = GradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.8375
# accuracy
# 0.8375
#
# f1_macro
# 0.6966431527074596
#
# precision
# 0.7534902012191126
#
# recall
# 0.6656001984126985
#
# confusion_matrix
# [[ 53   1  11  25]
#  [  0   2   1   3]
#  [  2   0 304  14]
#  [  0   2  45 177]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9636    0.5889    0.7310        90
#  Moderate_Demented     0.4000    0.3333    0.3636         6
#       Non_Demented     0.8421    0.9500    0.8928       320
# Very_Mild_Demented     0.8082    0.7902    0.7991       224
#
#           accuracy                         0.8375       640
#          macro avg     0.7535    0.6656    0.6966       640
#       weighted avg     0.8432    0.8375    0.8323       640
# {'accuracy': 0.8375,
#  'f1_macro': 0.6966431527074596,
#  'precision': 0.7534902012191126,
#  'recall': 0.6656001984126985,
#  'confusion_matrix': array([[ 53,   1,  11,  25],
#         [  0,   2,   1,   3],
#         [  2,   0, 304,  14],
#         [  0,   2,  45, 177]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.5296875
# accuracy
# 0.5296875
#
# f1_macro
# 0.3900700604169863
#
# precision
# 0.5835021690160674
#
# recall
# 0.36180555555555555
#
# confusion_matrix
# [[ 14   0  41  35]
#  [  1   1   0   4]
#  [ 15   0 240  65]
#  [ 18   0 122  84]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2917    0.1556    0.2029        90
#  Moderate_Demented     1.0000    0.1667    0.2857         6
#       Non_Demented     0.5955    0.7500    0.6639       320
# Very_Mild_Demented     0.4468    0.3750    0.4078       224
#
#           accuracy                         0.5297       640
#          macro avg     0.5835    0.3618    0.3901       640
#       weighted avg     0.5045    0.5297    0.5059       640
# {'accuracy': 0.5296875,
#  'f1_macro': 0.3900700604169863,
#  'precision': 0.5835021690160674,
#  'recall': 0.36180555555555555,
#  'confusion_matrix': array([[ 14,   0,  41,  35],
#         [  1,   1,   0,   4],
#         [ 15,   0, 240,  65],
#         [ 18,   0, 122,  84]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED, n_estimators = 400)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.5265625
# accuracy
# 0.5265625
#
# f1_macro
# 0.5052831538390337
#
# precision
# 0.5918197384806974
#
# recall
# 0.4623387896825397
#
# confusion_matrix
# [[ 22   0  32  36]
#  [  0   3   1   2]
#  [ 20   0 215  85]
#  [ 31   0  96  97]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3014    0.2444    0.2699        90
#  Moderate_Demented     1.0000    0.5000    0.6667         6
#       Non_Demented     0.6250    0.6719    0.6476       320
# Very_Mild_Demented     0.4409    0.4330    0.4369       224
#
#           accuracy                         0.5266       640
#          macro avg     0.5918    0.4623    0.5053       640
#       weighted avg     0.5186    0.5266    0.5209       640
# {'accuracy': 0.5265625,
#  'f1_macro': 0.5052831538390337,
#  'precision': 0.5918197384806974,
#  'recall': 0.4623387896825397,
#  'confusion_matrix': array([[ 22,   0,  32,  36],
#         [  0,   3,   1,   2],
#         [ 20,   0, 215,  85],
#         [ 31,   0,  96,  97]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = HistGradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.9640625
# accuracy
# 0.9640625
#
# f1_macro
# 0.9410550121534115
#
# precision
# 0.9788493179767528
#
# recall
# 0.9105158730158731
#
# confusion_matrix
# [[ 76   0   3  11]
#  [  0   5   1   0]
#  [  0   0 320   0]
#  [  0   0   8 216]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.8444    0.9157        90
#  Moderate_Demented     1.0000    0.8333    0.9091         6
#       Non_Demented     0.9639    1.0000    0.9816       320
# Very_Mild_Demented     0.9515    0.9643    0.9579       224
#
#           accuracy                         0.9641       640
#          macro avg     0.9788    0.9105    0.9411       640
#       weighted avg     0.9650    0.9641    0.9633       640
# {'accuracy': 0.9640625,
#  'f1_macro': 0.9410550121534115,
#  'precision': 0.9788493179767528,
#  'recall': 0.9105158730158731,
#  'confusion_matrix': array([[ 76,   0,   3,  11],
#         [  0,   5,   1,   0],
#         [  0,   0, 320,   0],
#         [  0,   0,   8, 216]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = LinearDiscriminantAnalysis()
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.840625
# accuracy
# 0.840625
#
# f1_macro
# 0.8703949175824175
#
# precision
# 0.8796198593073593
#
# recall
# 0.8626612103174602
#
# confusion_matrix
# [[ 68   0  14   8]
#  [  0   6   0   0]
#  [  6   0 281  33]
#  [  6   0  35 183]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8500    0.7556    0.8000        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.8515    0.8781    0.8646       320
# Very_Mild_Demented     0.8170    0.8170    0.8170       224
#
#           accuracy                         0.8406       640
#          macro avg     0.8796    0.8627    0.8704       640
#       weighted avg     0.8406    0.8406    0.8401       640
# {'accuracy': 0.840625,
#  'f1_macro': 0.8703949175824175,
#  'precision': 0.8796198593073593,
#  'recall': 0.8626612103174602,
#  'confusion_matrix': array([[ 68,   0,  14,   8],
#         [  0,   6,   0,   0],
#         [  6,   0, 281,  33],
#         [  6,   0,  35, 183]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = DummyClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.5
# accuracy
# 0.5
#
# f1_macro
# 0.16666666666666666
#
# precision
# 0.125
#
# recall
# 0.25
#
# confusion_matrix
# [[  0   0  90   0]
#  [  0   0   6   0]
#  [  0   0 320   0]
#  [  0   0 224   0]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.0000    0.0000    0.0000        90
#  Moderate_Demented     0.0000    0.0000    0.0000         6
#       Non_Demented     0.5000    1.0000    0.6667       320
# Very_Mild_Demented     0.0000    0.0000    0.0000       224
#
#           accuracy                         0.5000       640
#          macro avg     0.1250    0.2500    0.1667       640
#       weighted avg     0.2500    0.5000    0.3333       640
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.5,
#  'f1_macro': 0.16666666666666666,
#  'precision': 0.125,
#  'recall': 0.25,
#  'confusion_matrix': array([[  0,   0,  90,   0],
#         [  0,   0,   6,   0],
#         [  0,   0, 320,   0],
#         [  0,   0, 224,   0]], dtype=int64)}
