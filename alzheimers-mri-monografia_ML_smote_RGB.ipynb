# %%
import import_ipynb
from preprocessing_smote_RGB import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing_smote_RGB.ipynb
# importing Jupyter notebook from preprocessing_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# X:  6400
# X_train:  4480
# X_test:  1280
# X_val:  640
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 627,   45, 2240, 1568], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 627,   45, 2240, 1568], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# Unique Values: [0 1 2 3]
# Frequency Values: [ 627   45 2240 1568]
# 4480 4480
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\imblearn\over_sampling\_smote\base.py:336: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# 8960 8960
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo
model = DecisionTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.68125
# accuracy
# 0.68125
#
# f1_macro
# 0.6237199892413956
#
# precision
# 0.6074828107889956
#
# recall
# 0.6440225430121554
#
# confusion_matrix
# [[106   1  38  34]
#  [  2   8   1   2]
#  [ 34   4 483 119]
#  [ 59   3 111 275]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5274    0.5922    0.5579       179
#  Moderate_Demented     0.5000    0.6154    0.5517        13
#       Non_Demented     0.7630    0.7547    0.7588       640
# Very_Mild_Demented     0.6395    0.6138    0.6264       448
#
#           accuracy                         0.6813      1280
#          macro avg     0.6075    0.6440    0.6237      1280
#       weighted avg     0.6842    0.6813    0.6823      1280
# {'accuracy': 0.68125,
#  'f1_macro': 0.6237199892413956,
#  'precision': 0.6074828107889956,
#  'recall': 0.6440225430121554,
#  'confusion_matrix': array([[106,   1,  38,  34],
#         [  2,   8,   1,   2],
#         [ 34,   4, 483, 119],
#         [ 59,   3, 111, 275]], dtype=int64)}

# %%
# Criando o modelo
model = ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.63203125
# accuracy
# 0.63203125
#
# f1_macro
# 0.5500132119302834
#
# precision
# 0.5187433397207979
#
# recall
# 0.6224948824743691
#
# confusion_matrix
# [[ 92   4  34  49]
#  [  2   9   1   1]
#  [ 68   6 443 123]
#  [ 53  11 119 265]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.4279    0.5140    0.4670       179
#  Moderate_Demented     0.3000    0.6923    0.4186        13
#       Non_Demented     0.7420    0.6922    0.7162       640
# Very_Mild_Demented     0.6050    0.5915    0.5982       448
#
#           accuracy                         0.6320      1280
#          macro avg     0.5187    0.6225    0.5500      1280
#       weighted avg     0.6457    0.6320    0.6371      1280
# {'accuracy': 0.63203125,
#  'f1_macro': 0.5500132119302834,
#  'precision': 0.5187433397207979,
#  'recall': 0.6224948824743691,
#  'confusion_matrix': array([[ 92,   4,  34,  49],
#         [  2,   9,   1,   1],
#         [ 68,   6, 443, 123],
#         [ 53,  11, 119, 265]], dtype=int64)}

# %%
# Criando o modelo de Random Forest
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.93671875
# accuracy
# 0.93671875
#
# f1_macro
# 0.9487148842116838
#
# precision
# 0.9549938671223809
#
# recall
# 0.9430507407222666
#
# confusion_matrix
# [[160   0   4  15]
#  [  0  13   0   0]
#  [  5   0 615  20]
#  [  2   0  35 411]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9581    0.8939    0.9249       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9404    0.9609    0.9505       640
# Very_Mild_Demented     0.9215    0.9174    0.9195       448
#
#           accuracy                         0.9367      1280
#          macro avg     0.9550    0.9431    0.9487      1280
#       weighted avg     0.9369    0.9367    0.9366      1280
# {'accuracy': 0.93671875,
#  'f1_macro': 0.9487148842116838,
#  'precision': 0.9549938671223809,
#  'recall': 0.9430507407222666,
#  'confusion_matrix': array([[160,   0,   4,  15],
#         [  0,  13,   0,   0],
#         [  5,   0, 615,  20],
#         [  2,   0,  35, 411]], dtype=int64)}

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.92734375
# accuracy
# 0.92734375
#
# f1_macro
# 0.8686112789415162
#
# precision
# 0.8170409276272969
#
# recall
# 0.95981986981245
#
# confusion_matrix
# [[178   0   0   1]
#  [  0  13   0   0]
#  [ 40   8 565  27]
#  [ 15   2   0 431]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7639    0.9944    0.8641       179
#  Moderate_Demented     0.5652    1.0000    0.7222        13
#       Non_Demented     1.0000    0.8828    0.9378       640
# Very_Mild_Demented     0.9390    0.9621    0.9504       448
#
#           accuracy                         0.9273      1280
#          macro avg     0.8170    0.9598    0.8686      1280
#       weighted avg     0.9412    0.9273    0.9297      1280
# {'accuracy': 0.92734375,
#  'f1_macro': 0.8686112789415162,
#  'precision': 0.8170409276272969,
#  'recall': 0.95981986981245,
#  'confusion_matrix': array([[178,   0,   0,   1],
#         [  0,  13,   0,   0],
#         [ 40,   8, 565,  27],
#         [ 15,   2,   0, 431]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.91875
# accuracy
# 0.91875
#
# f1_macro
# 0.9362237240012262
#
# precision
# 0.9389940598447806
#
# recall
# 0.9337346618116521
#
# confusion_matrix
# [[162   0   7  10]
#  [  0  13   0   0]
#  [ 11   0 604  25]
#  [  3   0  48 397]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9205    0.9050    0.9127       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9165    0.9437    0.9299       640
# Very_Mild_Demented     0.9190    0.8862    0.9023       448
#
#           accuracy                         0.9187      1280
#          macro avg     0.9390    0.9337    0.9362      1280
#       weighted avg     0.9188    0.9187    0.9186      1280
# {'accuracy': 0.91875,
#  'f1_macro': 0.9362237240012262,
#  'precision': 0.9389940598447806,
#  'recall': 0.9337346618116521,
#  'confusion_matrix': array([[162,   0,   7,  10],
#         [  0,  13,   0,   0],
#         [ 11,   0, 604,  25],
#         [  3,   0,  48, 397]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.86015625
# accuracy
# 0.86015625
#
# f1_macro
# 0.8628078488059533
#
# precision
# 0.8406778302347504
#
# recall
# 0.8898559083200319
#
# confusion_matrix
# [[151   0  14  14]
#  [  0  13   0   0]
#  [ 19   1 561  59]
#  [ 13   2  57 376]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8251    0.8436    0.8343       179
#  Moderate_Demented     0.8125    1.0000    0.8966        13
#       Non_Demented     0.8877    0.8766    0.8821       640
# Very_Mild_Demented     0.8374    0.8393    0.8384       448
#
#           accuracy                         0.8602      1280
#          macro avg     0.8407    0.8899    0.8628      1280
#       weighted avg     0.8606    0.8602    0.8602      1280
# {'accuracy': 0.86015625,
#  'f1_macro': 0.8628078488059533,
#  'precision': 0.8406778302347504,
#  'recall': 0.8898559083200319,
#  'confusion_matrix': array([[151,   0,  14,  14],
#         [  0,  13,   0,   0],
#         [ 19,   1, 561,  59],
#         [ 13,   2,  57, 376]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.47578125
# accuracy
# 0.47578125
#
# f1_macro
# 0.5183756793588068
#
# precision
# 0.5133303934676332
#
# recall
# 0.5659927711952851
#
# confusion_matrix
# [[101   0  37  41]
#  [  0  11   0   2]
#  [140   2 382 116]
#  [162   2 169 115]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2506    0.5642    0.3471       179
#  Moderate_Demented     0.7333    0.8462    0.7857        13
#       Non_Demented     0.6497    0.5969    0.6221       640
# Very_Mild_Demented     0.4197    0.2567    0.3186       448
#
#           accuracy                         0.4758      1280
#          macro avg     0.5133    0.5660    0.5184      1280
#       weighted avg     0.5142    0.4758    0.4791      1280
# {'accuracy': 0.47578125,
#  'f1_macro': 0.5183756793588068,
#  'precision': 0.5133303934676332,
#  'recall': 0.5659927711952851,
#  'confusion_matrix': array([[101,   0,  37,  41],
#         [  0,  11,   0,   2],
#         [140,   2, 382, 116],
#         [162,   2, 169, 115]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.53984375
# accuracy
# 0.53984375
#
# f1_macro
# 0.5008628366659756
#
# precision
# 0.47527480172478365
#
# recall
# 0.5591593876619191
#
# confusion_matrix
# [[ 93   4  26  56]
#  [  4   9   0   0]
#  [ 90   3 433 114]
#  [105   5 182 156]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3185    0.5196    0.3949       179
#  Moderate_Demented     0.4286    0.6923    0.5294        13
#       Non_Demented     0.6755    0.6766    0.6760       640
# Very_Mild_Demented     0.4785    0.3482    0.4031       448
#
#           accuracy                         0.5398      1280
#          macro avg     0.4753    0.5592    0.5009      1280
#       weighted avg     0.5541    0.5398    0.5397      1280
# {'accuracy': 0.53984375,
#  'f1_macro': 0.5008628366659756,
#  'precision': 0.47527480172478365,
#  'recall': 0.5591593876619191,
#  'confusion_matrix': array([[ 93,   4,  26,  56],
#         [  4,   9,   0,   0],
#         [ 90,   3, 433, 114],
#         [105,   5, 182, 156]], dtype=int64)}

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.8203125
# accuracy
# 0.8203125
#
# f1_macro
# 0.857851167907378
#
# precision
# 0.8451197533635247
#
# recall
# 0.8774846618116521
#
# confusion_matrix
# [[162   0   6  11]
#  [  0  13   0   0]
#  [ 41   0 520  79]
#  [ 27   0  66 355]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7043    0.9050    0.7922       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8784    0.8125    0.8442       640
# Very_Mild_Demented     0.7978    0.7924    0.7951       448
#
#           accuracy                         0.8203      1280
#          macro avg     0.8451    0.8775    0.8579      1280
#       weighted avg     0.8271    0.8203    0.8213      1280
# {'accuracy': 0.8203125,
#  'f1_macro': 0.857851167907378,
#  'precision': 0.8451197533635247,
#  'recall': 0.8774846618116521,
#  'confusion_matrix': array([[162,   0,   6,  11],
#         [  0,  13,   0,   0],
#         [ 41,   0, 520,  79],
#         [ 27,   0,  66, 355]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9751782471391962
#
# precision
# 0.9753001200480192
#
# recall
# 0.9751006958300081
#
# confusion_matrix
# [[172   0   6   1]
#  [  0  13   0   0]
#  [  3   0 627  10]
#  [  5   0  13 430]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9556    0.9609    0.9582       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9706    0.9797    0.9751       640
# Very_Mild_Demented     0.9751    0.9598    0.9674       448
#
#           accuracy                         0.9703      1280
#          macro avg     0.9753    0.9751    0.9752      1280
#       weighted avg     0.9703    0.9703    0.9703      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9751782471391962,
#  'precision': 0.9753001200480192,
#  'recall': 0.9751006958300081,
#  'confusion_matrix': array([[172,   0,   6,   1],
#         [  0,  13,   0,   0],
#         [  3,   0, 627,  10],
#         [  5,   0,  13, 430]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.93203125
# accuracy
# 0.93203125
#
# f1_macro
# 0.9510098144609015
#
# precision
# 0.9514241228948224
#
# recall
# 0.9505998104549083
#
# confusion_matrix
# [[170   0   5   4]
#  [  0  13   0   0]
#  [  5   0 600  35]
#  [  3   0  35 410]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9551    0.9497    0.9524       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9375    0.9375    0.9375       640
# Very_Mild_Demented     0.9131    0.9152    0.9142       448
#
#           accuracy                         0.9320      1280
#          macro avg     0.9514    0.9506    0.9510      1280
#       weighted avg     0.9321    0.9320    0.9320      1280
# {'accuracy': 0.93203125,
#  'f1_macro': 0.9510098144609015,
#  'precision': 0.9514241228948224,
#  'recall': 0.9505998104549083,
#  'confusion_matrix': array([[170,   0,   5,   4],
#         [  0,  13,   0,   0],
#         [  5,   0, 600,  35],
#         [  3,   0,  35, 410]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.22734375
# accuracy
# 0.22734375
#
# f1_macro
# 0.19522419987847406
#
# precision
# 0.2376875899677176
#
# recall
# 0.3727177850082878
#
# confusion_matrix
# [[ 56  84  15  24]
#  [  1   9   0   3]
#  [ 78 121  28 413]
#  [ 73 139  38 198]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2692    0.3128    0.2894       179
#  Moderate_Demented     0.0255    0.6923    0.0492        13
#       Non_Demented     0.3457    0.0437    0.0777       640
# Very_Mild_Demented     0.3103    0.4420    0.3646       448
#
#           accuracy                         0.2273      1280
#          macro avg     0.2377    0.3727    0.1952      1280
#       weighted avg     0.3194    0.2273    0.2074      1280
# {'accuracy': 0.22734375,
#  'f1_macro': 0.19522419987847406,
#  'precision': 0.2376875899677176,
#  'recall': 0.3727177850082878,
#  'confusion_matrix': array([[ 56,  84,  15,  24],
#         [  1,   9,   0,   3],
#         [ 78, 121,  28, 413],
#         [ 73, 139,  38, 198]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(gamma = "auto", class_weight = "balanced",  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)

# %%
# Criando o modelo SVM
model = SVC(class_weight = "balanced",  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.99140625
# accuracy
# 0.99140625
#
# f1_macro
# 0.9926609430694316
#
# precision
# 0.9943576940275631
#
# recall
# 0.9910093899640862
#
# confusion_matrix
# [[175   0   4   0]
#  [  0  13   0   0]
#  [  1   0 637   2]
#  [  0   0   4 444]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.98      0.99       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.99      1.00      0.99       640
# Very_Mild_Demented       1.00      0.99      0.99       448
#
#           accuracy                           0.99      1280
#          macro avg       0.99      0.99      0.99      1280
#       weighted avg       0.99      0.99      0.99      1280
# {'accuracy': 0.99140625,
#  'f1_macro': 0.9926609430694316,
#  'precision': 0.9943576940275631,
#  'recall': 0.9910093899640862,
#  'confusion_matrix': array([[175,   0,   4,   0],
#         [  0,  13,   0,   0],
#         [  1,   0, 637,   2],
#         [  0,   0,   4, 444]], dtype=int64)}

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9741657784137153
#
# precision
# 0.9824161173670237
#
# recall
# 0.9668851007581803
#
# confusion_matrix
# [[164   0   7   8]
#  [  0  13   0   0]
#  [  1   0 636   3]
#  [  0   0  19 429]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.92      0.95       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.96      0.99      0.98       640
# Very_Mild_Demented       0.97      0.96      0.97       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.97      0.97      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9741657784137153,
#  'precision': 0.9824161173670237,
#  'recall': 0.9668851007581803,
#  'confusion_matrix': array([[164,   0,   7,   8],
#         [  0,  13,   0,   0],
#         [  1,   0, 636,   3],
#         [  0,   0,  19, 429]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = GradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.50546875
# accuracy
# 0.50546875
#
# f1_macro
# 0.575947508466921
#
# precision
# 0.5925095642182321
#
# recall
# 0.5834050922017927
#
# confusion_matrix
# [[ 80   0  54  45]
#  [  0  12   1   0]
#  [126   0 411 103]
#  [116   0 188 144]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2484    0.4469    0.3194       179
#  Moderate_Demented     1.0000    0.9231    0.9600        13
#       Non_Demented     0.6284    0.6422    0.6352       640
# Very_Mild_Demented     0.4932    0.3214    0.3892       448
#
#           accuracy                         0.5055      1280
#          macro avg     0.5925    0.5834    0.5759      1280
#       weighted avg     0.5317    0.5055    0.5082      1280
# {'accuracy': 0.50546875,
#  'f1_macro': 0.575947508466921,
#  'precision': 0.5925095642182321,
#  'recall': 0.5834050922017927,
#  'confusion_matrix': array([[ 80,   0,  54,  45],
#         [  0,  12,   1,   0],
#         [126,   0, 411, 103],
#         [116,   0, 188, 144]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = HistGradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9765625
# accuracy
# 0.9765625
#
# f1_macro
# 0.959201445514845
#
# precision
# 0.9858339871182338
#
# recall
# 0.9363523457164343
#
# confusion_matrix
# [[167   0   6   6]
#  [  0  11   1   1]
#  [  1   0 637   2]
#  [  0   0  13 435]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9940    0.9330    0.9625       179
#  Moderate_Demented     1.0000    0.8462    0.9167        13
#       Non_Demented     0.9696    0.9953    0.9823       640
# Very_Mild_Demented     0.9797    0.9710    0.9753       448
#
#           accuracy                         0.9766      1280
#          macro avg     0.9858    0.9364    0.9592      1280
#       weighted avg     0.9769    0.9766    0.9764      1280
# {'accuracy': 0.9765625,
#  'f1_macro': 0.959201445514845,
#  'precision': 0.9858339871182338,
#  'recall': 0.9363523457164343,
#  'confusion_matrix': array([[167,   0,   6,   6],
#         [  0,  11,   1,   1],
#         [  1,   0, 637,   2],
#         [  0,   0,  13, 435]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = LinearDiscriminantAnalysis()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Criando modelo Gradient Boosting
#       2 model = LinearDiscriminantAnalysis()
# ----> 3 model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
#
# File <string>:3, in model_application(model, X_train, y_train, X_test, y_test, target_names)
#
# File c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:622, in LinearDiscriminantAnalysis.fit(self, X, y)
#     616     if self.covariance_estimator is not None:
#     617         raise ValueError(
#     618             "covariance estimator "
#     619             "is not supported "
#     620             "with svd solver. Try another solver"
#     621         )
# --> 622     self._solve_svd(X, y)
#     623 elif self.solver == "lsqr":
#     624     self._solve_lstsq(
#     625         X,
#     626         y,
#     627         shrinkage=self.shrinkage,
#     628         covariance_estimator=self.covariance_estimator,
#     629     )
#
# File c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\discriminant_analysis.py:502, in LinearDiscriminantAnalysis._solve_svd(self, X, y)
#     500 Xc = []
#     501 for idx, group in enumerate(self.classes_):
# --> 502     Xg = X[y == group]
#     503     Xc.append(Xg - self.means_[idx, :])
#     505 self.xbar_ = self.priors_ @ self.means_
#
# MemoryError: Unable to allocate 840. MiB for an array with shape (2240, 49152) and data type float64

# %%
# Criando modelo Gradient Boosting
model = DummyClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.13984375
# accuracy
# 0.13984375
#
# f1_macro
# 0.061343385880740224
#
# precision
# 0.0349609375
#
# recall
# 0.25
#
# confusion_matrix
# [[179   0   0   0]
#  [ 13   0   0   0]
#  [640   0   0   0]
#  [448   0   0   0]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.1398    1.0000    0.2454       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.0000    0.0000    0.0000       640
# Very_Mild_Demented     0.0000    0.0000    0.0000       448
#
#           accuracy                         0.1398      1280
#          macro avg     0.0350    0.2500    0.0613      1280
#       weighted avg     0.0196    0.1398    0.0343      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.13984375,
#  'f1_macro': 0.061343385880740224,
#  'precision': 0.0349609375,
#  'recall': 0.25,
#  'confusion_matrix': array([[179,   0,   0,   0],
#         [ 13,   0,   0,   0],
#         [640,   0,   0,   0],
#         [448,   0,   0,   0]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = RidgeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96875
# accuracy
# 0.96875
#
# f1_macro
# 0.9724946355366418
#
# precision
# 0.9762589194187051
#
# recall
# 0.9689545091779729
#
# confusion_matrix
# [[167   0   3   9]
#  [  0  13   0   0]
#  [  0   0 632   8]
#  [  5   0  15 428]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9709    0.9330    0.9516       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9723    0.9875    0.9798       640
# Very_Mild_Demented     0.9618    0.9554    0.9586       448
#
#           accuracy                         0.9688      1280
#          macro avg     0.9763    0.9690    0.9725      1280
#       weighted avg     0.9687    0.9688    0.9686      1280
# {'accuracy': 0.96875,
#  'f1_macro': 0.9724946355366418,
#  'precision': 0.9762589194187051,
#  'recall': 0.9689545091779729,
#  'confusion_matrix': array([[167,   0,   3,   9],
#         [  0,  13,   0,   0],
#         [  0,   0, 632,   8],
#         [  5,   0,  15, 428]], dtype=int64)}
