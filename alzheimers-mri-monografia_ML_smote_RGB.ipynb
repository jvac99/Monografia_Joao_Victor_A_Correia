# %%
import import_ipynb
from preprocessing_smote_RGB import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing_smote_RGB.ipynb
# importing Jupyter notebook from preprocessing_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# X:  6400
# X_train:  4480
# X_test:  1280
# X_val:  640
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 627,   45, 2240, 1568], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 627,   45, 2240, 1568], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# ...

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo de Random Forest
model = DecisionTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.68125
# accuracy
# 0.68125
#
# f1_macro
# 0.6237199892413956
#
# precision
# 0.6074828107889956
#
# recall
# 0.6440225430121554
#
# confusion_matrix
# [[106   1  38  34]
#  [  2   8   1   2]
#  [ 34   4 483 119]
#  [ 59   3 111 275]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.53      0.59      0.56       179
#  Moderate_Demented       0.50      0.62      0.55        13
#       Non_Demented       0.76      0.75      0.76       640
# Very_Mild_Demented       0.64      0.61      0.63       448
#
#           accuracy                           0.68      1280
#          macro avg       0.61      0.64      0.62      1280
#       weighted avg       0.68      0.68      0.68      1280
# {'accuracy': 0.68125,
#  'f1_macro': 0.6237199892413956,
#  'precision': 0.6074828107889956,
#  'recall': 0.6440225430121554,
#  'confusion_matrix': array([[106,   1,  38,  34],
#         [  2,   8,   1,   2],
#         [ 34,   4, 483, 119],
# ...

# %%
# Criando o modelo de Random Forest
model = ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.63203125
# accuracy
# 0.63203125
#
# f1_macro
# 0.5500132119302834
#
# precision
# 0.5187433397207979
#
# recall
# 0.6224948824743691
#
# confusion_matrix
# [[ 92   4  34  49]
#  [  2   9   1   1]
#  [ 68   6 443 123]
#  [ 53  11 119 265]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.43      0.51      0.47       179
#  Moderate_Demented       0.30      0.69      0.42        13
#       Non_Demented       0.74      0.69      0.72       640
# Very_Mild_Demented       0.61      0.59      0.60       448
#
#           accuracy                           0.63      1280
#          macro avg       0.52      0.62      0.55      1280
#       weighted avg       0.65      0.63      0.64      1280
# {'accuracy': 0.63203125,
#  'f1_macro': 0.5500132119302834,
#  'precision': 0.5187433397207979,
#  'recall': 0.6224948824743691,
#  'confusion_matrix': array([[ 92,   4,  34,  49],
#         [  2,   9,   1,   1],
#         [ 68,   6, 443, 123],
# ...

# %%
# Criando o modelo de Random Forest
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.93671875
# accuracy
# 0.93671875
#
# f1_macro
# 0.9487148842116838
#
# precision
# 0.9549938671223809
#
# recall
# 0.9430507407222666
#
# confusion_matrix
# [[160   0   4  15]
#  [  0  13   0   0]
#  [  5   0 615  20]
#  [  2   0  35 411]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.96      0.89      0.92       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.94      0.96      0.95       640
# Very_Mild_Demented       0.92      0.92      0.92       448
#
#           accuracy                           0.94      1280
#          macro avg       0.95      0.94      0.95      1280
#       weighted avg       0.94      0.94      0.94      1280
# {'accuracy': 0.93671875,
#  'f1_macro': 0.9487148842116838,
#  'precision': 0.9549938671223809,
#  'recall': 0.9430507407222666,
#  'confusion_matrix': array([[160,   0,   4,  15],
#         [  0,  13,   0,   0],
#         [  5,   0, 615,  20],
# ...

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.92734375
# accuracy
# 0.92734375
#
# f1_macro
# 0.8686112789415162
#
# precision
# 0.8170409276272969
#
# recall
# 0.95981986981245
#
# confusion_matrix
# [[178   0   0   1]
#  [  0  13   0   0]
#  [ 40   8 565  27]
#  [ 15   2   0 431]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.76      0.99      0.86       179
#  Moderate_Demented       0.57      1.00      0.72        13
#       Non_Demented       1.00      0.88      0.94       640
# Very_Mild_Demented       0.94      0.96      0.95       448
#
#           accuracy                           0.93      1280
#          macro avg       0.82      0.96      0.87      1280
#       weighted avg       0.94      0.93      0.93      1280
# {'accuracy': 0.92734375,
#  'f1_macro': 0.8686112789415162,
#  'precision': 0.8170409276272969,
#  'recall': 0.95981986981245,
#  'confusion_matrix': array([[178,   0,   0,   1],
#         [  0,  13,   0,   0],
#         [ 40,   8, 565,  27],
# ...

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.91875
# accuracy
# 0.91875
#
# f1_macro
# 0.9362237240012262
#
# precision
# 0.9389940598447806
#
# recall
# 0.9337346618116521
#
# confusion_matrix
# [[162   0   7  10]
#  [  0  13   0   0]
#  [ 11   0 604  25]
#  [  3   0  48 397]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.92      0.91      0.91       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.92      0.94      0.93       640
# Very_Mild_Demented       0.92      0.89      0.90       448
#
#           accuracy                           0.92      1280
#          macro avg       0.94      0.93      0.94      1280
#       weighted avg       0.92      0.92      0.92      1280
# {'accuracy': 0.91875,
#  'f1_macro': 0.9362237240012262,
#  'precision': 0.9389940598447806,
#  'recall': 0.9337346618116521,
#  'confusion_matrix': array([[162,   0,   7,  10],
#         [  0,  13,   0,   0],
#         [ 11,   0, 604,  25],
# ...

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1, early_stopping = True)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.8203125
# accuracy
# 0.8203125
#
# f1_macro
# 0.7155790016915431
#
# precision
# 0.6763331079061243
#
# recall
# 0.874305416999202
#
# confusion_matrix
# [[163   6   5   5]
#  [  0  13   0   0]
#  [ 40  13 544  43]
#  [ 34  18  66 330]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.69      0.91      0.78       179
#  Moderate_Demented       0.26      1.00      0.41        13
#       Non_Demented       0.88      0.85      0.87       640
# Very_Mild_Demented       0.87      0.74      0.80       448
#
#           accuracy                           0.82      1280
#          macro avg       0.68      0.87      0.72      1280
#       weighted avg       0.85      0.82      0.83      1280
# {'accuracy': 0.8203125,
#  'f1_macro': 0.7155790016915431,
#  'precision': 0.6763331079061243,
#  'recall': 0.874305416999202,
#  'confusion_matrix': array([[163,   6,   5,   5],
#         [  0,  13,   0,   0],
#         [ 40,  13, 544,  43],
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.86015625
# accuracy
# 0.86015625
#
# f1_macro
# 0.8628078488059533
#
# precision
# 0.8406778302347504
#
# recall
# 0.8898559083200319
#
# confusion_matrix
# [[151   0  14  14]
#  [  0  13   0   0]
#  [ 19   1 561  59]
#  [ 13   2  57 376]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.83      0.84      0.83       179
#  Moderate_Demented       0.81      1.00      0.90        13
#       Non_Demented       0.89      0.88      0.88       640
# Very_Mild_Demented       0.84      0.84      0.84       448
#
#           accuracy                           0.86      1280
#          macro avg       0.84      0.89      0.86      1280
#       weighted avg       0.86      0.86      0.86      1280
# {'accuracy': 0.86015625,
#  'f1_macro': 0.8628078488059533,
#  'precision': 0.8406778302347504,
#  'recall': 0.8898559083200319,
#  'confusion_matrix': array([[151,   0,  14,  14],
#         [  0,  13,   0,   0],
#         [ 19,   1, 561,  59],
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.47578125
# accuracy
# 0.47578125
#
# f1_macro
# 0.5183756793588068
#
# precision
# 0.5133303934676332
#
# recall
# 0.5659927711952851
#
# confusion_matrix
# [[101   0  37  41]
#  [  0  11   0   2]
#  [140   2 382 116]
#  [162   2 169 115]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.25      0.56      0.35       179
#  Moderate_Demented       0.73      0.85      0.79        13
#       Non_Demented       0.65      0.60      0.62       640
# Very_Mild_Demented       0.42      0.26      0.32       448
#
#           accuracy                           0.48      1280
#          macro avg       0.51      0.57      0.52      1280
#       weighted avg       0.51      0.48      0.48      1280
# {'accuracy': 0.47578125,
#  'f1_macro': 0.5183756793588068,
#  'precision': 0.5133303934676332,
#  'recall': 0.5659927711952851,
#  'confusion_matrix': array([[101,   0,  37,  41],
#         [  0,  11,   0,   2],
#         [140,   2, 382, 116],
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.53984375
# accuracy
# 0.53984375
#
# f1_macro
# 0.5008628366659756
#
# precision
# 0.47527480172478365
#
# recall
# 0.5591593876619191
#
# confusion_matrix
# [[ 93   4  26  56]
#  [  4   9   0   0]
#  [ 90   3 433 114]
#  [105   5 182 156]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.32      0.52      0.39       179
#  Moderate_Demented       0.43      0.69      0.53        13
#       Non_Demented       0.68      0.68      0.68       640
# Very_Mild_Demented       0.48      0.35      0.40       448
#
#           accuracy                           0.54      1280
#          macro avg       0.48      0.56      0.50      1280
#       weighted avg       0.55      0.54      0.54      1280
# {'accuracy': 0.53984375,
#  'f1_macro': 0.5008628366659756,
#  'precision': 0.47527480172478365,
#  'recall': 0.5591593876619191,
#  'confusion_matrix': array([[ 93,   4,  26,  56],
#         [  4,   9,   0,   0],
#         [ 90,   3, 433, 114],
# ...

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9751782471391962
#
# precision
# 0.9753001200480192
#
# recall
# 0.9751006958300081
#
# confusion_matrix
# [[172   0   6   1]
#  [  0  13   0   0]
#  [  3   0 627  10]
#  [  5   0  13 430]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.96      0.96      0.96       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.97      0.98      0.98       640
# Very_Mild_Demented       0.98      0.96      0.97       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.98      0.98      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9751782471391962,
#  'precision': 0.9753001200480192,
#  'recall': 0.9751006958300081,
#  'confusion_matrix': array([[172,   0,   6,   1],
#         [  0,  13,   0,   0],
#         [  3,   0, 627,  10],
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.91015625
# accuracy
# 0.91015625
#
# f1_macro
# 0.9227595741042577
#
# precision
# 0.9432957097514689
#
# recall
# 0.9076416600159617
#
# confusion_matrix
# [[141   0  14  24]
#  [  0  13   0   0]
#  [  1   0 618  21]
#  [  3   0  52 393]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.97      0.79      0.87       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.90      0.97      0.93       640
# Very_Mild_Demented       0.90      0.88      0.89       448
#
#           accuracy                           0.91      1280
#          macro avg       0.94      0.91      0.92      1280
#       weighted avg       0.91      0.91      0.91      1280
# {'accuracy': 0.91015625,
#  'f1_macro': 0.9227595741042577,
#  'precision': 0.9432957097514689,
#  'recall': 0.9076416600159617,
#  'confusion_matrix': array([[141,   0,  14,  24],
#         [  0,  13,   0,   0],
#         [  1,   0, 618,  21],
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.35625
# accuracy
# 0.35625
#
# f1_macro
# 0.251124082615516
#
# precision
# 0.2506253496179749
#
# recall
# 0.2516978002793296
#
# confusion_matrix
# [[ 51   0 120   8]
#  [  3   0   7   3]
#  [ 46   0 272 322]
#  [ 75   0 240 133]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.29      0.28      0.29       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.43      0.42      0.43       640
# Very_Mild_Demented       0.29      0.30      0.29       448
#
#           accuracy                           0.36      1280
#          macro avg       0.25      0.25      0.25      1280
#       weighted avg       0.35      0.36      0.35      1280
# ...

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", class_weight = "balanced", C = 100,  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.99140625
# accuracy
# 0.99140625
#
# f1_macro
# 0.9926609430694316
#
# precision
# 0.9943576940275631
#
# recall
# 0.9910093899640862
#
# confusion_matrix
# [[175   0   4   0]
#  [  0  13   0   0]
#  [  1   0 637   2]
#  [  0   0   4 444]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.98      0.99       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.99      1.00      0.99       640
# Very_Mild_Demented       1.00      0.99      0.99       448
#
#           accuracy                           0.99      1280
#          macro avg       0.99      0.99      0.99      1280
#       weighted avg       0.99      0.99      0.99      1280
# {'accuracy': 0.99140625,
#  'f1_macro': 0.9926609430694316,
#  'precision': 0.9943576940275631,
#  'recall': 0.9910093899640862,
#  'confusion_matrix': array([[175,   0,   4,   0],
#         [  0,  13,   0,   0],
#         [  1,   0, 637,   2],
# ...

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9741657784137153
#
# precision
# 0.9824161173670237
#
# recall
# 0.9668851007581803
#
# confusion_matrix
# [[164   0   7   8]
#  [  0  13   0   0]
#  [  1   0 636   3]
#  [  0   0  19 429]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.92      0.95       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.96      0.99      0.98       640
# Very_Mild_Demented       0.97      0.96      0.97       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.97      0.97      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9741657784137153,
#  'precision': 0.9824161173670237,
#  'recall': 0.9668851007581803,
#  'confusion_matrix': array([[164,   0,   7,   8],
#         [  0,  13,   0,   0],
#         [  1,   0, 636,   3],
# ...

# %%
# Criando modelo Gradient Boosting
model = GradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.57890625
# accuracy
# 0.57890625
#
# f1_macro
# 0.5044799911228397
#
# precision
# 0.6386096113301423
#
# recall
# 0.4577148497452268
#
# confusion_matrix
# [[ 42   0  66  71]
#  [  1   5   3   4]
#  [ 28   0 504 108]
#  [ 30   0 228 190]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.42      0.23      0.30       179
#  Moderate_Demented       1.00      0.38      0.56        13
#       Non_Demented       0.63      0.79      0.70       640
# Very_Mild_Demented       0.51      0.42      0.46       448
#
#           accuracy                           0.58      1280
#          macro avg       0.64      0.46      0.50      1280
#       weighted avg       0.56      0.58      0.56      1280
# {'accuracy': 0.57890625,
#  'f1_macro': 0.5044799911228397,
#  'precision': 0.6386096113301423,
#  'recall': 0.4577148497452268,
#  'confusion_matrix': array([[ 42,   0,  66,  71],
#         [  1,   5,   3,   4],
#         [ 28,   0, 504, 108],
# ...

# %%
# Criando modelo Gradient Boosting
model = HistGradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96640625
# accuracy
# 0.96640625
#
# f1_macro
# 0.9247670239259262
#
# precision
# 0.9800774607340359
#
# recall
# 0.8852109264687826
#
# confusion_matrix
# [[159   0   6  14]
#  [  0   9   1   3]
#  [  0   0 636   4]
#  [  0   0  15 433]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       1.00      0.89      0.94       179
#  Moderate_Demented       1.00      0.69      0.82        13
#       Non_Demented       0.97      0.99      0.98       640
# Very_Mild_Demented       0.95      0.97      0.96       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.89      0.92      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.96640625,
#  'f1_macro': 0.9247670239259262,
#  'precision': 0.9800774607340359,
#  'recall': 0.8852109264687826,
#  'confusion_matrix': array([[159,   0,   6,  14],
#         [  0,   9,   1,   3],
#         [  0,   0, 636,   4],
# ...

# %%
# Criando modelo Gradient Boosting
model = LinearDiscriminantAnalysis()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.83515625
# accuracy
# 0.83515625
#
# f1_macro
# 0.8747940575409934
#
# precision
# 0.8799555540840233
#
# recall
# 0.8704842752394254
#
# confusion_matrix
# [[146   0  13  20]
#  [  0  13   0   0]
#  [ 10   0 545  85]
#  [ 10   0  73 365]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.88      0.82      0.85       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.86      0.85      0.86       640
# Very_Mild_Demented       0.78      0.81      0.80       448
#
#           accuracy                           0.84      1280
#          macro avg       0.88      0.87      0.87      1280
#       weighted avg       0.84      0.84      0.84      1280
# {'accuracy': 0.83515625,
#  'f1_macro': 0.8747940575409934,
#  'precision': 0.8799555540840233,
#  'recall': 0.8704842752394254,
#  'confusion_matrix': array([[146,   0,  13,  20],
#         [  0,  13,   0,   0],
#         [ 10,   0, 545,  85],
# ...

# %%
# Criando modelo Gradient Boosting
model = DummyClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.5
# accuracy
# 0.5
#
# f1_macro
# 0.16666666666666666
#
# precision
# 0.125
#
# recall
# 0.25
#
# confusion_matrix
# [[  0   0 179   0]
#  [  0   0  13   0]
#  [  0   0 640   0]
#  [  0   0 448   0]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.00      0.00      0.00       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.50      1.00      0.67       640
# Very_Mild_Demented       0.00      0.00      0.00       448
#
#           accuracy                           0.50      1280
#          macro avg       0.12      0.25      0.17      1280
#       weighted avg       0.25      0.50      0.33      1280
# ...

# %%
# Criando modelo Gradient Boosting
model = RidgeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96953125
# accuracy
# 0.96953125
#
# f1_macro
# 0.9715730984474658
#
# precision
# 0.976742562038247
#
# recall
# 0.9668292971867518
#
# confusion_matrix
# [[164   0   6   9]
#  [  0  13   0   0]
#  [  0   0 633   7]
#  [  5   0  12 431]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.97      0.92      0.94       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.97      0.99      0.98       640
# Very_Mild_Demented       0.96      0.96      0.96       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.97      0.97      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.96953125,
#  'f1_macro': 0.9715730984474658,
#  'precision': 0.976742562038247,
#  'recall': 0.9668292971867518,
#  'confusion_matrix': array([[164,   0,   6,   9],
#         [  0,  13,   0,   0],
#         [  0,   0, 633,   7],
# ...
