# %%
import import_ipynb
from preprocessing import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# X:  6400
# X_train:  4480
# X_test:  1280
# X_val:  640
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 627,   45, 2240, 1568], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 627,   45, 2240, 1568], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# Unique Values: [0 1 2 3]
# Frequency Values: [ 627   45 2240 1568]
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# **Validação Cruzada**

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = DecisionTreeClassifier(random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.70089286 0.68861607 0.71205357 0.69419643 0.69754464]
# Mean R^2 for Cross-Validation K-Fold: 0.6986607142857143
# accuracy
# 0.53984375
#
# f1_macro
# 0.40541230266697903
#
# precision
# 0.39988350300329456
#
# recall
# 0.41374434530204435
#
# confusion_matrix
# [[ 52   3  53  71]
#  [  2   3   5   3]
#  [ 63   6 427 144]
#  [ 59   6 174 209]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2955    0.2905    0.2930       179
#  Moderate_Demented     0.1667    0.2308    0.1935        13
#       Non_Demented     0.6480    0.6672    0.6574       640
# Very_Mild_Demented     0.4895    0.4665    0.4777       448
#
#           accuracy                         0.5398      1280
#          macro avg     0.3999    0.4137    0.4054      1280
#       weighted avg     0.5383    0.5398    0.5388      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = ExtraTreeClassifier(random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.6640625  0.63504464 0.6484375  0.66741071 0.63950893]
# Mean R^2 for Cross-Validation K-Fold: 0.6508928571428572
# accuracy
# 0.51875
#
# f1_macro
# 0.36768701583040875
#
# precision
# 0.3675815391240923
#
# recall
# 0.36904215939437657
#
# confusion_matrix
# [[ 58   2  69  50]
#  [  2   1   5   5]
#  [ 65   6 411 158]
#  [ 78   3 173 194]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2857    0.3240    0.3037       179
#  Moderate_Demented     0.0833    0.0769    0.0800        13
#       Non_Demented     0.6246    0.6422    0.6333       640
# Very_Mild_Demented     0.4767    0.4330    0.4538       448
#
#           accuracy                         0.5188      1280
#          macro avg     0.3676    0.3690    0.3677      1280
#       weighted avg     0.5199    0.5188    0.5187      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.87388393 0.85825893 0.84263393 0.87723214 0.86160714]
# Mean R^2 for Cross-Validation K-Fold: 0.8627232142857142
# accuracy
# 0.68515625
#
# f1_macro
# 0.44043967675896084
#
# precision
# 0.559344050445225
#
# recall
# 0.4280230571628093
#
# confusion_matrix
# [[ 42   0  49  88]
#  [  1   0   3   9]
#  [  0   0 577  63]
#  [  3   0 187 258]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9130    0.2346    0.3733       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.7071    0.9016    0.7926       640
# Very_Mild_Demented     0.6172    0.5759    0.5958       448
#
#           accuracy                         0.6852      1280
#          macro avg     0.5593    0.4280    0.4404      1280
#       weighted avg     0.6973    0.6852    0.6570      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = RandomForestClassifier(random_state = SEED, n_jobs = -1, n_estimators = 250)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.890625   0.859375   0.85379464 0.89508929 0.87611607]
# Mean R^2 for Cross-Validation K-Fold: 0.875
# accuracy
# 0.6890625
#
# f1_macro
# 0.44826281853097383
#
# precision
# 0.5810921269228586
#
# recall
# 0.4339971568236233
#
# confusion_matrix
# [[ 44   0  40  95]
#  [  0   0   4   9]
#  [  0   0 568  72]
#  [  0   0 178 270]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.2458    0.3946       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.7190    0.8875    0.7944       640
# Very_Mild_Demented     0.6054    0.6027    0.6040       448
#
#           accuracy                         0.6891      1280
#          macro avg     0.5811    0.4340    0.4483      1280
#       weighted avg     0.7112    0.6891    0.6638      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = KNeighborsClassifier(n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.92299107 0.93191964 0.92299107 0.92075893 0.921875  ]
# Mean R^2 for Cross-Validation K-Fold: 0.9241071428571429
# accuracy
# 0.6453125
#
# f1_macro
# 0.5101852981394028
#
# precision
# 0.719009280735766
#
# recall
# 0.4761467190281785
#
# confusion_matrix
# [[ 83   0  59  37]
#  [  2   2   4   5]
#  [ 24   0 548  68]
#  [ 34   0 221 193]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5804    0.4637    0.5155       179
#  Moderate_Demented     1.0000    0.1538    0.2667        13
#       Non_Demented     0.6587    0.8562    0.7446       640
# Very_Mild_Demented     0.6370    0.4308    0.5140       448
#
#           accuracy                         0.6453      1280
#          macro avg     0.7190    0.4761    0.5102      1280
#       weighted avg     0.6436    0.6453    0.6270      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SGDClassifier(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.90959821 0.890625   0.89955357 0.89955357 0.76227679]
# Mean R^2 for Cross-Validation K-Fold: 0.8723214285714285
# accuracy
# 0.6953125
#
# f1_macro
# 0.6853432782249769
#
# precision
# 0.7271235960921263
#
# recall
# 0.657416958913991
#
# confusion_matrix
# [[107   0  26  46]
#  [  2   8   0   3]
#  [ 30   0 468 142]
#  [ 32   1 108 307]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.6257    0.5978    0.6114       179
#  Moderate_Demented     0.8889    0.6154    0.7273        13
#       Non_Demented     0.7774    0.7312    0.7536       640
# Very_Mild_Demented     0.6165    0.6853    0.6490       448
#
#           accuracy                         0.6953      1280
#          macro avg     0.7271    0.6574    0.6853      1280
#       weighted avg     0.7010    0.6953    0.6969      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.86941964 0.8671875  0.88839286 0.89174107 0.85491071]
# Mean R^2 for Cross-Validation K-Fold: 0.8743303571428571
# accuracy
# 0.75234375
#
# f1_macro
# 0.6985352791412703
#
# precision
# 0.8046301053630619
#
# recall
# 0.6465735120326601
#
# confusion_matrix
# [[104   0  33  42]
#  [  3   6   1   3]
#  [ 15   0 538  87]
#  [ 21   0 112 315]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7273    0.5810    0.6460       179
#  Moderate_Demented     1.0000    0.4615    0.6316        13
#       Non_Demented     0.7865    0.8406    0.8127       640
# Very_Mild_Demented     0.7047    0.7031    0.7039       448
#
#           accuracy                         0.7523      1280
#          macro avg     0.8046    0.6466    0.6985      1280
#       weighted avg     0.7518    0.7523    0.7495      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.5078125  0.46540179 0.48995536 0.49107143 0.54799107]
# Mean R^2 for Cross-Validation K-Fold: 0.5004464285714285
# accuracy
# 0.525
#
# f1_macro
# 0.2843541221365503
#
# precision
# 0.32614601544806354
#
# recall
# 0.3020151636073424
#
# confusion_matrix
# [[  4   0  61 114]
#  [  0   0   4   9]
#  [  2   0 456 182]
#  [  8   0 228 212]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2857    0.0223    0.0415       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.6088    0.7125    0.6566       640
# Very_Mild_Demented     0.4101    0.4732    0.4394       448
#
#           accuracy                         0.5250      1280
#          macro avg     0.3261    0.3020    0.2844      1280
#       weighted avg     0.4879    0.5250    0.4879      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.49553571 0.48325893 0.48325893 0.52008929 0.54017857]
# Mean R^2 for Cross-Validation K-Fold: 0.5044642857142858
# accuracy
# 0.47890625
#
# f1_macro
# 0.3194384343036979
#
# precision
# 0.3268337936275733
#
# recall
# 0.37239531374700724
#
# confusion_matrix
# [[119   0  23  37]
#  [  7   0   3   3]
#  [136   0 415  89]
#  [179   0 190  79]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2698    0.6648    0.3839       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.6577    0.6484    0.6530       640
# Very_Mild_Demented     0.3798    0.1763    0.2409       448
#
#           accuracy                         0.4789      1280
#          macro avg     0.3268    0.3724    0.3194      1280
#       weighted avg     0.4995    0.4789    0.4645      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'rbf', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\svm\_base.py", line 240, in fit
#     X_var = (X.multiply(X)).mean() - (X.mean()) ** 2 if sparse else X.var()
#                                                                     ^^^^^^^
#   File "c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\numpy\core\_methods.py", line 233, in _var
#     x = asanyarray(arr - arrmean)
#                    ~~~~^~~~~~~~~
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 448. MiB for an array with shape (3584, 16384) and data type float64
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# K-Fold (R^2) Scores: [0.73102679 0.70982143 0.68080357        nan 0.71986607]
# Mean R^2 for Cross-Validation K-Fold: nan
# accuracy
# 0.59375
#
# f1_macro
# 0.306482412327594
#
# precision
# 0.28570946975519906
#
# recall
# 0.33387276785714287
#
# confusion_matrix
# [[  0   0  68 111]
#  [  0   0   3  10]
#  [  0   0 539 101]
#  [  0   0 227 221]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.0000    0.0000    0.0000       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.6440    0.8422    0.7299       640
# Very_Mild_Demented     0.4989    0.4933    0.4961       448
#
#           accuracy                         0.5938      1280
#          macro avg     0.2857    0.3339    0.3065      1280
#       weighted avg     0.4966    0.5938    0.5386      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.97209821 0.95089286 0.9609375  0.95424107 0.9375    ]
# Mean R^2 for Cross-Validation K-Fold: 0.9551339285714284
# accuracy
# 0.76796875
#
# f1_macro
# 0.7468102939344545
#
# precision
# 0.8097139781718716
#
# recall
# 0.7073224981198969
#
# confusion_matrix
# [[118   0  27  34]
#  [  3   8   0   2]
#  [ 27   0 535  78]
#  [ 21   0 105 322]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.6982    0.6592    0.6782       179
#  Moderate_Demented     1.0000    0.6154    0.7619        13
#       Non_Demented     0.8021    0.8359    0.8187       640
# Very_Mild_Demented     0.7385    0.7188    0.7285       448
#
#           accuracy                         0.7680      1280
#          macro avg     0.8097    0.7073    0.7468      1280
#       weighted avg     0.7673    0.7680    0.7669      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.88392857 0.88727679 0.88058036 0.90736607 0.88504464]
# Mean R^2 for Cross-Validation K-Fold: 0.8888392857142857
# accuracy
# 0.7046875
#
# f1_macro
# 0.581863148537024
#
# precision
# 0.7914211597464025
#
# recall
# 0.5285045458207993
#
# confusion_matrix
# [[ 70   0  39  70]
#  [  1   3   0   9]
#  [ 10   0 535  95]
#  [  7   0 147 294]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7955    0.3911    0.5243       179
#  Moderate_Demented     1.0000    0.2308    0.3750        13
#       Non_Demented     0.7420    0.8359    0.7862       640
# Very_Mild_Demented     0.6282    0.6562    0.6419       448
#
#           accuracy                         0.7047      1280
#          macro avg     0.7914    0.5285    0.5819      1280
#       weighted avg     0.7123    0.7047    0.6949      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.32254464 0.36830357 0.359375   0.34486607 0.33705357]
# Mean R^2 for Cross-Validation K-Fold: 0.3464285714285714
# accuracy
# 0.3734375
#
# f1_macro
# 0.16547835771256827
#
# precision
# 0.1543978500643861
#
# recall
# 0.19542410714285716
#
# confusion_matrix
# [[  0   0 178   1]
#  [  0   0  11   2]
#  [  4   0 426 210]
#  [  0   0 396  52]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.0000    0.0000    0.0000       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.4214    0.6656    0.5161       640
# Very_Mild_Demented     0.1962    0.1161    0.1459       448
#
#           accuracy                         0.3734      1280
#          macro avg     0.1544    0.1954    0.1655      1280
#       weighted avg     0.2794    0.3734    0.3091      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9578125
# accuracy
# 0.9578125
#
# f1_macro
# 0.9197703235021888
#
# precision
# 0.9746193769719854
#
# recall
# 0.8804133780849039
#
# confusion_matrix
# [[160   0   7  12]
#  [  0   9   2   2]
#  [  0   0 633   7]
#  [  1   0  23 424]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9938    0.8939    0.9412       179
#  Moderate_Demented     1.0000    0.6923    0.8182        13
#       Non_Demented     0.9519    0.9891    0.9701       640
# Very_Mild_Demented     0.9528    0.9464    0.9496       448
#
#           accuracy                         0.9578      1280
#          macro avg     0.9746    0.8804    0.9198      1280
#       weighted avg     0.9586    0.9578    0.9573      1280
# {'accuracy': 0.9578125,
#  'f1_macro': 0.9197703235021888,
#  'precision': 0.9746193769719854,
#  'recall': 0.8804133780849039,
#  'confusion_matrix': array([[160,   0,   7,  12],
#         [  0,   9,   2,   2],
#         [  0,   0, 633,   7],
#         [  1,   0,  23, 424]], dtype=int64)}

# %%
model = GradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.87578125
# accuracy
# 0.87578125
#
# f1_macro
# 0.7955426794566572
#
# precision
# 0.8634592061558465
#
# recall
# 0.7529339201301491
#
# confusion_matrix
# [[117   0  11  51]
#  [  0   7   2   4]
#  [  6   2 606  26]
#  [  0   0  57 391]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9512    0.6536    0.7748       179
#  Moderate_Demented     0.7778    0.5385    0.6364        13
#       Non_Demented     0.8964    0.9469    0.9210       640
# Very_Mild_Demented     0.8284    0.8728    0.8500       448
#
#           accuracy                         0.8758      1280
#          macro avg     0.8635    0.7529    0.7955      1280
#       weighted avg     0.8791    0.8758    0.8728      1280
# {'accuracy': 0.87578125,
#  'f1_macro': 0.7955426794566572,
#  'precision': 0.8634592061558465,
#  'recall': 0.7529339201301491,
#  'confusion_matrix': array([[117,   0,  11,  51],
#         [  0,   7,   2,   4],
#         [  6,   2, 606,  26],
#         [  0,   0,  57, 391]], dtype=int64)}

# %%
model = AdaBoostClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.57890625
# accuracy
# 0.57890625
#
# f1_macro
# 0.5044799911228397
#
# precision
# 0.6386096113301423
#
# recall
# 0.4577148497452268
#
# confusion_matrix
# [[ 42   0  66  71]
#  [  1   5   3   4]
#  [ 28   0 504 108]
#  [ 30   0 228 190]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.4158    0.2346    0.3000       179
#  Moderate_Demented     1.0000    0.3846    0.5556        13
#       Non_Demented     0.6292    0.7875    0.6995       640
# Very_Mild_Demented     0.5094    0.4241    0.4629       448
#
#           accuracy                         0.5789      1280
#          macro avg     0.6386    0.4577    0.5045      1280
#       weighted avg     0.5612    0.5789    0.5594      1280
# {'accuracy': 0.57890625,
#  'f1_macro': 0.5044799911228397,
#  'precision': 0.6386096113301423,
#  'recall': 0.4577148497452268,
#  'confusion_matrix': array([[ 42,   0,  66,  71],
#         [  1,   5,   3,   4],
#         [ 28,   0, 504, 108],
#         [ 30,   0, 228, 190]], dtype=int64)}

# %%
model = HistGradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96640625
# accuracy
# 0.96640625
#
# f1_macro
# 0.9247670239259262
#
# precision
# 0.9800774607340359
#
# recall
# 0.8852109264687826
#
# confusion_matrix
# [[159   0   6  14]
#  [  0   9   1   3]
#  [  0   0 636   4]
#  [  0   0  15 433]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.8883    0.9408       179
#  Moderate_Demented     1.0000    0.6923    0.8182        13
#       Non_Demented     0.9666    0.9938    0.9800       640
# Very_Mild_Demented     0.9537    0.9665    0.9601       448
#
#           accuracy                         0.9664      1280
#          macro avg     0.9801    0.8852    0.9248      1280
#       weighted avg     0.9671    0.9664    0.9659      1280
# {'accuracy': 0.96640625,
#  'f1_macro': 0.9247670239259262,
#  'precision': 0.9800774607340359,
#  'recall': 0.8852109264687826,
#  'confusion_matrix': array([[159,   0,   6,  14],
#         [  0,   9,   1,   3],
#         [  0,   0, 636,   4],
#         [  0,   0,  15, 433]], dtype=int64)}

# %%
model = LinearDiscriminantAnalysis()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.83515625
# accuracy
# 0.83515625
#
# f1_macro
# 0.8747940575409934
#
# precision
# 0.8799555540840233
#
# recall
# 0.8704842752394254
#
# confusion_matrix
# [[146   0  13  20]
#  [  0  13   0   0]
#  [ 10   0 545  85]
#  [ 10   0  73 365]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8795    0.8156    0.8464       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8637    0.8516    0.8576       640
# Very_Mild_Demented     0.7766    0.8147    0.7952       448
#
#           accuracy                         0.8352      1280
#          macro avg     0.8800    0.8705    0.8748      1280
#       weighted avg     0.8368    0.8352    0.8356      1280
# {'accuracy': 0.83515625,
#  'f1_macro': 0.8747940575409934,
#  'precision': 0.8799555540840233,
#  'recall': 0.8704842752394254,
#  'confusion_matrix': array([[146,   0,  13,  20],
#         [  0,  13,   0,   0],
#         [ 10,   0, 545,  85],
#         [ 10,   0,  73, 365]], dtype=int64)}

# %%
model = DummyClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.5
# accuracy
# 0.5
#
# f1_macro
# 0.16666666666666666
#
# precision
# 0.125
#
# recall
# 0.25
#
# confusion_matrix
# [[  0   0 179   0]
#  [  0   0  13   0]
#  [  0   0 640   0]
#  [  0   0 448   0]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.0000    0.0000    0.0000       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.5000    1.0000    0.6667       640
# Very_Mild_Demented     0.0000    0.0000    0.0000       448
#
#           accuracy                         0.5000      1280
#          macro avg     0.1250    0.2500    0.1667      1280
#       weighted avg     0.2500    0.5000    0.3333      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.5,
#  'f1_macro': 0.16666666666666666,
#  'precision': 0.125,
#  'recall': 0.25,
#  'confusion_matrix': array([[  0,   0, 179,   0],
#         [  0,   0,  13,   0],
#         [  0,   0, 640,   0],
#         [  0,   0, 448,   0]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = RidgeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96953125
# accuracy
# 0.96953125
#
# f1_macro
# 0.9715730984474658
#
# precision
# 0.976742562038247
#
# recall
# 0.9668292971867518
#
# confusion_matrix
# [[164   0   6   9]
#  [  0  13   0   0]
#  [  0   0 633   7]
#  [  5   0  12 431]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9704    0.9162    0.9425       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9724    0.9891    0.9806       640
# Very_Mild_Demented     0.9642    0.9621    0.9631       448
#
#           accuracy                         0.9695      1280
#          macro avg     0.9767    0.9668    0.9716      1280
#       weighted avg     0.9695    0.9695    0.9694      1280
# {'accuracy': 0.96953125,
#  'f1_macro': 0.9715730984474658,
#  'precision': 0.976742562038247,
#  'recall': 0.9668292971867518,
#  'confusion_matrix': array([[164,   0,   6,   9],
#         [  0,  13,   0,   0],
#         [  0,   0, 633,   7],
#         [  5,   0,  12, 431]], dtype=int64)}

# %%
#model = RandomForestClassifier(random_state = SEED, n_jobs=-1)
#result_scores = cross_val_score(model, X_train_flatten, y_train, cv = k, scoring = 'accuracy', n_jobs = -1)

#print("K-Fold (R^2) Scores: {0}".format(result_scores))
#print("Mean R^2 for Cross-Validation K-Fold: {0}".format(result_scores.mean()))
# Out:
# K-Fold (R^2) Scores: [0.84486607 0.85714286 0.85491071 0.86607143 0.87053571]
# Mean R^2 for Cross-Validation K-Fold: 0.8587053571428571
