# %%
import import_ipynb
from preprocessing import *
from imports.imports_common_models_ML import *

# %% [markdown]
# **Validação Cruzada**

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.87388393 0.85825893 0.84263393 0.87723214 0.86160714]
# Mean R^2 for Cross-Validation K-Fold: 0.8627232142857142
# accuracy
# 0.68515625
#
# f1_macro
# 0.44043967675896084
#
# precision
# 0.559344050445225
#
# recall
# 0.4280230571628093
#
# confusion_matrix
# [[ 42   0  49  88]
#  [  1   0   3   9]
#  [  0   0 577  63]
#  [  3   0 187 258]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.91      0.23      0.37       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.71      0.90      0.79       640
# Very_Mild_Demented       0.62      0.58      0.60       448
#
#           accuracy                           0.69      1280
#          macro avg       0.56      0.43      0.44      1280
#       weighted avg       0.70      0.69      0.66      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = KNeighborsClassifier(n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.92299107 0.93191964 0.92299107 0.92075893 0.921875  ]
# Mean R^2 for Cross-Validation K-Fold: 0.9241071428571429
# accuracy
# 0.6453125
#
# f1_macro
# 0.5101852981394028
#
# precision
# 0.719009280735766
#
# recall
# 0.4761467190281785
#
# confusion_matrix
# [[ 83   0  59  37]
#  [  2   2   4   5]
#  [ 24   0 548  68]
#  [ 34   0 221 193]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.58      0.46      0.52       179
#  Moderate_Demented       1.00      0.15      0.27        13
#       Non_Demented       0.66      0.86      0.74       640
# Very_Mild_Demented       0.64      0.43      0.51       448
#
#           accuracy                           0.65      1280
#          macro avg       0.72      0.48      0.51      1280
#       weighted avg       0.64      0.65      0.63      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SGDClassifier(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.82254464 0.90290179 0.87834821 0.88950893 0.90625   ]
# Mean R^2 for Cross-Validation K-Fold: 0.8799107142857142
# accuracy
# 0.7473958333333334
#
# f1_macro
# 0.7318422695490723
#
# precision
# 0.7984729962706943
#
# recall
# 0.6929269505284952
#
# confusion_matrix
# [[167   0  62  47]
#  [  3  13   0   3]
#  [ 27   0 876  57]
#  [ 54   0 232 379]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.67      0.61      0.63       276
#            1       1.00      0.68      0.81        19
#            2       0.75      0.91      0.82       960
#            3       0.78      0.57      0.66       665
#
#     accuracy                           0.75      1920
#    macro avg       0.80      0.69      0.73      1920
# weighted avg       0.75      0.75      0.74      1920

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SGDClassifier(random_state = SEED, n_jobs = -1, early_stopping = True)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.55915179 0.57366071 0.75669643 0.73883929 0.76339286]
# Mean R^2 for Cross-Validation K-Fold: 0.6783482142857143
# accuracy
# 0.52421875
#
# f1_macro
# 0.34963175858741363
#
# precision
# 0.5423473370540577
#
# recall
# 0.37322440565719195
#
# confusion_matrix
# [[ 12   5  64  98]
#  [  0   3   3   7]
#  [  0  11 402 227]
#  [  0   5 189 254]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       1.00      0.07      0.13       179
#  Moderate_Demented       0.12      0.23      0.16        13
#       Non_Demented       0.61      0.63      0.62       640
# Very_Mild_Demented       0.43      0.57      0.49       448
#
#           accuracy                           0.52      1280
#          macro avg       0.54      0.37      0.35      1280
#       weighted avg       0.60      0.52      0.50      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.86941964 0.8671875  0.88839286 0.89174107 0.85491071]
# Mean R^2 for Cross-Validation K-Fold: 0.8743303571428571
# accuracy
# 0.75234375
#
# f1_macro
# 0.6985352791412703
#
# precision
# 0.8046301053630619
#
# recall
# 0.6465735120326601
#
# confusion_matrix
# [[104   0  33  42]
#  [  3   6   1   3]
#  [ 15   0 538  87]
#  [ 21   0 112 315]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.73      0.58      0.65       179
#  Moderate_Demented       1.00      0.46      0.63        13
#       Non_Demented       0.79      0.84      0.81       640
# Very_Mild_Demented       0.70      0.70      0.70       448
#
#           accuracy                           0.75      1280
#          macro avg       0.80      0.65      0.70      1280
#       weighted avg       0.75      0.75      0.75      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.5078125  0.46540179 0.48995536 0.49107143 0.54799107]
# Mean R^2 for Cross-Validation K-Fold: 0.5004464285714285
# accuracy
# 0.525
#
# f1_macro
# 0.2843541221365503
#
# precision
# 0.32614601544806354
#
# recall
# 0.3020151636073424
#
# confusion_matrix
# [[  4   0  61 114]
#  [  0   0   4   9]
#  [  2   0 456 182]
#  [  8   0 228 212]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.29      0.02      0.04       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.61      0.71      0.66       640
# Very_Mild_Demented       0.41      0.47      0.44       448
#
#           accuracy                           0.53      1280
#          macro avg       0.33      0.30      0.28      1280
#       weighted avg       0.49      0.53      0.49      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.49553571 0.48325893 0.48325893 0.52008929 0.54017857]
# Mean R^2 for Cross-Validation K-Fold: 0.5044642857142858
# accuracy
# 0.47890625
#
# f1_macro
# 0.3194384343036979
#
# precision
# 0.3268337936275733
#
# recall
# 0.37239531374700724
#
# confusion_matrix
# [[119   0  23  37]
#  [  7   0   3   3]
#  [136   0 415  89]
#  [179   0 190  79]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.27      0.66      0.38       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.66      0.65      0.65       640
# Very_Mild_Demented       0.38      0.18      0.24       448
#
#           accuracy                           0.48      1280
#          macro avg       0.33      0.37      0.32      1280
#       weighted avg       0.50      0.48      0.46      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'rbf', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.73102679 0.70982143 0.68080357 0.72433036 0.71986607]
# Mean R^2 for Cross-Validation K-Fold: 0.7131696428571429
# accuracy
# 0.59375
#
# f1_macro
# 0.306482412327594
#
# precision
# 0.28570946975519906
#
# recall
# 0.33387276785714287
#
# confusion_matrix
# [[  0   0  68 111]
#  [  0   0   3  10]
#  [  0   0 539 101]
#  [  0   0 227 221]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.00      0.00      0.00       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.64      0.84      0.73       640
# Very_Mild_Demented       0.50      0.49      0.50       448
#
#           accuracy                           0.59      1280
#          macro avg       0.29      0.33      0.31      1280
#       weighted avg       0.50      0.59      0.54      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.97209821 0.95089286 0.9609375  0.95424107 0.9375    ]
# Mean R^2 for Cross-Validation K-Fold: 0.9551339285714284
# accuracy
# 0.76796875
#
# f1_macro
# 0.7468102939344545
#
# precision
# 0.8097139781718716
#
# recall
# 0.7073224981198969
#
# confusion_matrix
# [[118   0  27  34]
#  [  3   8   0   2]
#  [ 27   0 535  78]
#  [ 21   0 105 322]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.70      0.66      0.68       179
#  Moderate_Demented       1.00      0.62      0.76        13
#       Non_Demented       0.80      0.84      0.82       640
# Very_Mild_Demented       0.74      0.72      0.73       448
#
#           accuracy                           0.77      1280
#          macro avg       0.81      0.71      0.75      1280
#       weighted avg       0.77      0.77      0.77      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.875      0.88616071 0.88058036 0.88727679 0.875     ]
# Mean R^2 for Cross-Validation K-Fold: 0.8808035714285716
# accuracy
# 0.7395833333333334
#
# f1_macro
# 0.6746019372121888
#
# precision
# 0.7947819535566305
#
# recall
# 0.618853519668737
#
# confusion_matrix
# [[123   0  43 110]
#  [  2   9   0   8]
#  [ 24   0 824 112]
#  [ 21   0 180 464]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.72      0.45      0.55       276
#            1       1.00      0.47      0.64        19
#            2       0.79      0.86      0.82       960
#            3       0.67      0.70      0.68       665
#
#     accuracy                           0.74      1920
#    macro avg       0.79      0.62      0.67      1920
# weighted avg       0.74      0.74      0.73      1920

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.32700893 0.35379464 0.29464286 0.31473214 0.34486607]
# Mean R^2 for Cross-Validation K-Fold: 0.32700892857142855
# accuracy
# 0.32708333333333334
#
# f1_macro
# 0.16528399805386793
#
# precision
# 0.15749179833863053
#
# recall
# 0.17925281954887218
#
# confusion_matrix
# [[  0   0 263  13]
#  [  0   0  15   4]
#  [ 79   0 492 389]
#  [  1   0 528 136]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       276
#            1       0.00      0.00      0.00        19
#            2       0.38      0.51      0.44       960
#            3       0.25      0.20      0.23       665
#
#     accuracy                           0.33      1920
#    macro avg       0.16      0.18      0.17      1920
# weighted avg       0.28      0.33      0.30      1920
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.73102679 0.70982143 0.68080357 0.72433036 0.71986607]
# Mean R^2 for Cross-Validation K-Fold: 0.7131696428571429
# accuracy
# 0.59375
#
# f1_macro
# 0.306482412327594
#
# precision
# 0.28570946975519906
#
# recall
# 0.33387276785714287
#
# confusion_matrix
# [[  0   0  68 111]
#  [  0   0   3  10]
#  [  0   0 539 101]
#  [  0   0 227 221]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.00      0.00      0.00       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.64      0.84      0.73       640
# Very_Mild_Demented       0.50      0.49      0.50       448
#
#           accuracy                           0.59      1280
#          macro avg       0.29      0.33      0.31      1280
#       weighted avg       0.50      0.59      0.54      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Criando o modelo SVM
model = SVC(gamma = "auto", random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.57254464 0.53794643 0.54575893 0.57589286 0.54799107]
# Mean R^2 for Cross-Validation K-Fold: 0.5560267857142858
# accuracy
# 0.509375
#
# f1_macro
# 0.18216487680200885
#
# precision
# 0.27471455412631884
#
# recall
# 0.25686383928571427
#
# confusion_matrix
# [[  0   0 172   7]
#  [  0   0  12   1]
#  [  0   0 639   1]
#  [  0   0 435  13]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.00      0.00      0.00       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.51      1.00      0.67       640
# Very_Mild_Demented       0.59      0.03      0.06       448
#
#           accuracy                           0.51      1280
#          macro avg       0.27      0.26      0.18      1280
#       weighted avg       0.46      0.51      0.36      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model = RandomForestClassifier(random_state = SEED, n_jobs=-1)
result_scores = cross_val_score(model, X_train_flatten, y_train, cv = k, scoring = 'accuracy', n_jobs = -1)

print("K-Fold (R^2) Scores: {0}".format(result_scores))
print("Mean R^2 for Cross-Validation K-Fold: {0}".format(result_scores.mean()))
# Out:
# K-Fold (R^2) Scores: [0.84486607 0.85714286 0.85491071 0.86607143 0.87053571]
# Mean R^2 for Cross-Validation K-Fold: 0.8587053571428571
