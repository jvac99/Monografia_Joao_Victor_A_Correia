# %%
import import_ipynb
from preprocessing import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 620,   45, 2240, 1575], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 620,   45, 2240, 1575], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([276,  19, 960, 665], dtype=int64))
# (array([0, 1, 2, 3]), array([276,  19, 960, 665], dtype=int64))
# Unique Values: [0 1 2 3]
# Frequency Values: [ 620   45 2240 1575]
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# **Validação Cruzada**

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.86272321 0.86607143 0.85825893 0.85267857 0.85379464]
# Mean R^2 for Cross-Validation K-Fold: 0.8587053571428571
# accuracy
# 0.7104166666666667
#
# f1_macro
# 0.5281309269273398
#
# precision
# 0.8312051494484635
#
# recall
# 0.4870974140514329
#
# confusion_matrix
# [[ 91   0  58 127]
#  [  1   2   8   8]
#  [  0   0 861  99]
#  [  3   0 252 410]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.96      0.33      0.49       276
#            1       1.00      0.11      0.19        19
#            2       0.73      0.90      0.81       960
#            3       0.64      0.62      0.63       665
#
#     accuracy                           0.71      1920
#    macro avg       0.83      0.49      0.53      1920
# weighted avg       0.73      0.71      0.69      1920

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = KNeighborsClassifier(n_jobs = -1)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.92857143 0.91294643 0.90736607 0.91741071 0.92410714]
# Mean R^2 for Cross-Validation K-Fold: 0.9180803571428573
# accuracy
# 0.7151041666666667
#
# f1_macro
# 0.6453403191854952
#
# precision
# 0.7407149134163469
#
# recall
# 0.601756599378882
#
# confusion_matrix
# [[153   0  58  65]
#  [  3   8   6   2]
#  [ 37   0 846  77]
#  [ 52   1 246 366]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.62      0.55      0.59       276
#            1       0.89      0.42      0.57        19
#            2       0.73      0.88      0.80       960
#            3       0.72      0.55      0.62       665
#
#     accuracy                           0.72      1920
#    macro avg       0.74      0.60      0.65      1920
# weighted avg       0.71      0.72      0.71      1920

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SGDClassifier(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.82254464 0.90290179 0.87834821 0.88950893 0.90625   ]
# Mean R^2 for Cross-Validation K-Fold: 0.8799107142857142
# accuracy
# 0.7473958333333334
#
# f1_macro
# 0.7318422695490723
#
# precision
# 0.7984729962706943
#
# recall
# 0.6929269505284952
#
# confusion_matrix
# [[167   0  62  47]
#  [  3  13   0   3]
#  [ 27   0 876  57]
#  [ 54   0 232 379]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.67      0.61      0.63       276
#            1       1.00      0.68      0.81        19
#            2       0.75      0.91      0.82       960
#            3       0.78      0.57      0.66       665
#
#     accuracy                           0.75      1920
#    macro avg       0.80      0.69      0.73      1920
# weighted avg       0.75      0.75      0.74      1920

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SGDClassifier(random_state = SEED, n_jobs = -1, early_stopping = True)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.75446429 0.78348214 0.67745536 0.75223214 0.57254464]
# Mean R^2 for Cross-Validation K-Fold: 0.7080357142857142
# accuracy
# 0.6223958333333334
#
# f1_macro
# 0.5223037212596708
#
# precision
# 0.7217362462221132
#
# recall
# 0.46993604936253675
#
# confusion_matrix
# [[ 85   0  92  99]
#  [  3   5   4   7]
#  [ 20   0 764 176]
#  [ 16   0 308 341]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.69      0.31      0.42       276
#            1       1.00      0.26      0.42        19
#            2       0.65      0.80      0.72       960
#            3       0.55      0.51      0.53       665
#
#     accuracy                           0.62      1920
#    macro avg       0.72      0.47      0.52      1920
# weighted avg       0.63      0.62      0.61      1920

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.86049107 0.88504464 0.86272321 0.85267857 0.88392857]
# Mean R^2 for Cross-Validation K-Fold: 0.8689732142857143
# accuracy
# 0.7729166666666667
#
# f1_macro
# 0.7590407775113368
#
# precision
# 0.81238515521381
#
# recall
# 0.7218928775743707
#
# confusion_matrix
# [[176   0  46  54]
#  [  3  13   0   3]
#  [ 27   0 826 107]
#  [ 45   0 151 469]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.70      0.64      0.67       276
#            1       1.00      0.68      0.81        19
#            2       0.81      0.86      0.83       960
#            3       0.74      0.71      0.72       665
#
#     accuracy                           0.77      1920
#    macro avg       0.81      0.72      0.76      1920
# weighted avg       0.77      0.77      0.77      1920

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.47879464 0.51339286 0.51785714 0.48995536 0.50334821]
# Mean R^2 for Cross-Validation K-Fold: 0.5006696428571429
# accuracy
# 0.5119791666666667
#
# f1_macro
# 0.3295840525004515
#
# precision
# 0.3333449828266251
#
# recall
# 0.3302025444044895
#
# confusion_matrix
# [[ 74   0  85 117]
#  [  3   0   7   9]
#  [ 60   0 680 220]
#  [ 89   0 347 229]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.33      0.27      0.29       276
#            1       0.00      0.00      0.00        19
#            2       0.61      0.71      0.65       960
#            3       0.40      0.34      0.37       665
#
#     accuracy                           0.51      1920
#    macro avg       0.33      0.33      0.33      1920
# weighted avg       0.49      0.51      0.50      1920
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.49107143 0.51116071 0.51116071 0.546875   0.48883929]
# Mean R^2 for Cross-Validation K-Fold: 0.5098214285714285
# accuracy
# 0.4817708333333333
#
# f1_macro
# 0.3205302035412533
#
# precision
# 0.32659326179035725
#
# recall
# 0.3649249652664269
#
# confusion_matrix
# [[170   2  48  56]
#  [  7   0   3   9]
#  [193   0 631 136]
#  [259   0 282 124]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.27      0.62      0.38       276
#            1       0.00      0.00      0.00        19
#            2       0.65      0.66      0.66       960
#            3       0.38      0.19      0.25       665
#
#     accuracy                           0.48      1920
#    macro avg       0.33      0.36      0.32      1920
# weighted avg       0.50      0.48      0.47      1920

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'rbf', random_state = SEED)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.68303571 0.72879464 0.7265625  0.72767857 0.70870536]
# Mean R^2 for Cross-Validation K-Fold: 0.7149553571428572
# accuracy
# 0.5953125
#
# f1_macro
# 0.31872671385090456
#
# precision
# 0.5357050619834711
#
# recall
# 0.34103746118012424
#
# confusion_matrix
# [[  6   0  88 182]
#  [  0   0   4  15]
#  [  0   0 795 165]
#  [  0   0 323 342]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.04       276
#            1       0.00      0.00      0.00        19
#            2       0.66      0.83      0.73       960
#            3       0.49      0.51      0.50       665
#
#     accuracy                           0.60      1920
#    macro avg       0.54      0.34      0.32      1920
# weighted avg       0.64      0.60      0.55      1920
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.95535714 0.95982143 0.94084821 0.94754464 0.96540179]
# Mean R^2 for Cross-Validation K-Fold: 0.9537946428571429
# accuracy
# 0.8182291666666667
#
# f1_macro
# 0.8261314951394987
#
# precision
# 0.8439791021397318
#
# recall
# 0.8129845673967528
#
# confusion_matrix
# [[216   0  30  30]
#  [  2  16   0   1]
#  [ 37   0 836  87]
#  [ 48   0 114 503]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.75       276
#            1       1.00      0.84      0.91        19
#            2       0.85      0.87      0.86       960
#            3       0.81      0.76      0.78       665
#
#     accuracy                           0.82      1920
#    macro avg       0.84      0.81      0.83      1920
# weighted avg       0.82      0.82      0.82      1920

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.875      0.88616071 0.88058036 0.88727679 0.875     ]
# Mean R^2 for Cross-Validation K-Fold: 0.8808035714285716
# accuracy
# 0.7395833333333334
#
# f1_macro
# 0.6746019372121888
#
# precision
# 0.7947819535566305
#
# recall
# 0.618853519668737
#
# confusion_matrix
# [[123   0  43 110]
#  [  2   9   0   8]
#  [ 24   0 824 112]
#  [ 21   0 180 464]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.72      0.45      0.55       276
#            1       1.00      0.47      0.64        19
#            2       0.79      0.86      0.82       960
#            3       0.67      0.70      0.68       665
#
#     accuracy                           0.74      1920
#    macro avg       0.79      0.62      0.67      1920
# weighted avg       0.74      0.74      0.73      1920

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.32700893 0.35379464 0.29464286 0.31473214 0.34486607]
# Mean R^2 for Cross-Validation K-Fold: 0.32700892857142855
# accuracy
# 0.32708333333333334
#
# f1_macro
# 0.16528399805386793
#
# precision
# 0.15749179833863053
#
# recall
# 0.17925281954887218
#
# confusion_matrix
# [[  0   0 263  13]
#  [  0   0  15   4]
#  [ 79   0 492 389]
#  [  1   0 528 136]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       276
#            1       0.00      0.00      0.00        19
#            2       0.38      0.51      0.44       960
#            3       0.25      0.20      0.23       665
#
#     accuracy                           0.33      1920
#    macro avg       0.16      0.18      0.17      1920
# weighted avg       0.28      0.33      0.30      1920
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", random_state = SEED)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.68303571 0.72879464 0.7265625  0.72767857 0.70870536]
# Mean R^2 for Cross-Validation K-Fold: 0.7149553571428572
# accuracy
# 0.5953125
#
# f1_macro
# 0.31872671385090456
#
# precision
# 0.5357050619834711
#
# recall
# 0.34103746118012424
#
# confusion_matrix
# [[  6   0  88 182]
#  [  0   0   4  15]
#  [  0   0 795 165]
#  [  0   0 323 342]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.04       276
#            1       0.00      0.00      0.00        19
#            2       0.66      0.83      0.73       960
#            3       0.49      0.51      0.50       665
#
#     accuracy                           0.60      1920
#    macro avg       0.54      0.34      0.32      1920
# weighted avg       0.64      0.60      0.55      1920
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Criando o modelo SVM
model = SVC(gamma = "auto", random_state = SEED)
metrics = kfold_application(model, k, X_train, y_train, X_test, y_test, SEED)
# Out:
# K-Fold (R^2) Scores: [0.54352679 0.5625     0.5625     0.56808036 0.5546875 ]
# Mean R^2 for Cross-Validation K-Fold: 0.5582589285714286
# accuracy
# 0.5213541666666667
#
# f1_macro
# 0.21386191215196854
#
# precision
# 0.2518819710625367
#
# recall
# 0.26887922932330827
#
# confusion_matrix
# [[  0   0 231  45]
#  [  0   0  18   1]
#  [  0   0 930  30]
#  [  0   0 594  71]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       276
#            1       0.00      0.00      0.00        19
#            2       0.52      0.97      0.68       960
#            3       0.48      0.11      0.17       665
#
#     accuracy                           0.52      1920
#    macro avg       0.25      0.27      0.21      1920
# weighted avg       0.43      0.52      0.40      1920
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model = RandomForestClassifier(random_state = SEED, n_jobs=-1)
result_scores = cross_val_score(model, X_train, y_train, cv = k, scoring = 'accuracy', n_jobs = -1)

print("K-Fold (R^2) Scores: {0}".format(result_scores))
print("Mean R^2 for Cross-Validation K-Fold: {0}".format(result_scores.mean()))
# Out:
# K-Fold (R^2) Scores: [0.85714286 0.84151786 0.86272321 0.84263393 0.87834821]
# Mean R^2 for Cross-Validation K-Fold: 0.8564732142857142
