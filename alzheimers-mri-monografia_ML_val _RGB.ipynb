# %%
import import_ipynb
from preprocessing_RGB import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# X:  6400
# X_train:  4480
# X_test:  1280
# X_val:  640
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 627,   45, 2240, 1568], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 627,   45, 2240, 1568], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# ...

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo
model = DecisionTreeClassifier(random_state = SEED)
metrics = model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.6953125
# accuracy
# 0.6953125
#
# f1_macro
# 0.5749456802267409
#
# precision
# 0.563742083625813
#
# recall
# 0.6047247023809523
#
# confusion_matrix
# [[ 42   0  21  27]
#  [  0   3   2   1]
#  [ 18   6 249  47]
#  [ 16   2  55 151]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5526    0.4667    0.5060        90
#  Moderate_Demented     0.2727    0.5000    0.3529         6
#       Non_Demented     0.7615    0.7781    0.7697       320
# Very_Mild_Demented     0.6681    0.6741    0.6711       224
#
#           accuracy                         0.6953       640
#          macro avg     0.5637    0.6047    0.5749       640
#       weighted avg     0.6949    0.6953    0.6942       640

# %%
# Criando o modelo
model = ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.6453125
# accuracy
# 0.6453125
#
# f1_macro
# 0.48870065337416596
#
# precision
# 0.48276454603580565
#
# recall
# 0.4966021825396826
#
# confusion_matrix
# [[ 43   1  25  21]
#  [  2   1   2   1]
#  [ 21   4 228  67]
#  [ 30   2  51 141]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.4479    0.4778    0.4624        90
#  Moderate_Demented     0.1250    0.1667    0.1429         6
#       Non_Demented     0.7451    0.7125    0.7284       320
# Very_Mild_Demented     0.6130    0.6295    0.6211       224
#
#           accuracy                         0.6453       640
#          macro avg     0.4828    0.4966    0.4887       640
#       weighted avg     0.6513    0.6453    0.6480       640
# {'accuracy': 0.6453125,
#  'f1_macro': 0.48870065337416596,
#  'precision': 0.48276454603580565,
#  'recall': 0.4966021825396826,
#  'confusion_matrix': array([[ 43,   1,  25,  21],
#         [  2,   1,   2,   1],
#         [ 21,   4, 228,  67],
# ...

# %%
# Criando o modelo de Random Forest
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.8734375
# accuracy
# 0.8734375
#
# f1_macro
# 0.6952857656950306
#
# precision
# 0.9322257188695544
#
# recall
# 0.6413814484126984
#
# confusion_matrix
# [[ 50   0  18  22]
#  [  0   1   2   3]
#  [  0   0 317   3]
#  [  0   0  33 191]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.5556    0.7143        90
#  Moderate_Demented     1.0000    0.1667    0.2857         6
#       Non_Demented     0.8568    0.9906    0.9188       320
# Very_Mild_Demented     0.8721    0.8527    0.8623       224
#
#           accuracy                         0.8734       640
#          macro avg     0.9322    0.6414    0.6953       640
#       weighted avg     0.8836    0.8734    0.8644       640
# {'accuracy': 0.8734375,
#  'f1_macro': 0.6952857656950306,
#  'precision': 0.9322257188695544,
#  'recall': 0.6413814484126984,
#  'confusion_matrix': array([[ 50,   0,  18,  22],
#         [  0,   1,   2,   3],
#         [  0,   0, 317,   3],
# ...

# %%
# Criando o modelo de Random Forest hiperparametros
model = RandomForestClassifier(random_state = SEED, n_jobs = -1, n_estimators = 250)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.884375
# accuracy
# 0.884375
#
# f1_macro
# 0.7614183542533766
#
# precision
# 0.9366453510838538
#
# recall
# 0.696391369047619
#
# confusion_matrix
# [[ 54   0  14  22]
#  [  0   2   1   3]
#  [  0   0 317   3]
#  [  0   0  31 193]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.6000    0.7500        90
#  Moderate_Demented     1.0000    0.3333    0.5000         6
#       Non_Demented     0.8733    0.9906    0.9283       320
# Very_Mild_Demented     0.8733    0.8616    0.8674       224
#
#           accuracy                         0.8844       640
#          macro avg     0.9366    0.6964    0.7614       640
#       weighted avg     0.8923    0.8844    0.8779       640
# {'accuracy': 0.884375,
#  'f1_macro': 0.7614183542533766,
#  'precision': 0.9366453510838538,
#  'recall': 0.696391369047619,
#  'confusion_matrix': array([[ 54,   0,  14,  22],
#         [  0,   2,   1,   3],
#         [  0,   0, 317,   3],
# ...

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.94375
# accuracy
# 0.94375
#
# f1_macro
# 0.9528219666137334
#
# precision
# 0.9595417303590894
#
# recall
# 0.9475322420634921
#
# confusion_matrix
# [[ 82   0   4   4]
#  [  0   6   0   0]
#  [  0   0 317   3]
#  [  5   0  20 199]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9425    0.9111    0.9266        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.9296    0.9906    0.9592       320
# Very_Mild_Demented     0.9660    0.8884    0.9256       224
#
#           accuracy                         0.9437       640
#          macro avg     0.9595    0.9475    0.9528       640
#       weighted avg     0.9448    0.9437    0.9432       640
# {'accuracy': 0.94375,
#  'f1_macro': 0.9528219666137334,
#  'precision': 0.9595417303590894,
#  'recall': 0.9475322420634921,
#  'confusion_matrix': array([[ 82,   0,   4,   4],
#         [  0,   6,   0,   0],
#         [  0,   0, 317,   3],
# ...

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.9234375
# accuracy
# 0.9234375
#
# f1_macro
# 0.9370364785627653
#
# precision
# 0.9453893802378349
#
# recall
# 0.9310391865079365
#
# confusion_matrix
# [[ 80   0   6   4]
#  [  0   6   0   0]
#  [  3   0 313   4]
#  [  4   0  28 192]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9195    0.8889    0.9040        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.9020    0.9781    0.9385       320
# Very_Mild_Demented     0.9600    0.8571    0.9057       224
#
#           accuracy                         0.9234       640
#          macro avg     0.9454    0.9310    0.9370       640
#       weighted avg     0.9257    0.9234    0.9227       640
# {'accuracy': 0.9234375,
#  'f1_macro': 0.9370364785627653,
#  'precision': 0.9453893802378349,
#  'recall': 0.9310391865079365,
#  'confusion_matrix': array([[ 80,   0,   6,   4],
#         [  0,   6,   0,   0],
#         [  3,   0, 313,   4],
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.865625
# accuracy
# 0.865625
#
# f1_macro
# 0.8941613455198031
#
# precision
# 0.8997912223575788
#
# recall
# 0.8891369047619048
#
# confusion_matrix
# [[ 75   0   7   8]
#  [  0   6   0   0]
#  [  4   0 290  26]
#  [  6   0  35 183]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8824    0.8333    0.8571        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.8735    0.9062    0.8896       320
# Very_Mild_Demented     0.8433    0.8170    0.8299       224
#
#           accuracy                         0.8656       640
#          macro avg     0.8998    0.8891    0.8942       640
#       weighted avg     0.8654    0.8656    0.8652       640
# {'accuracy': 0.865625,
#  'f1_macro': 0.8941613455198031,
#  'precision': 0.8997912223575788,
#  'recall': 0.8891369047619048,
#  'confusion_matrix': array([[ 75,   0,   7,   8],
#         [  0,   6,   0,   0],
#         [  4,   0, 290,  26],
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.45
# accuracy
# 0.45
#
# f1_macro
# 0.3030483238525991
#
# precision
# 0.30061804547653603
#
# recall
# 0.3222842261904762
#
# confusion_matrix
# [[ 39   0  28  23]
#  [  3   0   1   2]
#  [ 53   0 191  76]
#  [ 61   0 105  58]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2500    0.4333    0.3171        90
#  Moderate_Demented     0.0000    0.0000    0.0000         6
#       Non_Demented     0.5877    0.5969    0.5922       320
# Very_Mild_Demented     0.3648    0.2589    0.3029       224
#
#           accuracy                         0.4500       640
#          macro avg     0.3006    0.3223    0.3030       640
#       weighted avg     0.4567    0.4500    0.4467       640
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.503125
# accuracy
# 0.503125
#
# f1_macro
# 0.3790067696638163
#
# precision
# 0.36975125679008364
#
# recall
# 0.44892113095238095
#
# confusion_matrix
# [[ 48   3  11  28]
#  [  3   2   1   0]
#  [ 45   8 213  54]
#  [ 62  10  93  59]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3038    0.5333    0.3871        90
#  Moderate_Demented     0.0870    0.3333    0.1379         6
#       Non_Demented     0.6698    0.6656    0.6677       320
# Very_Mild_Demented     0.4184    0.2634    0.3233       224
#
#           accuracy                         0.5031       640
#          macro avg     0.3698    0.4489    0.3790       640
#       weighted avg     0.5249    0.5031    0.5027       640
# {'accuracy': 0.503125,
#  'f1_macro': 0.3790067696638163,
#  'precision': 0.36975125679008364,
#  'recall': 0.44892113095238095,
#  'confusion_matrix': array([[ 48,   3,  11,  28],
#         [  3,   2,   1,   0],
#         [ 45,   8, 213,  54],
# ...

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.7140625
# accuracy
# 0.7140625
#
# f1_macro
# 0.4610431001580184
#
# precision
# 0.5678699188870658
#
# recall
# 0.44883432539682533
#
# confusion_matrix
# [[ 22   0  24  44]
#  [  0   0   2   4]
#  [  1   0 292  27]
#  [  2   0  79 143]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8800    0.2444    0.3826        90
#  Moderate_Demented     0.0000    0.0000    0.0000         6
#       Non_Demented     0.7355    0.9125    0.8145       320
# Very_Mild_Demented     0.6560    0.6384    0.6471       224
#
#           accuracy                         0.7141       640
#          macro avg     0.5679    0.4488    0.4610       640
#       weighted avg     0.7211    0.7141    0.6875       640
# ...

# %%
# Criando o modelo SVM
model = SVC(class_weight = "balanced",  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.7203125
# accuracy
# 0.7203125
#
# f1_macro
# 0.7766096710289376
#
# precision
# 0.7661141058132586
#
# recall
# 0.812078373015873
#
# confusion_matrix
# [[ 79   0   5   6]
#  [  0   6   0   0]
#  [ 40   0 230  50]
#  [ 32   0  46 146]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5232    0.8778    0.6556        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.8185    0.7188    0.7654       320
# Very_Mild_Demented     0.7228    0.6518    0.6854       224
#
#           accuracy                         0.7203       640
#          macro avg     0.7661    0.8121    0.7766       640
#       weighted avg     0.7452    0.7203    0.7242       640
# {'accuracy': 0.7203125,
#  'f1_macro': 0.7766096710289376,
#  'precision': 0.7661141058132586,
#  'recall': 0.812078373015873,
#  'confusion_matrix': array([[ 79,   0,   5,   6],
#         [  0,   6,   0,   0],
#         [ 40,   0, 230,  50],
# ...

# %%
# Criando o modelo SVM
model = SVC(gamma = "auto", class_weight = "balanced",  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.5390625
# accuracy
# 0.5390625
#
# f1_macro
# 0.6219645549996478
#
# precision
# 0.6244044266635593
#
# recall
# 0.6570808531746032
#
# confusion_matrix
# [[ 59   0   9  22]
#  [  0   6   0   0]
#  [ 57   0 207  56]
#  [ 70   0  81  73]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3172    0.6556    0.4275        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.6970    0.6469    0.6710       320
# Very_Mild_Demented     0.4834    0.3259    0.3893       224
#
#           accuracy                         0.5391       640
#          macro avg     0.6244    0.6571    0.6220       640
#       weighted avg     0.5717    0.5391    0.5413       640
# {'accuracy': 0.5390625,
#  'f1_macro': 0.6219645549996478,
#  'precision': 0.6244044266635593,
#  'recall': 0.6570808531746032,
#  'confusion_matrix': array([[ 59,   0,   9,  22],
#         [  0,   6,   0,   0],
#         [ 57,   0, 207,  56],
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.9734375
# accuracy
# 0.9734375
#
# f1_macro
# 0.9760285838645202
#
# precision
# 0.9826451015475406
#
# recall
# 0.9700644841269842
#
# confusion_matrix
# [[ 83   0   3   4]
#  [  0   6   0   0]
#  [  0   0 318   2]
#  [  1   0   7 216]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9881    0.9222    0.9540        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.9695    0.9938    0.9815       320
# Very_Mild_Demented     0.9730    0.9643    0.9686       224
#
#           accuracy                         0.9734       640
#          macro avg     0.9826    0.9701    0.9760       640
#       weighted avg     0.9736    0.9734    0.9733       640
# {'accuracy': 0.9734375,
#  'f1_macro': 0.9760285838645202,
#  'precision': 0.9826451015475406,
#  'recall': 0.9700644841269842,
#  'confusion_matrix': array([[ 83,   0,   3,   4],
#         [  0,   6,   0,   0],
#         [  0,   0, 318,   2],
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.8765625
# accuracy
# 0.8765625
#
# f1_macro
# 0.8960585187801718
#
# precision
# 0.9262114713128556
#
# recall
# 0.8766493055555555
#
# confusion_matrix
# [[ 65   0  10  15]
#  [  0   6   0   0]
#  [  0   0 301  19]
#  [  1   0  34 189]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9848    0.7222    0.8333        90
#  Moderate_Demented     1.0000    1.0000    1.0000         6
#       Non_Demented     0.8725    0.9406    0.9053       320
# Very_Mild_Demented     0.8475    0.8438    0.8456       224
#
#           accuracy                         0.8766       640
#          macro avg     0.9262    0.8766    0.8961       640
#       weighted avg     0.8807    0.8766    0.8752       640
# {'accuracy': 0.8765625,
#  'f1_macro': 0.8960585187801718,
#  'precision': 0.9262114713128556,
#  'recall': 0.8766493055555555,
#  'confusion_matrix': array([[ 65,   0,  10,  15],
#         [  0,   6,   0,   0],
#         [  0,   0, 301,  19],
# ...

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.321875
# accuracy
# 0.321875
#
# f1_macro
# 0.2302079864986067
#
# precision
# 0.2296995078449947
#
# recall
# 0.23091517857142857
#
# confusion_matrix
# [[ 27   0  62   1]
#  [  2   0   2   2]
#  [ 25   0 131 164]
#  [ 34   0 142  48]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3068    0.3000    0.3034        90
#  Moderate_Demented     0.0000    0.0000    0.0000         6
#       Non_Demented     0.3887    0.4094    0.3988       320
# Very_Mild_Demented     0.2233    0.2143    0.2187       224
#
#           accuracy                         0.3219       640
#          macro avg     0.2297    0.2309    0.2302       640
#       weighted avg     0.3156    0.3219    0.3186       640
# ...

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
# Out:
# 0.953125
# accuracy
# 0.953125
#
# f1_macro
# 0.9100482746290006
#
# precision
# 0.9713538556538733
#
# recall
# 0.8674727182539683
#
# confusion_matrix
# [[ 79   0   3   8]
#  [  0   4   1   1]
#  [  0   0 319   1]
#  [  1   0  15 208]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9875    0.8778    0.9294        90
#  Moderate_Demented     1.0000    0.6667    0.8000         6
#       Non_Demented     0.9438    0.9969    0.9696       320
# Very_Mild_Demented     0.9541    0.9286    0.9412       224
#
#           accuracy                         0.9531       640
#          macro avg     0.9714    0.8675    0.9100       640
#       weighted avg     0.9541    0.9531    0.9524       640
# {'accuracy': 0.953125,
#  'f1_macro': 0.9100482746290006,
#  'precision': 0.9713538556538733,
#  'recall': 0.8674727182539683,
#  'confusion_matrix': array([[ 79,   0,   3,   8],
#         [  0,   4,   1,   1],
#         [  0,   0, 319,   1],
# ...

# %%
# Criando modelo Gradient Boosting
model = GradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED, n_estimators = 400)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)

# %%
# Criando modelo Gradient Boosting
model = HistGradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)

# %%
# Criando modelo Gradient Boosting
model = LinearDiscriminantAnalysis()
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)

# %%
# Criando modelo Gradient Boosting
model = DummyClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_val_flatten, y_val, target_names)
