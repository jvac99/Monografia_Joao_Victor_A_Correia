# %%
import import_ipynb
from preprocessing import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# X:  6400
# X_train:  4480
# X_test:  1280
# X_val:  640
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 627,   45, 2240, 1568], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 627,   45, 2240, 1568], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# Unique Values: [0 1 2 3]
# Frequency Values: [ 627   45 2240 1568]
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo
model = DecisionTreeClassifier(random_state = SEED)
metrics = model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.7
# accuracy
# 0.7
#
# f1_macro
# 0.6409233257697249
#
# precision
# 0.668860774857628
#
# recall
# 0.6194608180750814
#
# confusion_matrix
# [[ 87   1  41  50]
#  [  1   7   3   2]
#  [ 31   1 503 105]
#  [ 38   1 110 299]]
#
# classification_report
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5541    0.4860    0.5179       179
#  Moderate_Demented     0.7000    0.5385    0.6087        13
#       Non_Demented     0.7656    0.7859    0.7756       640
# Very_Mild_Demented     0.6557    0.6674    0.6615       448
#
#           accuracy                         0.7000      1280
#          macro avg     0.6689    0.6195    0.6409      1280
#       weighted avg     0.6969    0.7000    0.6979      1280
#
#
# <class 'str'>

# %%
# Criando o modelo
model = ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.64453125
# accuracy
# 0.64453125
#
# f1_macro
# 0.5772395484809638
#
# precision
# 0.5658983409186976
#
# recall
# 0.5913978566824237
#
# confusion_matrix
# [[ 91   2  35  51]
#  [  1   7   3   2]
#  [ 47   0 454 139]
#  [ 41   7 127 273]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5056    0.5084    0.5070       179
#  Moderate_Demented     0.4375    0.5385    0.4828        13
#       Non_Demented     0.7334    0.7094    0.7212       640
# Very_Mild_Demented     0.5871    0.6094    0.5980       448
#
#           accuracy                         0.6445      1280
#          macro avg     0.5659    0.5914    0.5772      1280
#       weighted avg     0.6473    0.6445    0.6457      1280
# {'accuracy': 0.64453125,
#  'f1_macro': 0.5772395484809638,
#  'precision': 0.5658983409186976,
#  'recall': 0.5913978566824237,
#  'confusion_matrix': array([[ 91,   2,  35,  51],
#         [  1,   7,   3,   2],
#         [ 47,   0, 454, 139],
#         [ 41,   7, 127, 273]], dtype=int64)}

# %%
# Criando o modelo de Random Forest
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.88984375
# accuracy
# 0.88984375
#
# f1_macro
# 0.7733220986098241
#
# precision
# 0.9376599610974612
#
# recall
# 0.7135065266437473
#
# confusion_matrix
# [[128   0  15  36]
#  [  0   4   4   5]
#  [  0   0 622  18]
#  [  0   0  63 385]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.7151    0.8339       179
#  Moderate_Demented     1.0000    0.3077    0.4706        13
#       Non_Demented     0.8835    0.9719    0.9256       640
# Very_Mild_Demented     0.8671    0.8594    0.8632       448
#
#           accuracy                         0.8898      1280
#          macro avg     0.9377    0.7135    0.7733      1280
#       weighted avg     0.8953    0.8898    0.8863      1280
# {'accuracy': 0.88984375,
#  'f1_macro': 0.7733220986098241,
#  'precision': 0.9376599610974612,
#  'recall': 0.7135065266437473,
#  'confusion_matrix': array([[128,   0,  15,  36],
#         [  0,   4,   4,   5],
#         [  0,   0, 622,  18],
#         [  0,   0,  63, 385]], dtype=int64)}

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.95546875
# accuracy
# 0.95546875
#
# f1_macro
# 0.9523937843824881
#
# precision
# 0.9503267617411538
#
# recall
# 0.9557770725259378
#
# confusion_matrix
# [[162   0   9   8]
#  [  0  13   0   0]
#  [  3   1 629   7]
#  [  4   0  25 419]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9586    0.9050    0.9310       179
#  Moderate_Demented     0.9286    1.0000    0.9630        13
#       Non_Demented     0.9487    0.9828    0.9655       640
# Very_Mild_Demented     0.9654    0.9353    0.9501       448
#
#           accuracy                         0.9555      1280
#          macro avg     0.9503    0.9558    0.9524      1280
#       weighted avg     0.9557    0.9555    0.9553      1280
# {'accuracy': 0.95546875,
#  'f1_macro': 0.9523937843824881,
#  'precision': 0.9503267617411538,
#  'recall': 0.9557770725259378,
#  'confusion_matrix': array([[162,   0,   9,   8],
#         [  0,  13,   0,   0],
#         [  3,   1, 629,   7],
#         [  4,   0,  25, 419]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.921875
# accuracy
# 0.921875
#
# f1_macro
# 0.908089014380753
#
# precision
# 0.9502177339503304
#
# recall
# 0.8750890171281233
#
# confusion_matrix
# [[159   0   8  12]
#  [  0  10   1   2]
#  [  3   0 618  19]
#  [  2   0  53 393]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9695    0.8883    0.9271       179
#  Moderate_Demented     1.0000    0.7692    0.8696        13
#       Non_Demented     0.9088    0.9656    0.9364       640
# Very_Mild_Demented     0.9225    0.8772    0.8993       448
#
#           accuracy                         0.9219      1280
#          macro avg     0.9502    0.8751    0.9081      1280
#       weighted avg     0.9230    0.9219    0.9214      1280
# {'accuracy': 0.921875,
#  'f1_macro': 0.908089014380753,
#  'precision': 0.9502177339503304,
#  'recall': 0.8750890171281233,
#  'confusion_matrix': array([[159,   0,   8,  12],
#         [  0,  10,   1,   2],
#         [  3,   0, 618,  19],
#         [  2,   0,  53, 393]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1, early_stopping = True)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.7671875
# accuracy
# 0.7671875
#
# f1_macro
# 0.6936307985573427
#
# precision
# 0.6904700893570911
#
# recall
# 0.8226250748204309
#
# confusion_matrix
# [[159   3  15   2]
#  [  0  13   0   0]
#  [ 26   3 606   5]
#  [ 77  13 154 204]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.6069    0.8883    0.7211       179
#  Moderate_Demented     0.4062    1.0000    0.5778        13
#       Non_Demented     0.7819    0.9469    0.8565       640
# Very_Mild_Demented     0.9668    0.4554    0.6191       448
#
#           accuracy                         0.7672      1280
#          macro avg     0.6905    0.8226    0.6936      1280
#       weighted avg     0.8183    0.7672    0.7517      1280
# {'accuracy': 0.7671875,
#  'f1_macro': 0.6936307985573427,
#  'precision': 0.6904700893570911,
#  'recall': 0.8226250748204309,
#  'confusion_matrix': array([[159,   3,  15,   2],
#         [  0,  13,   0,   0],
#         [ 26,   3, 606,   5],
#         [ 77,  13, 154, 204]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.88125
# accuracy
# 0.88125
#
# f1_macro
# 0.8811101538451045
#
# precision
# 0.9130580693815987
#
# recall
# 0.8545037822687089
#
# confusion_matrix
# [[141   0  17  21]
#  [  0  11   0   2]
#  [ 11   0 589  40]
#  [  4   0  57 387]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9038    0.7877    0.8418       179
#  Moderate_Demented     1.0000    0.8462    0.9167        13
#       Non_Demented     0.8884    0.9203    0.9041       640
# Very_Mild_Demented     0.8600    0.8638    0.8619       448
#
#           accuracy                         0.8812      1280
#          macro avg     0.9131    0.8545    0.8811      1280
#       weighted avg     0.8817    0.8812    0.8807      1280
# {'accuracy': 0.88125,
#  'f1_macro': 0.8811101538451045,
#  'precision': 0.9130580693815987,
#  'recall': 0.8545037822687089,
#  'confusion_matrix': array([[141,   0,  17,  21],
#         [  0,  11,   0,   2],
#         [ 11,   0, 589,  40],
#         [  4,   0,  57, 387]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.48828125
# accuracy
# 0.48828125
#
# f1_macro
# 0.3317116756916127
#
# precision
# 0.3301918956911944
#
# recall
# 0.3552726581205108
#
# confusion_matrix
# [[ 89   0  39  51]
#  [  6   0   2   5]
#  [107   0 407 126]
#  [124   0 195 129]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2730    0.4972    0.3525       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.6330    0.6359    0.6345       640
# Very_Mild_Demented     0.4148    0.2879    0.3399       448
#
#           accuracy                         0.4883      1280
#          macro avg     0.3302    0.3553    0.3317      1280
#       weighted avg     0.4998    0.4883    0.4855      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.48828125,
#  'f1_macro': 0.3317116756916127,
#  'precision': 0.3301918956911944,
#  'recall': 0.3552726581205108,
#  'confusion_matrix': array([[ 89,   0,  39,  51],
#         [  6,   0,   2,   5],
#         [107,   0, 407, 126],
#         [124,   0, 195, 129]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.5234375
# accuracy
# 0.5234375
#
# f1_macro
# 0.42342225744691303
#
# precision
# 0.4053381960479654
#
# recall
# 0.5502897373227331
#
# confusion_matrix
# [[ 95  13  18  53]
#  [  4   9   0   0]
#  [ 92  17 426 105]
#  [109  21 178 140]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3167    0.5307    0.3967       179
#  Moderate_Demented     0.1500    0.6923    0.2466        13
#       Non_Demented     0.6849    0.6656    0.6751       640
# Very_Mild_Demented     0.4698    0.3125    0.3753       448
#
#           accuracy                         0.5234      1280
#          macro avg     0.4053    0.5503    0.4234      1280
#       weighted avg     0.5527    0.5234    0.5269      1280
# {'accuracy': 0.5234375,
#  'f1_macro': 0.42342225744691303,
#  'precision': 0.4053381960479654,
#  'recall': 0.5502897373227331,
#  'confusion_matrix': array([[ 95,  13,  18,  53],
#         [  4,   9,   0,   0],
#         [ 92,  17, 426, 105],
#         [109,  21, 178, 140]], dtype=int64)}

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.7453125
# accuracy
# 0.7453125
#
# f1_macro
# 0.4936998549449191
#
# precision
# 0.5876074225947914
#
# recall
# 0.4787098463687151
#
# confusion_matrix
# [[ 53   0  35  91]
#  [  0   0   2  11]
#  [  5   0 586  49]
#  [  1   0 132 315]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8983    0.2961    0.4454       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.7762    0.9156    0.8401       640
# Very_Mild_Demented     0.6760    0.7031    0.6893       448
#
#           accuracy                         0.7453      1280
#          macro avg     0.5876    0.4787    0.4937      1280
#       weighted avg     0.7503    0.7453    0.7236      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.7453125,
#  'f1_macro': 0.4936998549449191,
#  'precision': 0.5876074225947914,
#  'recall': 0.4787098463687151,
#  'confusion_matrix': array([[ 53,   0,  35,  91],
#         [  0,   0,   2,  11],
#         [  5,   0, 586,  49],
#         [  1,   0, 132, 315]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(class_weight = "balanced",  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[1], line 2
#
#       1 # Criando o modelo SVM
#
# ----> 2 model = SVC(gamma = "scale", class_weight = "balanced",  random_state = SEED)
#
#       3 model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
#
#
#
# NameError: name 'SVC' is not defined

# %%
# Criando o modelo SVM
model = SVC(gamma = "auto", class_weight = "balanced",  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9751782471391962
#
# precision
# 0.9753001200480192
#
# recall
# 0.9751006958300081
#
# confusion_matrix
# [[172   0   6   1]
#  [  0  13   0   0]
#  [  3   0 627  10]
#  [  5   0  13 430]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9556    0.9609    0.9582       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9706    0.9797    0.9751       640
# Very_Mild_Demented     0.9751    0.9598    0.9674       448
#
#           accuracy                         0.9703      1280
#          macro avg     0.9753    0.9751    0.9752      1280
#       weighted avg     0.9703    0.9703    0.9703      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9751782471391962,
#  'precision': 0.9753001200480192,
#  'recall': 0.9751006958300081,
#  'confusion_matrix': array([[172,   0,   6,   1],
#         [  0,  13,   0,   0],
#         [  3,   0, 627,  10],
#         [  5,   0,  13, 430]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.91015625
# accuracy
# 0.91015625
#
# f1_macro
# 0.9227595741042577
#
# precision
# 0.9432957097514689
#
# recall
# 0.9076416600159617
#
# confusion_matrix
# [[141   0  14  24]
#  [  0  13   0   0]
#  [  1   0 618  21]
#  [  3   0  52 393]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9724    0.7877    0.8704       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9035    0.9656    0.9335       640
# Very_Mild_Demented     0.8973    0.8772    0.8871       448
#
#           accuracy                         0.9102      1280
#          macro avg     0.9433    0.9076    0.9228      1280
#       weighted avg     0.9119    0.9102    0.9091      1280
# {'accuracy': 0.91015625,
#  'f1_macro': 0.9227595741042577,
#  'precision': 0.9432957097514689,
#  'recall': 0.9076416600159617,
#  'confusion_matrix': array([[141,   0,  14,  24],
#         [  0,  13,   0,   0],
#         [  1,   0, 618,  21],
#         [  3,   0,  52, 393]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.35625
# accuracy
# 0.35625
#
# f1_macro
# 0.251124082615516
#
# precision
# 0.2506253496179749
#
# recall
# 0.2516978002793296
#
# confusion_matrix
# [[ 51   0 120   8]
#  [  3   0   7   3]
#  [ 46   0 272 322]
#  [ 75   0 240 133]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2914    0.2849    0.2881       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.4257    0.4250    0.4253       640
# Very_Mild_Demented     0.2854    0.2969    0.2910       448
#
#           accuracy                         0.3563      1280
#          macro avg     0.2506    0.2517    0.2511      1280
#       weighted avg     0.3535    0.3563    0.3548      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.35625,
#  'f1_macro': 0.251124082615516,
#  'precision': 0.2506253496179749,
#  'recall': 0.2516978002793296,
#  'confusion_matrix': array([[ 51,   0, 120,   8],
#         [  3,   0,   7,   3],
#         [ 46,   0, 272, 322],
#         [ 75,   0, 240, 133]], dtype=int64)}

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9578125
# accuracy
# 0.9578125
#
# f1_macro
# 0.9197703235021888
#
# precision
# 0.9746193769719854
#
# recall
# 0.8804133780849039
#
# confusion_matrix
# [[160   0   7  12]
#  [  0   9   2   2]
#  [  0   0 633   7]
#  [  1   0  23 424]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9938    0.8939    0.9412       179
#  Moderate_Demented     1.0000    0.6923    0.8182        13
#       Non_Demented     0.9519    0.9891    0.9701       640
# Very_Mild_Demented     0.9528    0.9464    0.9496       448
#
#           accuracy                         0.9578      1280
#          macro avg     0.9746    0.8804    0.9198      1280
#       weighted avg     0.9586    0.9578    0.9573      1280
# {'accuracy': 0.9578125,
#  'f1_macro': 0.9197703235021888,
#  'precision': 0.9746193769719854,
#  'recall': 0.8804133780849039,
#  'confusion_matrix': array([[160,   0,   7,  12],
#         [  0,   9,   2,   2],
#         [  0,   0, 633,   7],
#         [  1,   0,  23, 424]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = GradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.57890625
# accuracy
# 0.57890625
#
# f1_macro
# 0.5044799911228397
#
# precision
# 0.6386096113301423
#
# recall
# 0.4577148497452268
#
# confusion_matrix
# [[ 42   0  66  71]
#  [  1   5   3   4]
#  [ 28   0 504 108]
#  [ 30   0 228 190]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.4158    0.2346    0.3000       179
#  Moderate_Demented     1.0000    0.3846    0.5556        13
#       Non_Demented     0.6292    0.7875    0.6995       640
# Very_Mild_Demented     0.5094    0.4241    0.4629       448
#
#           accuracy                         0.5789      1280
#          macro avg     0.6386    0.4577    0.5045      1280
#       weighted avg     0.5612    0.5789    0.5594      1280
# {'accuracy': 0.57890625,
#  'f1_macro': 0.5044799911228397,
#  'precision': 0.6386096113301423,
#  'recall': 0.4577148497452268,
#  'confusion_matrix': array([[ 42,   0,  66,  71],
#         [  1,   5,   3,   4],
#         [ 28,   0, 504, 108],
#         [ 30,   0, 228, 190]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = HistGradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96640625
# accuracy
# 0.96640625
#
# f1_macro
# 0.9247670239259262
#
# precision
# 0.9800774607340359
#
# recall
# 0.8852109264687826
#
# confusion_matrix
# [[159   0   6  14]
#  [  0   9   1   3]
#  [  0   0 636   4]
#  [  0   0  15 433]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.8883    0.9408       179
#  Moderate_Demented     1.0000    0.6923    0.8182        13
#       Non_Demented     0.9666    0.9938    0.9800       640
# Very_Mild_Demented     0.9537    0.9665    0.9601       448
#
#           accuracy                         0.9664      1280
#          macro avg     0.9801    0.8852    0.9248      1280
#       weighted avg     0.9671    0.9664    0.9659      1280
# {'accuracy': 0.96640625,
#  'f1_macro': 0.9247670239259262,
#  'precision': 0.9800774607340359,
#  'recall': 0.8852109264687826,
#  'confusion_matrix': array([[159,   0,   6,  14],
#         [  0,   9,   1,   3],
#         [  0,   0, 636,   4],
#         [  0,   0,  15, 433]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = LinearDiscriminantAnalysis()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.83515625
# accuracy
# 0.83515625
#
# f1_macro
# 0.8747940575409934
#
# precision
# 0.8799555540840233
#
# recall
# 0.8704842752394254
#
# confusion_matrix
# [[146   0  13  20]
#  [  0  13   0   0]
#  [ 10   0 545  85]
#  [ 10   0  73 365]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8795    0.8156    0.8464       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8637    0.8516    0.8576       640
# Very_Mild_Demented     0.7766    0.8147    0.7952       448
#
#           accuracy                         0.8352      1280
#          macro avg     0.8800    0.8705    0.8748      1280
#       weighted avg     0.8368    0.8352    0.8356      1280
# {'accuracy': 0.83515625,
#  'f1_macro': 0.8747940575409934,
#  'precision': 0.8799555540840233,
#  'recall': 0.8704842752394254,
#  'confusion_matrix': array([[146,   0,  13,  20],
#         [  0,  13,   0,   0],
#         [ 10,   0, 545,  85],
#         [ 10,   0,  73, 365]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = DummyClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.5
# accuracy
# 0.5
#
# f1_macro
# 0.16666666666666666
#
# precision
# 0.125
#
# recall
# 0.25
#
# confusion_matrix
# [[  0   0 179   0]
#  [  0   0  13   0]
#  [  0   0 640   0]
#  [  0   0 448   0]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.0000    0.0000    0.0000       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.5000    1.0000    0.6667       640
# Very_Mild_Demented     0.0000    0.0000    0.0000       448
#
#           accuracy                         0.5000      1280
#          macro avg     0.1250    0.2500    0.1667      1280
#       weighted avg     0.2500    0.5000    0.3333      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.5,
#  'f1_macro': 0.16666666666666666,
#  'precision': 0.125,
#  'recall': 0.25,
#  'confusion_matrix': array([[  0,   0, 179,   0],
#         [  0,   0,  13,   0],
#         [  0,   0, 640,   0],
#         [  0,   0, 448,   0]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = RidgeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96953125
# accuracy
# 0.96953125
#
# f1_macro
# 0.9715730984474658
#
# precision
# 0.976742562038247
#
# recall
# 0.9668292971867518
#
# confusion_matrix
# [[164   0   6   9]
#  [  0  13   0   0]
#  [  0   0 633   7]
#  [  5   0  12 431]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9704    0.9162    0.9425       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9724    0.9891    0.9806       640
# Very_Mild_Demented     0.9642    0.9621    0.9631       448
#
#           accuracy                         0.9695      1280
#          macro avg     0.9767    0.9668    0.9716      1280
#       weighted avg     0.9695    0.9695    0.9694      1280
# {'accuracy': 0.96953125,
#  'f1_macro': 0.9715730984474658,
#  'precision': 0.976742562038247,
#  'recall': 0.9668292971867518,
#  'confusion_matrix': array([[164,   0,   6,   9],
#         [  0,  13,   0,   0],
#         [  0,   0, 633,   7],
#         [  5,   0,  12, 431]], dtype=int64)}
