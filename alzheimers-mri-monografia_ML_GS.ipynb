# %%
import import_ipynb
from preprocessing import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# X:  6400
# X_train:  4480
# X_test:  1280
# X_val:  640
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 627,   45, 2240, 1568], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 627,   45, 2240, 1568], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# Unique Values: [0 1 2 3]
# Frequency Values: [ 627   45 2240 1568]
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# #### 4. Seleção de modelos de ML e DL.

# %%
# Crie uma instância do modelo
#  criterion = 'entropy', max_features = 'auto', min_samples_leaf = 1
model = DecisionTreeClassifier(random_state = SEED, min_samples_leaf = 1)

# Defina a grade de hiperparâmetros

param_grid = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [15, 20],
    'min_samples_split': [2, 5, 6],
    'min_samples_leaf': [1, 2, 4],
}

grid_search_application(model, X_train_flatten, y_train, X_test_flatten, y_test, k, param_grid, target_names)
# Out:
# accuracy
# 0.70546875
#
# f1_macro
# 0.628132244420698
#
# precision
# 0.6510249469557693
#
# recall
# 0.6107289140677759
#
# confusion_matrix
# [[ 92   1  36  50]
#  [  1   6   2   4]
#  [ 39   1 492 108]
#  [ 30   2 103 313]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5679    0.5140    0.5396       179
#  Moderate_Demented     0.6000    0.4615    0.5217        13
#       Non_Demented     0.7773    0.7688    0.7730       640
# Very_Mild_Demented     0.6589    0.6987    0.6782       448
#
#           accuracy                         0.7055      1280
#          macro avg     0.6510    0.6107    0.6281      1280
#       weighted avg     0.7048    0.7055    0.7046      1280
# {'metrics': {'accuracy': 0.70546875,
#   'f1_macro': 0.628132244420698,
#   'precision': 0.6510249469557693,
#   'recall': 0.6107289140677759,
#   'confusion_matrix': array([[ 92,   1,  36,  50],
#          [  1,   6,   2,   4],
#          [ 39,   1, 492, 108],
#          [ 30,   2, 103, 313]], dtype=int64)},
#  'best_params': {'criterion': 'entropy',
#   'max_depth': 15,
#   'min_samples_leaf': 1,
#   'min_samples_split': 2},
#  'best_estimator': DecisionTreeClassifier(criterion='entropy', max_depth=15, random_state=42)}

# %%
# Crie uma instância do modelo
model = ExtraTreeClassifier(random_state = SEED, criterion = 'entropy', max_features = 'auto', min_samples_leaf = 1)

# Defina a grade de hiperparâmetros

param_grid = {
    #'min_samples_leaf': [1, 2, 3, 4],
    #'criterion': ['gini', 'entropy', 'log_loss'],
    #'max_features': ['auto', 'sqrt', 'log2'],
}

grid_search_application(model, X_train_flatten, y_train, X_test_flatten, y_test, k, param_grid, target_names)
# Out:
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# accuracy
# 0.65390625
#
# f1_macro
# 0.5712195920344003
#
# precision
# 0.5891620590834366
#
# recall
# 0.5572331932208853
#
# confusion_matrix
# [[ 91   1  35  52]
#  [  1   5   4   3]
#  [ 30   3 475 132]
#  [ 48   1 133 266]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5353    0.5084    0.5215       179
#  Moderate_Demented     0.5000    0.3846    0.4348        13
#       Non_Demented     0.7342    0.7422    0.7382       640
# Very_Mild_Demented     0.5872    0.5938    0.5905       448
#
#           accuracy                         0.6539      1280
#          macro avg     0.5892    0.5572    0.5712      1280
#       weighted avg     0.6525    0.6539    0.6531      1280
# {'metrics': {'accuracy': 0.65390625,
#   'f1_macro': 0.5712195920344003,
#   'precision': 0.5891620590834366,
#   'recall': 0.5572331932208853,
#   'confusion_matrix': array([[ 91,   1,  35,  52],
#          [  1,   5,   4,   3],
#          [ 30,   3, 475, 132],
#          [ 48,   1, 133, 266]], dtype=int64)},
#  'best_params': {'min_samples_leaf': 1},
#  'best_estimator': ExtraTreeClassifier(criterion='entropy', max_features='auto', random_state=42)}

# %%
# Crie uma instância do modelo
model = RandomForestClassifier(random_state = SEED, n_jobs=-1, criterion = 'entropy', n_estimators = 250, min_samples_leaf = 1, max_features = 'auto',
  min_samples_split =  2)

# Defina a grade de hiperparâmetros

param_grid = {
    'n_estimators': [200, 250, 300],
    #'max_depth': [None, 5],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_features': ['auto', 'sqrt', 'log2'],
}

grid_search_application(model, X_train_flatten, y_train, X_test_flatten, y_test, k, param_grid, target_names)
# Out:
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# accuracy
# 0.915625
#
# f1_macro
# 0.8678626191830062
#
# precision
# 0.9550770308123249
#
# recall
# 0.812822423299466
#
# confusion_matrix
# [[138   0  20  21]
#  [  0   8   2   3]
#  [  0   0 635   5]
#  [  0   0  57 391]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.7709    0.8707       179
#  Moderate_Demented     1.0000    0.6154    0.7619        13
#       Non_Demented     0.8894    0.9922    0.9380       640
# Very_Mild_Demented     0.9310    0.8728    0.9009       448
#
#           accuracy                         0.9156      1280
#          macro avg     0.9551    0.8128    0.8679      1280
#       weighted avg     0.9205    0.9156    0.9138      1280
# {'metrics': {'accuracy': 0.915625,
#   'f1_macro': 0.8678626191830062,
#   'precision': 0.9550770308123249,
#   'recall': 0.812822423299466,
#   'confusion_matrix': array([[138,   0,  20,  21],
#          [  0,   8,   2,   3],
#          [  0,   0, 635,   5],
#          [  0,   0,  57, 391]], dtype=int64)},
#  'best_params': {},
#  'best_estimator': RandomForestClassifier(criterion='entropy', max_features='auto',
#                         n_estimators=250, n_jobs=-1, random_state=42)}

# %%
# Crie uma instância do modelo
model = SVC()

# Defina a grade de hiperparâmetros
param_grid = {
    #'C': [0.1, 1, 10], 
    'C': [20, 30], 
    #'kernel': ['linear', 'rbf', 'poly', 'sigmoid'], 
    #'gamma': ['scale', 'auto'],
    #'class_weight': [ 'balanced', 'dict ', None], 
    }

grid_search_application(model, X_train_flatten, y_train, X_test_flatten, y_test, k, param_grid, target_names)
# Out:
# accuracy
# 0.99140625
#
# f1_macro
# 0.9921616240064969
#
# precision
# 0.9933366737054061
#
# recall
# 0.9910093899640862
#
# confusion_matrix
# [[175   0   4   0]
#  [  0  13   0   0]
#  [  1   0 637   2]
#  [  1   0   3 444]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9887    0.9777    0.9831       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9891    0.9953    0.9922       640
# Very_Mild_Demented     0.9955    0.9911    0.9933       448
#
#           accuracy                         0.9914      1280
#          macro avg     0.9933    0.9910    0.9922      1280
#       weighted avg     0.9914    0.9914    0.9914      1280
# {'metrics': {'accuracy': 0.99140625,
#   'f1_macro': 0.9921616240064969,
#   'precision': 0.9933366737054061,
#   'recall': 0.9910093899640862,
#   'confusion_matrix': array([[175,   0,   4,   0],
#          [  0,  13,   0,   0],
#          [  1,   0, 637,   2],
#          [  1,   0,   3, 444]], dtype=int64)},
#  'best_params': {'C': 30},
#  'best_estimator': SVC(C=30)}

# %%
# Crie uma instância do modelo
model = AdaBoostClassifier(random_state = SEED)

# Defina a grade de hiperparâmetros

param_grid = {
    'n_estimators': [400, 450],
    'learning_rate':[1, 2]
}

grid_search_application(model, X_train_flatten, y_train, X_test_flatten, y_test, k, param_grid, target_names)
# Out:
# accuracy
# 0.559375
#
# f1_macro
# 0.5015893177529085
#
# precision
# 0.6141961989900134
#
# recall
# 0.4583364828258334
#
# confusion_matrix
# [[ 47   0  56  76]
#  [  0   5   5   3]
#  [ 59   0 442 139]
#  [ 50   0 176 222]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3013    0.2626    0.2806       179
#  Moderate_Demented     1.0000    0.3846    0.5556        13
#       Non_Demented     0.6510    0.6906    0.6702       640
# Very_Mild_Demented     0.5045    0.4955    0.5000       448
#
#           accuracy                         0.5594      1280
#          macro avg     0.6142    0.4583    0.5016      1280
#       weighted avg     0.5544    0.5594    0.5550      1280
# {'metrics': {'accuracy': 0.559375,
#   'f1_macro': 0.5015893177529085,
#   'precision': 0.6141961989900134,
#   'recall': 0.4583364828258334,
#   'confusion_matrix': array([[ 47,   0,  56,  76],
#          [  0,   5,   5,   3],
#          [ 59,   0, 442, 139],
#          [ 50,   0, 176, 222]], dtype=int64)},
#  'best_params': {'learning_rate': 1, 'n_estimators': 400},
#  'best_estimator': AdaBoostClassifier(learning_rate=1, n_estimators=400, random_state=42)}

# %%
# Crie uma instância do modelo
model = DummyClassifier(random_state = SEED)

# Defina a grade de hiperparâmetros

param_grid = {
    'strategy': ['most_frequent', 'prior', 'stratified', 'uniform', 'constant'],
}

grid_search_application(model, X_train_flatten, y_train, X_test_flatten, y_test, k, param_grid, target_names)
# Out:
# accuracy
# 0.5
#
# f1_macro
# 0.16666666666666666
#
# precision
# 0.125
#
# recall
# 0.25
#
# confusion_matrix
# [[  0   0 179   0]
#  [  0   0  13   0]
#  [  0   0 640   0]
#  [  0   0 448   0]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.0000    0.0000    0.0000       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.5000    1.0000    0.6667       640
# Very_Mild_Demented     0.0000    0.0000    0.0000       448
#
#           accuracy                         0.5000      1280
#          macro avg     0.1250    0.2500    0.1667      1280
#       weighted avg     0.2500    0.5000    0.3333      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 2 fits failed out of a total of 10.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\dummy.py", line 196, in fit
#     raise ValueError(
# ValueError: Constant target value has to be specified when the constant strategy is used.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.5        0.5        0.39375    0.24107143        nan]
#   warnings.warn(
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'metrics': {'accuracy': 0.5,
#   'f1_macro': 0.16666666666666666,
#   'precision': 0.125,
#   'recall': 0.25,
#   'confusion_matrix': array([[  0,   0, 179,   0],
#          [  0,   0,  13,   0],
#          [  0,   0, 640,   0],
#          [  0,   0, 448,   0]], dtype=int64)},
#  'best_params': {'strategy': 'most_frequent'},
#  'best_estimator': DummyClassifier(random_state=42, strategy='most_frequent')}

# %%
# Crie uma instância do modelo
model = DummyClassifier(random_state = SEED)

# Defina a grade de hiperparâmetros

param_grid = {
    'strategy': ['most_frequent', 'prior', 'stratified', 'uniform', 'constant'],
}

grid_search_application(model, X_train_flatten, y_train, X_test_flatten, y_test, k, param_grid, target_names)
