# %%
import import_ipynb
from preprocessing_smote import *
from imports.imports_common_models_ML import *

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo
model = DecisionTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.7
# accuracy
# 0.7
#
# f1_macro
# 0.6409233257697249
#
# precision
# 0.668860774857628
#
# recall
# 0.6194608180750814
#
# confusion_matrix
# [[ 87   1  41  50]
#  [  1   7   3   2]
#  [ 31   1 503 105]
#  [ 38   1 110 299]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.55      0.49      0.52       179
#  Moderate_Demented       0.70      0.54      0.61        13
#       Non_Demented       0.77      0.79      0.78       640
# Very_Mild_Demented       0.66      0.67      0.66       448
#
#           accuracy                           0.70      1280
#          macro avg       0.67      0.62      0.64      1280
#       weighted avg       0.70      0.70      0.70      1280
# {'accuracy': 0.7,
#  'f1_macro': 0.6409233257697249,
#  'precision': 0.668860774857628,
#  'recall': 0.6194608180750814,
#  'confusion_matrix': array([[ 87,   1,  41,  50],
#         [  1,   7,   3,   2],
#         [ 31,   1, 503, 105],
#         [ 38,   1, 110, 299]], dtype=int64)}

# %%
# Criando o modelo
model = ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.64453125
# accuracy
# 0.64453125
#
# f1_macro
# 0.5772395484809638
#
# precision
# 0.5658983409186976
#
# recall
# 0.5913978566824237
#
# confusion_matrix
# [[ 91   2  35  51]
#  [  1   7   3   2]
#  [ 47   0 454 139]
#  [ 41   7 127 273]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.51      0.51      0.51       179
#  Moderate_Demented       0.44      0.54      0.48        13
#       Non_Demented       0.73      0.71      0.72       640
# Very_Mild_Demented       0.59      0.61      0.60       448
#
#           accuracy                           0.64      1280
#          macro avg       0.57      0.59      0.58      1280
#       weighted avg       0.65      0.64      0.65      1280
# {'accuracy': 0.64453125,
#  'f1_macro': 0.5772395484809638,
#  'precision': 0.5658983409186976,
#  'recall': 0.5913978566824237,
#  'confusion_matrix': array([[ 91,   2,  35,  51],
#         [  1,   7,   3,   2],
#         [ 47,   0, 454, 139],
#         [ 41,   7, 127, 273]], dtype=int64)}

# %%
# Criando o modelo de Random Forest
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.93125
# accuracy
# 0.93125
#
# f1_macro
# 0.9452595384666878
#
# precision
# 0.9561174139661195
#
# recall
# 0.9361248628292098
#
# confusion_matrix
# [[156   0   8  15]
#  [  0  13   0   0]
#  [  3   0 613  24]
#  [  0   0  38 410]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.98      0.87      0.92       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.93      0.96      0.94       640
# Very_Mild_Demented       0.91      0.92      0.91       448
#
#           accuracy                           0.93      1280
#          macro avg       0.96      0.94      0.95      1280
#       weighted avg       0.93      0.93      0.93      1280
# {'accuracy': 0.93125,
#  'f1_macro': 0.9452595384666878,
#  'precision': 0.9561174139661195,
#  'recall': 0.9361248628292098,
#  'confusion_matrix': array([[156,   0,   8,  15],
#         [  0,  13,   0,   0],
#         [  3,   0, 613,  24],
#         [  0,   0,  38, 410]], dtype=int64)}

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.92734375
# accuracy
# 0.92734375
#
# f1_macro
# 0.8686112789415162
#
# precision
# 0.8170409276272969
#
# recall
# 0.95981986981245
#
# confusion_matrix
# [[178   0   0   1]
#  [  0  13   0   0]
#  [ 40   8 565  27]
#  [ 15   2   0 431]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.76      0.99      0.86       179
#  Moderate_Demented       0.57      1.00      0.72        13
#       Non_Demented       1.00      0.88      0.94       640
# Very_Mild_Demented       0.94      0.96      0.95       448
#
#           accuracy                           0.93      1280
#          macro avg       0.82      0.96      0.87      1280
#       weighted avg       0.94      0.93      0.93      1280
# {'accuracy': 0.92734375,
#  'f1_macro': 0.8686112789415162,
#  'precision': 0.8170409276272969,
#  'recall': 0.95981986981245,
#  'confusion_matrix': array([[178,   0,   0,   1],
#         [  0,  13,   0,   0],
#         [ 40,   8, 565,  27],
#         [ 15,   2,   0, 431]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.90546875
# accuracy
# 0.90546875
#
# f1_macro
# 0.928254742930581
#
# precision
# 0.9507315706010036
#
# recall
# 0.9126826865522745
#
# confusion_matrix
# [[153   0  16  10]
#  [  0  13   0   0]
#  [  1   0 628  11]
#  [  0   0  83 365]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.85      0.92       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.86      0.98      0.92       640
# Very_Mild_Demented       0.95      0.81      0.88       448
#
#           accuracy                           0.91      1280
#          macro avg       0.95      0.91      0.93      1280
#       weighted avg       0.91      0.91      0.90      1280
# {'accuracy': 0.90546875,
#  'f1_macro': 0.928254742930581,
#  'precision': 0.9507315706010036,
#  'recall': 0.9126826865522745,
#  'confusion_matrix': array([[153,   0,  16,  10],
#         [  0,  13,   0,   0],
#         [  1,   0, 628,  11],
#         [  0,   0,  83, 365]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1, early_stopping = True)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.85234375
# accuracy
# 0.85234375
#
# f1_macro
# 0.8818212199373425
#
# precision
# 0.9243313139376788
#
# recall
# 0.8584662435155627
#
# confusion_matrix
# [[133   0  33  13]
#  [  0  13   0   0]
#  [  1   0 625  14]
#  [  2   0 126 320]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.98      0.74      0.84       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.80      0.98      0.88       640
# Very_Mild_Demented       0.92      0.71      0.81       448
#
#           accuracy                           0.85      1280
#          macro avg       0.92      0.86      0.88      1280
#       weighted avg       0.87      0.85      0.85      1280
# {'accuracy': 0.85234375,
#  'f1_macro': 0.8818212199373425,
#  'precision': 0.9243313139376788,
#  'recall': 0.8584662435155627,
#  'confusion_matrix': array([[133,   0,  33,  13],
#         [  0,  13,   0,   0],
#         [  1,   0, 625,  14],
#         [  2,   0, 126, 320]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.88125
# accuracy
# 0.88125
#
# f1_macro
# 0.9040017175797395
#
# precision
# 0.9027730082417582
#
# recall
# 0.905262370311253
#
# confusion_matrix
# [[154   0  13  12]
#  [  0  13   0   0]
#  [ 17   0 574  49]
#  [ 11   0  50 387]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.85      0.86      0.85       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.90      0.90      0.90       640
# Very_Mild_Demented       0.86      0.86      0.86       448
#
#           accuracy                           0.88      1280
#          macro avg       0.90      0.91      0.90      1280
#       weighted avg       0.88      0.88      0.88      1280
# {'accuracy': 0.88125,
#  'f1_macro': 0.9040017175797395,
#  'precision': 0.9027730082417582,
#  'recall': 0.905262370311253,
#  'confusion_matrix': array([[154,   0,  13,  12],
#         [  0,  13,   0,   0],
#         [ 17,   0, 574,  49],
#         [ 11,   0,  50, 387]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.47578125
# accuracy
# 0.47578125
#
# f1_macro
# 0.5183756793588068
#
# precision
# 0.5133303934676332
#
# recall
# 0.5659927711952851
#
# confusion_matrix
# [[101   0  37  41]
#  [  0  11   0   2]
#  [140   2 382 116]
#  [162   2 169 115]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.25      0.56      0.35       179
#  Moderate_Demented       0.73      0.85      0.79        13
#       Non_Demented       0.65      0.60      0.62       640
# Very_Mild_Demented       0.42      0.26      0.32       448
#
#           accuracy                           0.48      1280
#          macro avg       0.51      0.57      0.52      1280
#       weighted avg       0.51      0.48      0.48      1280
# {'accuracy': 0.47578125,
#  'f1_macro': 0.5183756793588068,
#  'precision': 0.5133303934676332,
#  'recall': 0.5659927711952851,
#  'confusion_matrix': array([[101,   0,  37,  41],
#         [  0,  11,   0,   2],
#         [140,   2, 382, 116],
#         [162,   2, 169, 115]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.53984375
# accuracy
# 0.53984375
#
# f1_macro
# 0.5008628366659756
#
# precision
# 0.47527480172478365
#
# recall
# 0.5591593876619191
#
# confusion_matrix
# [[ 93   4  26  56]
#  [  4   9   0   0]
#  [ 90   3 433 114]
#  [105   5 182 156]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.32      0.52      0.39       179
#  Moderate_Demented       0.43      0.69      0.53        13
#       Non_Demented       0.68      0.68      0.68       640
# Very_Mild_Demented       0.48      0.35      0.40       448
#
#           accuracy                           0.54      1280
#          macro avg       0.48      0.56      0.50      1280
#       weighted avg       0.55      0.54      0.54      1280
# {'accuracy': 0.53984375,
#  'f1_macro': 0.5008628366659756,
#  'precision': 0.47527480172478365,
#  'recall': 0.5591593876619191,
#  'confusion_matrix': array([[ 93,   4,  26,  56],
#         [  4,   9,   0,   0],
#         [ 90,   3, 433, 114],
#         [105,   5, 182, 156]], dtype=int64)}

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.8203125
# accuracy
# 0.8203125
#
# f1_macro
# 0.857851167907378
#
# precision
# 0.8451197533635247
#
# recall
# 0.8774846618116521
#
# confusion_matrix
# [[162   0   6  11]
#  [  0  13   0   0]
#  [ 41   0 520  79]
#  [ 27   0  66 355]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.70      0.91      0.79       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.88      0.81      0.84       640
# Very_Mild_Demented       0.80      0.79      0.80       448
#
#           accuracy                           0.82      1280
#          macro avg       0.85      0.88      0.86      1280
#       weighted avg       0.83      0.82      0.82      1280
# {'accuracy': 0.8203125,
#  'f1_macro': 0.857851167907378,
#  'precision': 0.8451197533635247,
#  'recall': 0.8774846618116521,
#  'confusion_matrix': array([[162,   0,   6,  11],
#         [  0,  13,   0,   0],
#         [ 41,   0, 520,  79],
#         [ 27,   0,  66, 355]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9751782471391962
#
# precision
# 0.9753001200480192
#
# recall
# 0.9751006958300081
#
# confusion_matrix
# [[172   0   6   1]
#  [  0  13   0   0]
#  [  3   0 627  10]
#  [  5   0  13 430]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.96      0.96      0.96       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.97      0.98      0.98       640
# Very_Mild_Demented       0.98      0.96      0.97       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.98      0.98      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9751782471391962,
#  'precision': 0.9753001200480192,
#  'recall': 0.9751006958300081,
#  'confusion_matrix': array([[172,   0,   6,   1],
#         [  0,  13,   0,   0],
#         [  3,   0, 627,  10],
#         [  5,   0,  13, 430]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.93203125
# accuracy
# 0.93203125
#
# f1_macro
# 0.9510098144609015
#
# precision
# 0.9514241228948224
#
# recall
# 0.9505998104549083
#
# confusion_matrix
# [[170   0   5   4]
#  [  0  13   0   0]
#  [  5   0 600  35]
#  [  3   0  35 410]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.96      0.95      0.95       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.94      0.94      0.94       640
# Very_Mild_Demented       0.91      0.92      0.91       448
#
#           accuracy                           0.93      1280
#          macro avg       0.95      0.95      0.95      1280
#       weighted avg       0.93      0.93      0.93      1280
# {'accuracy': 0.93203125,
#  'f1_macro': 0.9510098144609015,
#  'precision': 0.9514241228948224,
#  'recall': 0.9505998104549083,
#  'confusion_matrix': array([[170,   0,   5,   4],
#         [  0,  13,   0,   0],
#         [  5,   0, 600,  35],
#         [  3,   0,  35, 410]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.22734375
# accuracy
# 0.22734375
#
# f1_macro
# 0.19522419987847406
#
# precision
# 0.2376875899677176
#
# recall
# 0.3727177850082878
#
# confusion_matrix
# [[ 56  84  15  24]
#  [  1   9   0   3]
#  [ 78 121  28 413]
#  [ 73 139  38 198]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.27      0.31      0.29       179
#  Moderate_Demented       0.03      0.69      0.05        13
#       Non_Demented       0.35      0.04      0.08       640
# Very_Mild_Demented       0.31      0.44      0.36       448
#
#           accuracy                           0.23      1280
#          macro avg       0.24      0.37      0.20      1280
#       weighted avg       0.32      0.23      0.21      1280
# {'accuracy': 0.22734375,
#  'f1_macro': 0.19522419987847406,
#  'precision': 0.2376875899677176,
#  'recall': 0.3727177850082878,
#  'confusion_matrix': array([[ 56,  84,  15,  24],
#         [  1,   9,   0,   3],
#         [ 78, 121,  28, 413],
#         [ 73, 139,  38, 198]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.8203125
# accuracy
# 0.8203125
#
# f1_macro
# 0.857851167907378
#
# precision
# 0.8451197533635247
#
# recall
# 0.8774846618116521
#
# confusion_matrix
# [[162   0   6  11]
#  [  0  13   0   0]
#  [ 41   0 520  79]
#  [ 27   0  66 355]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.70      0.91      0.79       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.88      0.81      0.84       640
# Very_Mild_Demented       0.80      0.79      0.80       448
#
#           accuracy                           0.82      1280
#          macro avg       0.85      0.88      0.86      1280
#       weighted avg       0.83      0.82      0.82      1280
# {'accuracy': 0.8203125,
#  'f1_macro': 0.857851167907378,
#  'precision': 0.8451197533635247,
#  'recall': 0.8774846618116521,
#  'confusion_matrix': array([[162,   0,   6,  11],
#         [  0,  13,   0,   0],
#         [ 41,   0, 520,  79],
#         [ 27,   0,  66, 355]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", class_weight = "balanced", C = 100,  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.99140625
# accuracy
# 0.99140625
#
# f1_macro
# 0.9926609430694316
#
# precision
# 0.9943576940275631
#
# recall
# 0.9910093899640862
#
# confusion_matrix
# [[175   0   4   0]
#  [  0  13   0   0]
#  [  1   0 637   2]
#  [  0   0   4 444]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.98      0.99       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.99      1.00      0.99       640
# Very_Mild_Demented       1.00      0.99      0.99       448
#
#           accuracy                           0.99      1280
#          macro avg       0.99      0.99      0.99      1280
#       weighted avg       0.99      0.99      0.99      1280
# {'accuracy': 0.99140625,
#  'f1_macro': 0.9926609430694316,
#  'precision': 0.9943576940275631,
#  'recall': 0.9910093899640862,
#  'confusion_matrix': array([[175,   0,   4,   0],
#         [  0,  13,   0,   0],
#         [  1,   0, 637,   2],
#         [  0,   0,   4, 444]], dtype=int64)}

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9741657784137153
#
# precision
# 0.9824161173670237
#
# recall
# 0.9668851007581803
#
# confusion_matrix
# [[164   0   7   8]
#  [  0  13   0   0]
#  [  1   0 636   3]
#  [  0   0  19 429]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.92      0.95       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.96      0.99      0.98       640
# Very_Mild_Demented       0.97      0.96      0.97       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.97      0.97      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9741657784137153,
#  'precision': 0.9824161173670237,
#  'recall': 0.9668851007581803,
#  'confusion_matrix': array([[164,   0,   7,   8],
#         [  0,  13,   0,   0],
#         [  1,   0, 636,   3],
#         [  0,   0,  19, 429]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = GradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.57890625
# accuracy
# 0.57890625
#
# f1_macro
# 0.5044799911228397
#
# precision
# 0.6386096113301423
#
# recall
# 0.4577148497452268
#
# confusion_matrix
# [[ 42   0  66  71]
#  [  1   5   3   4]
#  [ 28   0 504 108]
#  [ 30   0 228 190]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.42      0.23      0.30       179
#  Moderate_Demented       1.00      0.38      0.56        13
#       Non_Demented       0.63      0.79      0.70       640
# Very_Mild_Demented       0.51      0.42      0.46       448
#
#           accuracy                           0.58      1280
#          macro avg       0.64      0.46      0.50      1280
#       weighted avg       0.56      0.58      0.56      1280
# {'accuracy': 0.57890625,
#  'f1_macro': 0.5044799911228397,
#  'precision': 0.6386096113301423,
#  'recall': 0.4577148497452268,
#  'confusion_matrix': array([[ 42,   0,  66,  71],
#         [  1,   5,   3,   4],
#         [ 28,   0, 504, 108],
#         [ 30,   0, 228, 190]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = HistGradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96640625
# accuracy
# 0.96640625
#
# f1_macro
# 0.9247670239259262
#
# precision
# 0.9800774607340359
#
# recall
# 0.8852109264687826
#
# confusion_matrix
# [[159   0   6  14]
#  [  0   9   1   3]
#  [  0   0 636   4]
#  [  0   0  15 433]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       1.00      0.89      0.94       179
#  Moderate_Demented       1.00      0.69      0.82        13
#       Non_Demented       0.97      0.99      0.98       640
# Very_Mild_Demented       0.95      0.97      0.96       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.89      0.92      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.96640625,
#  'f1_macro': 0.9247670239259262,
#  'precision': 0.9800774607340359,
#  'recall': 0.8852109264687826,
#  'confusion_matrix': array([[159,   0,   6,  14],
#         [  0,   9,   1,   3],
#         [  0,   0, 636,   4],
#         [  0,   0,  15, 433]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = LinearDiscriminantAnalysis()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.83515625
# accuracy
# 0.83515625
#
# f1_macro
# 0.8747940575409934
#
# precision
# 0.8799555540840233
#
# recall
# 0.8704842752394254
#
# confusion_matrix
# [[146   0  13  20]
#  [  0  13   0   0]
#  [ 10   0 545  85]
#  [ 10   0  73 365]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.88      0.82      0.85       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.86      0.85      0.86       640
# Very_Mild_Demented       0.78      0.81      0.80       448
#
#           accuracy                           0.84      1280
#          macro avg       0.88      0.87      0.87      1280
#       weighted avg       0.84      0.84      0.84      1280
# {'accuracy': 0.83515625,
#  'f1_macro': 0.8747940575409934,
#  'precision': 0.8799555540840233,
#  'recall': 0.8704842752394254,
#  'confusion_matrix': array([[146,   0,  13,  20],
#         [  0,  13,   0,   0],
#         [ 10,   0, 545,  85],
#         [ 10,   0,  73, 365]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = DummyClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.5
# accuracy
# 0.5
#
# f1_macro
# 0.16666666666666666
#
# precision
# 0.125
#
# recall
# 0.25
#
# confusion_matrix
# [[  0   0 179   0]
#  [  0   0  13   0]
#  [  0   0 640   0]
#  [  0   0 448   0]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.00      0.00      0.00       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.50      1.00      0.67       640
# Very_Mild_Demented       0.00      0.00      0.00       448
#
#           accuracy                           0.50      1280
#          macro avg       0.12      0.25      0.17      1280
#       weighted avg       0.25      0.50      0.33      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.5,
#  'f1_macro': 0.16666666666666666,
#  'precision': 0.125,
#  'recall': 0.25,
#  'confusion_matrix': array([[  0,   0, 179,   0],
#         [  0,   0,  13,   0],
#         [  0,   0, 640,   0],
#         [  0,   0, 448,   0]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = RidgeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96953125
# accuracy
# 0.96953125
#
# f1_macro
# 0.9715730984474658
#
# precision
# 0.976742562038247
#
# recall
# 0.9668292971867518
#
# confusion_matrix
# [[164   0   6   9]
#  [  0  13   0   0]
#  [  0   0 633   7]
#  [  5   0  12 431]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.97      0.92      0.94       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.97      0.99      0.98       640
# Very_Mild_Demented       0.96      0.96      0.96       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.97      0.97      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.96953125,
#  'f1_macro': 0.9715730984474658,
#  'precision': 0.976742562038247,
#  'recall': 0.9668292971867518,
#  'confusion_matrix': array([[164,   0,   6,   9],
#         [  0,  13,   0,   0],
#         [  0,   0, 633,   7],
#         [  5,   0,  12, 431]], dtype=int64)}
