# %%
import import_ipynb
from preprocessing_smote import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing_smote.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# ['Mild_Demented' 'Moderate_Demented' 'Non_Demented' 'Very_Mild_Demented']
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\imblearn\over_sampling\_smote\base.py:336: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo de Random Forest
model = tree.DecisionTreeClassifier(random_state = SEED)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.6572916666666667
# accuracy
# 0.6572916666666667
#
# f1_macro
# 0.5942558360051619
#
# precision
# 0.5697693408020117
#
# recall
# 0.6312283766481421
#
# confusion_matrix
# [[156   3  49  68]
#  [  2  12   3   2]
#  [ 75   8 686 191]
#  [ 77   6 174 408]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53       276
#            1       0.41      0.63      0.50        19
#            2       0.75      0.71      0.73       960
#            3       0.61      0.61      0.61       665
#
#     accuracy                           0.66      1920
#    macro avg       0.57      0.63      0.59      1920
# weighted avg       0.66      0.66      0.66      1920
# {'accuracy': 0.6572916666666667,
#  'f1_macro': 0.5942558360051619,
#  'precision': 0.5697693408020117,
#  'recall': 0.6312283766481421,
#  'confusion_matrix': array([[156,   3,  49,  68],
#         [  2,  12,   3,   2],
#         [ 75,   8, 686, 191],
#         [ 77,   6, 174, 408]], dtype=int64),
#  'classification_report': '              precision    recall  f1-score   support\n\n           0       0.50      0.57      0.53       276\n           1       0.41      0.63      0.50        19\n           2       0.75      0.71      0.73       960\n           3       0.61      0.61      0.61       665\n\n    accuracy                           0.66      1920\n   macro avg       0.57      0.63      0.59      1920\nweighted avg       0.66      0.66      0.66      1920\n'}

# %%
# Criando o modelo de Random Forest
model = tree.ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.6484375
# {'accuracy': 0.6484375,
#  'f1_macro': 0.6121537272737966,
#  'precision': 0.593788061985207,
#  'recall': 0.6358088665958375,
#  'confusion_matrix': array([[173,   2,  44,  57],
#         [  4,  12,   1,   2],
#         [ 75,   5, 669, 211],
#         [ 79,   4, 191, 391]], dtype=int64)}

# %%
# Criando o modelo de Random Forest
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.9359375
# {'accuracy': 0.9359375,
#  'f1_macro': 0.9068162968530996,
#  'precision': 0.9606473865065218,
#  'recall': 0.8686932174185463,
#  'confusion_matrix': array([[253,   0,  12,  11],
#         [  0,  13,   1,   5],
#         [  1,   0, 927,  32],
#         [  2,   0,  59, 604]], dtype=int64)}

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs = -1)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.9364583333333333
# {'accuracy': 0.9364583333333333,
#  'f1_macro': 0.8959066096478999,
#  'precision': 0.8559113966805499,
#  'recall': 0.9532522713032581,
#  'confusion_matrix': array([[276,   0,   0,   0],
#         [  0,  18,   0,   1],
#         [ 39,   6, 857,  58],
#         [ 12,   3,   3, 647]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.8776041666666666
# {'accuracy': 0.8776041666666666,
#  'f1_macro': 0.8772894031110532,
#  'precision': 0.9137189741080675,
#  'recall': 0.8609172387490466,
#  'confusion_matrix': array([[259,   0,   4,  13],
#         [  0,  14,   0,   5],
#         [ 20,   0, 768, 172],
#         [  7,   0,  14, 644]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1, early_stopping = True)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.865625
# {'accuracy': 0.865625,
#  'f1_macro': 0.8660490689274674,
#  'precision': 0.8544385417376225,
#  'recall': 0.8841893286204642,
#  'confusion_matrix': array([[250,   0,  14,  12],
#         [  0,  18,   0,   1],
#         [ 16,   4, 893,  47],
#         [ 28,   0, 136, 501]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.8833333333333333
# {'accuracy': 0.8833333333333333,
#  'f1_macro': 0.8794056284483777,
#  'precision': 0.9042077724506731,
#  'recall': 0.8611946816770186,
#  'confusion_matrix': array([[247,   0,  13,  16],
#         [  0,  15,   0,   4],
#         [ 20,   0, 857,  83],
#         [ 23,   0,  65, 577]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.44583333333333336
# {'accuracy': 0.44583333333333336,
#  'f1_macro': 0.33279916702823875,
#  'precision': 0.34689167915644437,
#  'recall': 0.4583902010460935,
#  'confusion_matrix': array([[143,  34,  50,  49],
#         [  7,  10,   2,   0],
#         [214,  43, 580, 123],
#         [238,  69, 235, 123]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.5255208333333333
# {'accuracy': 0.5255208333333333,
#  'f1_macro': 0.428715290700015,
#  'precision': 0.4125076651189086,
#  'recall': 0.47017739661654134,
#  'confusion_matrix': array([[138,   7,  41,  90],
#         [  5,   7,   1,   6],
#         [134,   8, 621, 197],
#         [158,  13, 251, 243]], dtype=int64)}

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train, y_train, X_test, y_test)

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
kfold_application(model, k, X_cross, y_cross)

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
kfold_application(model, k, X_cross, y_cross)

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
kfold_application(model, k, X_cross, y_cross)

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", )
model_application(model, X_train, y_train, X_test, y_test)

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", class_weight = "balanced", C=100)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.9890625
# {'accuracy': 0.9890625,
#  'f1_macro': 0.9628337913595391,
#  'precision': 0.9924372618229014,
#  'recall': 0.9394356305165087,
#  'confusion_matrix': array([[272,   0,   4,   0],
#         [  0,  15,   0,   4],
#         [  2,   0, 955,   3],
#         [  0,   0,   8, 657]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
gbc = GradientBoostingClassifier(random_state = SEED)
model_application(gbc, X_train, y_train, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Criando modelo Gradient Boosting
# ----> 2 gbc = GradientBoostingClassifier(random_state = SEED, n_jobs = -1)
#       3 model_application(gbc, X_train, y_train, X_test, y_test)
#
# TypeError: GradientBoostingClassifier.__init__() got an unexpected keyword argument 'n_jobs'

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.959375
# {'accuracy': 0.959375,
#  'f1_macro': 0.9188034528687001,
#  'precision': 0.9738636909099636,
#  'recall': 0.8797743339326578,
#  'confusion_matrix': array([[247,   0,  14,  15],
#         [  0,  13,   0,   6],
#         [  3,   0, 950,   7],
#         [  1,   0,  32, 632]], dtype=int64)}
