# %%
import import_ipynb
from preprocessing_smote import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing_smote.ipynb
# importing Jupyter notebook from preprocessing.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# X:  6400
# X_train:  4480
# X_test:  1280
# X_val:  640
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 627,   45, 2240, 1568], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 627,   45, 2240, 1568], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# Unique Values: [0 1 2 3]
# Frequency Values: [ 627   45 2240 1568]
# 4480 4480
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\imblearn\over_sampling\_smote\base.py:336: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# 8960 8960
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo
model = DecisionTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.68125
# accuracy
# 0.68125
#
# f1_macro
# 0.6050127648835373
#
# precision
# 0.5862270160492006
#
# recall
# 0.6303783659601572
#
# confusion_matrix
# [[110   1  32  36]
#  [  1   7   4   1]
#  [ 43   5 473 119]
#  [ 59   4 103 282]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5164    0.6145    0.5612       179
#  Moderate_Demented     0.4118    0.5385    0.4667        13
#       Non_Demented     0.7729    0.7391    0.7556       640
# Very_Mild_Demented     0.6438    0.6295    0.6366       448
#
#           accuracy                         0.6813      1280
#          macro avg     0.5862    0.6304    0.6050      1280
#       weighted avg     0.6882    0.6813    0.6838      1280
# {'accuracy': 0.68125,
#  'f1_macro': 0.6050127648835373,
#  'precision': 0.5862270160492006,
#  'recall': 0.6303783659601572,
#  'confusion_matrix': array([[110,   1,  32,  36],
#         [  1,   7,   4,   1],
#         [ 43,   5, 473, 119],
#         [ 59,   4, 103, 282]], dtype=int64)}

# %%
# Criando o modelo
model = ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.64765625
# accuracy
# 0.64765625
#
# f1_macro
# 0.6145709077145176
#
# precision
# 0.5944935085712906
#
# recall
# 0.6430493018678249
#
# confusion_matrix
# [[104   0  36  39]
#  [  2   9   2   0]
#  [ 69   4 447 120]
#  [ 59   3 117 269]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.4444    0.5810    0.5036       179
#  Moderate_Demented     0.5625    0.6923    0.6207        13
#       Non_Demented     0.7425    0.6984    0.7198       640
# Very_Mild_Demented     0.6285    0.6004    0.6142       448
#
#           accuracy                         0.6477      1280
#          macro avg     0.5945    0.6430    0.6146      1280
#       weighted avg     0.6591    0.6477    0.6516      1280
# {'accuracy': 0.64765625,
#  'f1_macro': 0.6145709077145176,
#  'precision': 0.5944935085712906,
#  'recall': 0.6430493018678249,
#  'confusion_matrix': array([[104,   0,  36,  39],
#         [  2,   9,   2,   0],
#         [ 69,   4, 447, 120],
#         [ 59,   3, 117, 269]], dtype=int64)}

# %%
# Criando o modelo de Random Forest
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.93125
# accuracy
# 0.93125
#
# f1_macro
# 0.9452595384666878
#
# precision
# 0.9561174139661195
#
# recall
# 0.9361248628292098
#
# confusion_matrix
# [[156   0   8  15]
#  [  0  13   0   0]
#  [  3   0 613  24]
#  [  0   0  38 410]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9811    0.8715    0.9231       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9302    0.9578    0.9438       640
# Very_Mild_Demented     0.9131    0.9152    0.9142       448
#
#           accuracy                         0.9313      1280
#          macro avg     0.9561    0.9361    0.9453      1280
#       weighted avg     0.9321    0.9313    0.9311      1280
# {'accuracy': 0.93125,
#  'f1_macro': 0.9452595384666878,
#  'precision': 0.9561174139661195,
#  'recall': 0.9361248628292098,
#  'confusion_matrix': array([[156,   0,   8,  15],
#         [  0,  13,   0,   0],
#         [  3,   0, 613,  24],
#         [  0,   0,  38, 410]], dtype=int64)}

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.92734375
# accuracy
# 0.92734375
#
# f1_macro
# 0.8686112789415162
#
# precision
# 0.8170409276272969
#
# recall
# 0.95981986981245
#
# confusion_matrix
# [[178   0   0   1]
#  [  0  13   0   0]
#  [ 40   8 565  27]
#  [ 15   2   0 431]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7639    0.9944    0.8641       179
#  Moderate_Demented     0.5652    1.0000    0.7222        13
#       Non_Demented     1.0000    0.8828    0.9378       640
# Very_Mild_Demented     0.9390    0.9621    0.9504       448
#
#           accuracy                         0.9273      1280
#          macro avg     0.8170    0.9598    0.8686      1280
#       weighted avg     0.9412    0.9273    0.9297      1280
# {'accuracy': 0.92734375,
#  'f1_macro': 0.8686112789415162,
#  'precision': 0.8170409276272969,
#  'recall': 0.95981986981245,
#  'confusion_matrix': array([[178,   0,   0,   1],
#         [  0,  13,   0,   0],
#         [ 40,   8, 565,  27],
#         [ 15,   2,   0, 431]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.90546875
# accuracy
# 0.90546875
#
# f1_macro
# 0.928254742930581
#
# precision
# 0.9507315706010036
#
# recall
# 0.9126826865522745
#
# confusion_matrix
# [[153   0  16  10]
#  [  0  13   0   0]
#  [  1   0 628  11]
#  [  0   0  83 365]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9935    0.8547    0.9189       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8638    0.9812    0.9188       640
# Very_Mild_Demented     0.9456    0.8147    0.8753       448
#
#           accuracy                         0.9055      1280
#          macro avg     0.9507    0.9127    0.9283      1280
#       weighted avg     0.9120    0.9055    0.9044      1280
# {'accuracy': 0.90546875,
#  'f1_macro': 0.928254742930581,
#  'precision': 0.9507315706010036,
#  'recall': 0.9126826865522745,
#  'confusion_matrix': array([[153,   0,  16,  10],
#         [  0,  13,   0,   0],
#         [  1,   0, 628,  11],
#         [  0,   0,  83, 365]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.88125
# accuracy
# 0.88125
#
# f1_macro
# 0.9040017175797395
#
# precision
# 0.9027730082417582
#
# recall
# 0.905262370311253
#
# confusion_matrix
# [[154   0  13  12]
#  [  0  13   0   0]
#  [ 17   0 574  49]
#  [ 11   0  50 387]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8462    0.8603    0.8532       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9011    0.8969    0.8990       640
# Very_Mild_Demented     0.8638    0.8638    0.8638       448
#
#           accuracy                         0.8812      1280
#          macro avg     0.9028    0.9053    0.9040      1280
#       weighted avg     0.8814    0.8812    0.8813      1280
# {'accuracy': 0.88125,
#  'f1_macro': 0.9040017175797395,
#  'precision': 0.9027730082417582,
#  'recall': 0.905262370311253,
#  'confusion_matrix': array([[154,   0,  13,  12],
#         [  0,  13,   0,   0],
#         [ 17,   0, 574,  49],
#         [ 11,   0,  50, 387]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.47578125
# accuracy
# 0.47578125
#
# f1_macro
# 0.5183756793588068
#
# precision
# 0.5133303934676332
#
# recall
# 0.5659927711952851
#
# confusion_matrix
# [[101   0  37  41]
#  [  0  11   0   2]
#  [140   2 382 116]
#  [162   2 169 115]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2506    0.5642    0.3471       179
#  Moderate_Demented     0.7333    0.8462    0.7857        13
#       Non_Demented     0.6497    0.5969    0.6221       640
# Very_Mild_Demented     0.4197    0.2567    0.3186       448
#
#           accuracy                         0.4758      1280
#          macro avg     0.5133    0.5660    0.5184      1280
#       weighted avg     0.5142    0.4758    0.4791      1280
# {'accuracy': 0.47578125,
#  'f1_macro': 0.5183756793588068,
#  'precision': 0.5133303934676332,
#  'recall': 0.5659927711952851,
#  'confusion_matrix': array([[101,   0,  37,  41],
#         [  0,  11,   0,   2],
#         [140,   2, 382, 116],
#         [162,   2, 169, 115]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.53984375
# accuracy
# 0.53984375
#
# f1_macro
# 0.5008628366659756
#
# precision
# 0.47527480172478365
#
# recall
# 0.5591593876619191
#
# confusion_matrix
# [[ 93   4  26  56]
#  [  4   9   0   0]
#  [ 90   3 433 114]
#  [105   5 182 156]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3185    0.5196    0.3949       179
#  Moderate_Demented     0.4286    0.6923    0.5294        13
#       Non_Demented     0.6755    0.6766    0.6760       640
# Very_Mild_Demented     0.4785    0.3482    0.4031       448
#
#           accuracy                         0.5398      1280
#          macro avg     0.4753    0.5592    0.5009      1280
#       weighted avg     0.5541    0.5398    0.5397      1280
# {'accuracy': 0.53984375,
#  'f1_macro': 0.5008628366659756,
#  'precision': 0.47527480172478365,
#  'recall': 0.5591593876619191,
#  'confusion_matrix': array([[ 93,   4,  26,  56],
#         [  4,   9,   0,   0],
#         [ 90,   3, 433, 114],
#         [105,   5, 182, 156]], dtype=int64)}

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.8203125
# accuracy
# 0.8203125
#
# f1_macro
# 0.857851167907378
#
# precision
# 0.8451197533635247
#
# recall
# 0.8774846618116521
#
# confusion_matrix
# [[162   0   6  11]
#  [  0  13   0   0]
#  [ 41   0 520  79]
#  [ 27   0  66 355]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7043    0.9050    0.7922       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8784    0.8125    0.8442       640
# Very_Mild_Demented     0.7978    0.7924    0.7951       448
#
#           accuracy                         0.8203      1280
#          macro avg     0.8451    0.8775    0.8579      1280
#       weighted avg     0.8271    0.8203    0.8213      1280
# {'accuracy': 0.8203125,
#  'f1_macro': 0.857851167907378,
#  'precision': 0.8451197533635247,
#  'recall': 0.8774846618116521,
#  'confusion_matrix': array([[162,   0,   6,  11],
#         [  0,  13,   0,   0],
#         [ 41,   0, 520,  79],
#         [ 27,   0,  66, 355]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9751782471391962
#
# precision
# 0.9753001200480192
#
# recall
# 0.9751006958300081
#
# confusion_matrix
# [[172   0   6   1]
#  [  0  13   0   0]
#  [  3   0 627  10]
#  [  5   0  13 430]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9556    0.9609    0.9582       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9706    0.9797    0.9751       640
# Very_Mild_Demented     0.9751    0.9598    0.9674       448
#
#           accuracy                         0.9703      1280
#          macro avg     0.9753    0.9751    0.9752      1280
#       weighted avg     0.9703    0.9703    0.9703      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9751782471391962,
#  'precision': 0.9753001200480192,
#  'recall': 0.9751006958300081,
#  'confusion_matrix': array([[172,   0,   6,   1],
#         [  0,  13,   0,   0],
#         [  3,   0, 627,  10],
#         [  5,   0,  13, 430]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.93203125
# accuracy
# 0.93203125
#
# f1_macro
# 0.9510098144609015
#
# precision
# 0.9514241228948224
#
# recall
# 0.9505998104549083
#
# confusion_matrix
# [[170   0   5   4]
#  [  0  13   0   0]
#  [  5   0 600  35]
#  [  3   0  35 410]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9551    0.9497    0.9524       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9375    0.9375    0.9375       640
# Very_Mild_Demented     0.9131    0.9152    0.9142       448
#
#           accuracy                         0.9320      1280
#          macro avg     0.9514    0.9506    0.9510      1280
#       weighted avg     0.9321    0.9320    0.9320      1280
# {'accuracy': 0.93203125,
#  'f1_macro': 0.9510098144609015,
#  'precision': 0.9514241228948224,
#  'recall': 0.9505998104549083,
#  'confusion_matrix': array([[170,   0,   5,   4],
#         [  0,  13,   0,   0],
#         [  5,   0, 600,  35],
#         [  3,   0,  35, 410]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.22734375
# accuracy
# 0.22734375
#
# f1_macro
# 0.19522419987847406
#
# precision
# 0.2376875899677176
#
# recall
# 0.3727177850082878
#
# confusion_matrix
# [[ 56  84  15  24]
#  [  1   9   0   3]
#  [ 78 121  28 413]
#  [ 73 139  38 198]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2692    0.3128    0.2894       179
#  Moderate_Demented     0.0255    0.6923    0.0492        13
#       Non_Demented     0.3457    0.0437    0.0777       640
# Very_Mild_Demented     0.3103    0.4420    0.3646       448
#
#           accuracy                         0.2273      1280
#          macro avg     0.2377    0.3727    0.1952      1280
#       weighted avg     0.3194    0.2273    0.2074      1280
# {'accuracy': 0.22734375,
#  'f1_macro': 0.19522419987847406,
#  'precision': 0.2376875899677176,
#  'recall': 0.3727177850082878,
#  'confusion_matrix': array([[ 56,  84,  15,  24],
#         [  1,   9,   0,   3],
#         [ 78, 121,  28, 413],
#         [ 73, 139,  38, 198]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.8203125
# accuracy
# 0.8203125
#
# f1_macro
# 0.857851167907378
#
# precision
# 0.8451197533635247
#
# recall
# 0.8774846618116521
#
# confusion_matrix
# [[162   0   6  11]
#  [  0  13   0   0]
#  [ 41   0 520  79]
#  [ 27   0  66 355]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7043    0.9050    0.7922       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8784    0.8125    0.8442       640
# Very_Mild_Demented     0.7978    0.7924    0.7951       448
#
#           accuracy                         0.8203      1280
#          macro avg     0.8451    0.8775    0.8579      1280
#       weighted avg     0.8271    0.8203    0.8213      1280
# {'accuracy': 0.8203125,
#  'f1_macro': 0.857851167907378,
#  'precision': 0.8451197533635247,
#  'recall': 0.8774846618116521,
#  'confusion_matrix': array([[162,   0,   6,  11],
#         [  0,  13,   0,   0],
#         [ 41,   0, 520,  79],
#         [ 27,   0,  66, 355]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(class_weight = "balanced",  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.8203125
# accuracy
# 0.8203125
#
# f1_macro
# 0.857851167907378
#
# precision
# 0.8451197533635247
#
# recall
# 0.8774846618116521
#
# confusion_matrix
# [[162   0   6  11]
#  [  0  13   0   0]
#  [ 41   0 520  79]
#  [ 27   0  66 355]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7043    0.9050    0.7922       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8784    0.8125    0.8442       640
# Very_Mild_Demented     0.7978    0.7924    0.7951       448
#
#           accuracy                         0.8203      1280
#          macro avg     0.8451    0.8775    0.8579      1280
#       weighted avg     0.8271    0.8203    0.8213      1280
# {'accuracy': 0.8203125,
#  'f1_macro': 0.857851167907378,
#  'precision': 0.8451197533635247,
#  'recall': 0.8774846618116521,
#  'confusion_matrix': array([[162,   0,   6,  11],
#         [  0,  13,   0,   0],
#         [ 41,   0, 520,  79],
#         [ 27,   0,  66, 355]], dtype=int64)}

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9741657784137153
#
# precision
# 0.9824161173670237
#
# recall
# 0.9668851007581803
#
# confusion_matrix
# [[164   0   7   8]
#  [  0  13   0   0]
#  [  1   0 636   3]
#  [  0   0  19 429]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9939    0.9162    0.9535       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9607    0.9938    0.9770       640
# Very_Mild_Demented     0.9750    0.9576    0.9662       448
#
#           accuracy                         0.9703      1280
#          macro avg     0.9824    0.9669    0.9742      1280
#       weighted avg     0.9708    0.9703    0.9702      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9741657784137153,
#  'precision': 0.9824161173670237,
#  'recall': 0.9668851007581803,
#  'confusion_matrix': array([[164,   0,   7,   8],
#         [  0,  13,   0,   0],
#         [  1,   0, 636,   3],
#         [  0,   0,  19, 429]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = GradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.84609375
# accuracy
# 0.84609375
#
# f1_macro
# 0.8745215607470705
#
# precision
# 0.8771259666081757
#
# recall
# 0.87209634377494
#
# confusion_matrix
# [[142   0  12  25]
#  [  0  13   0   0]
#  [ 15   0 562  63]
#  [ 15   0  67 366]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8256    0.7933    0.8091       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8768    0.8781    0.8774       640
# Very_Mild_Demented     0.8062    0.8170    0.8115       448
#
#           accuracy                         0.8461      1280
#          macro avg     0.8771    0.8721    0.8745      1280
#       weighted avg     0.8461    0.8461    0.8461      1280
# {'accuracy': 0.84609375,
#  'f1_macro': 0.8745215607470705,
#  'precision': 0.8771259666081757,
#  'recall': 0.87209634377494,
#  'confusion_matrix': array([[142,   0,  12,  25],
#         [  0,  13,   0,   0],
#         [ 15,   0, 562,  63],
#         [ 15,   0,  67, 366]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.50546875
# accuracy
# 0.50546875
#
# f1_macro
# 0.575947508466921
#
# precision
# 0.5925095642182321
#
# recall
# 0.5834050922017927
#
# confusion_matrix
# [[ 80   0  54  45]
#  [  0  12   1   0]
#  [126   0 411 103]
#  [116   0 188 144]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2484    0.4469    0.3194       179
#  Moderate_Demented     1.0000    0.9231    0.9600        13
#       Non_Demented     0.6284    0.6422    0.6352       640
# Very_Mild_Demented     0.4932    0.3214    0.3892       448
#
#           accuracy                         0.5055      1280
#          macro avg     0.5925    0.5834    0.5759      1280
#       weighted avg     0.5317    0.5055    0.5082      1280
# {'accuracy': 0.50546875,
#  'f1_macro': 0.575947508466921,
#  'precision': 0.5925095642182321,
#  'recall': 0.5834050922017927,
#  'confusion_matrix': array([[ 80,   0,  54,  45],
#         [  0,  12,   1,   0],
#         [126,   0, 411, 103],
#         [116,   0, 188, 144]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = HistGradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9765625
# accuracy
# 0.9765625
#
# f1_macro
# 0.959201445514845
#
# precision
# 0.9858339871182338
#
# recall
# 0.9363523457164343
#
# confusion_matrix
# [[167   0   6   6]
#  [  0  11   1   1]
#  [  1   0 637   2]
#  [  0   0  13 435]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9940    0.9330    0.9625       179
#  Moderate_Demented     1.0000    0.8462    0.9167        13
#       Non_Demented     0.9696    0.9953    0.9823       640
# Very_Mild_Demented     0.9797    0.9710    0.9753       448
#
#           accuracy                         0.9766      1280
#          macro avg     0.9858    0.9364    0.9592      1280
#       weighted avg     0.9769    0.9766    0.9764      1280
# {'accuracy': 0.9765625,
#  'f1_macro': 0.959201445514845,
#  'precision': 0.9858339871182338,
#  'recall': 0.9363523457164343,
#  'confusion_matrix': array([[167,   0,   6,   6],
#         [  0,  11,   1,   1],
#         [  1,   0, 637,   2],
#         [  0,   0,  13, 435]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = LinearDiscriminantAnalysis()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.81796875
# accuracy
# 0.81796875
#
# f1_macro
# 0.8639142308202572
#
# precision
# 0.8633534370385716
#
# recall
# 0.8652449745610533
#
# confusion_matrix
# [[150   0  11  18]
#  [  0  13   0   0]
#  [ 15   0 523 102]
#  [ 13   0  74 361]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8427    0.8380    0.8403       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8602    0.8172    0.8381       640
# Very_Mild_Demented     0.7505    0.8058    0.7772       448
#
#           accuracy                         0.8180      1280
#          macro avg     0.8634    0.8652    0.8639      1280
#       weighted avg     0.8208    0.8180    0.8188      1280
# {'accuracy': 0.81796875,
#  'f1_macro': 0.8639142308202572,
#  'precision': 0.8633534370385716,
#  'recall': 0.8652449745610533,
#  'confusion_matrix': array([[150,   0,  11,  18],
#         [  0,  13,   0,   0],
#         [ 15,   0, 523, 102],
#         [ 13,   0,  74, 361]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = DummyClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.13984375
# accuracy
# 0.13984375
#
# f1_macro
# 0.061343385880740224
#
# precision
# 0.0349609375
#
# recall
# 0.25
#
# confusion_matrix
# [[179   0   0   0]
#  [ 13   0   0   0]
#  [640   0   0   0]
#  [448   0   0   0]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.1398    1.0000    0.2454       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.0000    0.0000    0.0000       640
# Very_Mild_Demented     0.0000    0.0000    0.0000       448
#
#           accuracy                         0.1398      1280
#          macro avg     0.0350    0.2500    0.0613      1280
#       weighted avg     0.0196    0.1398    0.0343      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.13984375,
#  'f1_macro': 0.061343385880740224,
#  'precision': 0.0349609375,
#  'recall': 0.25,
#  'confusion_matrix': array([[179,   0,   0,   0],
#         [ 13,   0,   0,   0],
#         [640,   0,   0,   0],
#         [448,   0,   0,   0]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = RidgeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9725206449280839
#
# precision
# 0.9771600514237703
#
# recall
# 0.9682259452314446
#
# confusion_matrix
# [[165   0   5   9]
#  [  0  13   0   0]
#  [  0   0 633   7]
#  [  5   0  12 431]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9706    0.9218    0.9456       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9738    0.9891    0.9814       640
# Very_Mild_Demented     0.9642    0.9621    0.9631       448
#
#           accuracy                         0.9703      1280
#          macro avg     0.9772    0.9682    0.9725      1280
#       weighted avg     0.9703    0.9703    0.9702      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9725206449280839,
#  'precision': 0.9771600514237703,
#  'recall': 0.9682259452314446,
#  'confusion_matrix': array([[165,   0,   5,   9],
#         [  0,  13,   0,   0],
#         [  0,   0, 633,   7],
#         [  5,   0,  12, 431]], dtype=int64)}
