# %% [markdown]
# #### Carregando as importações

# %%
import import_ipynb
from imports.imports_common import *
from imports.imports_common_models_DL import *
from imports.imports_common_metrics import *

# %%
# Definir proporção de divisão
TRAIN_SPLIT = 0.7
VAL_SPLIT = 0.15
TEST_SPLIT = 0.15
COLOR_MODE = "rgb"

# Carrega as imagens e divide automaticamente em treino, teste e validação
train_dataset = image_dataset_from_directory(
    path,
    validation_split = VAL_SPLIT + TEST_SPLIT,  # Define a proporção para validação + teste
    subset='training',  # Define o conjunto como treinamento
    seed = SEED,
    image_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    color_mode = COLOR_MODE,
    label_mode = 'categorical',
)

validation_dataset = image_dataset_from_directory(
    path,
    validation_split = VAL_SPLIT + TEST_SPLIT,  # Define a proporção para validação + teste
    subset='validation',  # Define o conjunto como validação
    seed = SEED,
    image_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    color_mode = COLOR_MODE,
    label_mode = 'categorical',
)

test_dataset = image_dataset_from_directory(
    path,
    validation_split = VAL_SPLIT + TEST_SPLIT,  # Define a proporção para validação + teste
    subset='validation',  # Define o conjunto como teste
    seed = SEED,
    image_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    color_mode = COLOR_MODE,
    label_mode = 'categorical',
)
# Out:
# Found 6400 files belonging to 4 classes.
# Using 4480 files for training.
# Found 6400 files belonging to 4 classes.
# Using 1920 files for validation.
# Found 6400 files belonging to 4 classes.
# Using 1920 files for validation.

# %%
# Cria modelo
model = Sequential([
    Conv2D(64, (3,3), activation='relu', input_shape=(*IMAGE_SIZE, 3)),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Conv2D(32, (2,2), activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(50, activation='relu'),
    Dense(4, activation='softmax')
])

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics='accuracy')

#Train the Convolutional Neural Network on the data
history = model.fit(train_dataset, epochs = EPOCHS, validation_data = validation_dataset,  callbacks=[early_stop])

# Plota os gráficos de perda e acurácia
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss / Accuracy')
plt.legend()
plt.show()

# Avalia o modelo no conjunto de teste
test_loss, test_accuracy = model.evaluate(test_dataset)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)

model.summary()

# Extract metrics from history object
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))

# Plot accuracy metrics
ax1.plot(acc, label='Training Accuracy', color='blue', linestyle='solid')
ax1.plot(val_acc, label='Validation Accuracy', color='orange', linestyle='dashed')
ax1.set_xlabel('Epoch', fontsize=12)
ax1.set_ylabel('Accuracy', fontsize=12)
ax1.set_title('Training and Validation Accuracy', fontsize=10)
ax1.grid()

# Plot loss metrics
ax2.plot(loss, label='Training Loss', color='blue', linestyle='solid')
ax2.plot(val_loss, label='Validation Loss', color='orange', linestyle='dashed')
ax2.set_xlabel('Epoch', fontsize=12)
ax2.set_ylabel('Loss', fontsize=12)
ax2.set_title('Training and Validation Loss', fontsize=10)
ax2.grid()

# Add legend and title to figure
fig.legend(loc='lower center', ncol=2, fontsize=10)
fig.suptitle('Model Training History', fontsize=16)

# Show the plot
plt.show()
# Out:
# Epoch 1/30
# 140/140 [==============================] - 72s 506ms/step - loss: 3.1217 - accuracy: 0.5147 - val_loss: 0.9245 - val_accuracy: 0.5620
# Epoch 2/30
# 140/140 [==============================] - 71s 507ms/step - loss: 0.8225 - accuracy: 0.6339 - val_loss: 0.8254 - val_accuracy: 0.6125
# Epoch 3/30
# 140/140 [==============================] - 75s 535ms/step - loss: 0.6483 - accuracy: 0.7270 - val_loss: 0.6897 - val_accuracy: 0.6875
# Epoch 4/30
# 140/140 [==============================] - 86s 616ms/step - loss: 0.5086 - accuracy: 0.7837 - val_loss: 0.6303 - val_accuracy: 0.7583
# Epoch 5/30
# 140/140 [==============================] - 101s 721ms/step - loss: 0.4640 - accuracy: 0.8083 - val_loss: 0.5298 - val_accuracy: 0.7635
# Epoch 6/30
# 140/140 [==============================] - 94s 672ms/step - loss: 0.3666 - accuracy: 0.8502 - val_loss: 0.4602 - val_accuracy: 0.8151
# Epoch 7/30
# 140/140 [==============================] - 77s 546ms/step - loss: 0.2752 - accuracy: 0.8895 - val_loss: 0.4578 - val_accuracy: 0.8255
# Epoch 8/30
# 140/140 [==============================] - 71s 507ms/step - loss: 0.2016 - accuracy: 0.9165 - val_loss: 0.5515 - val_accuracy: 0.8245
# Epoch 9/30
# 140/140 [==============================] - 75s 534ms/step - loss: 0.2192 - accuracy: 0.9199 - val_loss: 0.4425 - val_accuracy: 0.8422
# Epoch 10/30
# 140/140 [==============================] - 87s 616ms/step - loss: 0.1598 - accuracy: 0.9364 - val_loss: 0.4237 - val_accuracy: 0.8625
# Epoch 11/30
# 140/140 [==============================] - 104s 739ms/step - loss: 0.1228 - accuracy: 0.9527 - val_loss: 0.4580 - val_accuracy: 0.8453
# Epoch 12/30
# 140/140 [==============================] - 70s 498ms/step - loss: 0.1611 - accuracy: 0.9391 - val_loss: 0.5453 - val_accuracy: 0.8359
# Epoch 13/30
# 140/140 [==============================] - 85s 611ms/step - loss: 0.1212 - accuracy: 0.9551 - val_loss: 0.3413 - val_accuracy: 0.8828
# Epoch 14/30
# 140/140 [==============================] - 88s 629ms/step - loss: 0.0890 - accuracy: 0.9661 - val_loss: 0.3456 - val_accuracy: 0.8859
# Epoch 15/30
# 140/140 [==============================] - 79s 562ms/step - loss: 0.1606 - accuracy: 0.9386 - val_loss: 0.4080 - val_accuracy: 0.8781
# Epoch 16/30
# 140/140 [==============================] - 82s 584ms/step - loss: 0.1169 - accuracy: 0.9542 - val_loss: 0.3614 - val_accuracy: 0.8839
# Epoch 17/30
# 140/140 [==============================] - 82s 586ms/step - loss: 0.0851 - accuracy: 0.9658 - val_loss: 0.8736 - val_accuracy: 0.7901
# Epoch 18/30
# 140/140 [==============================] - 79s 562ms/step - loss: 0.1186 - accuracy: 0.9567 - val_loss: 0.6508 - val_accuracy: 0.8219
# Epoch 19/30
# 140/140 [==============================] - 78s 558ms/step - loss: 0.0807 - accuracy: 0.9674 - val_loss: 0.4113 - val_accuracy: 0.8885
# Epoch 20/30
# 140/140 [==============================] - 78s 558ms/step - loss: 0.0354 - accuracy: 0.9866 - val_loss: 0.3055 - val_accuracy: 0.9083
# Epoch 21/30
# 140/140 [==============================] - 83s 591ms/step - loss: 0.0608 - accuracy: 0.9779 - val_loss: 0.3263 - val_accuracy: 0.9125
# Epoch 22/30
# 140/140 [==============================] - 82s 582ms/step - loss: 0.0969 - accuracy: 0.9667 - val_loss: 0.4803 - val_accuracy: 0.8687
# Epoch 23/30
# 140/140 [==============================] - 77s 551ms/step - loss: 0.0769 - accuracy: 0.9730 - val_loss: 0.4820 - val_accuracy: 0.8771
# Epoch 24/30
# 140/140 [==============================] - 87s 620ms/step - loss: 0.0803 - accuracy: 0.9712 - val_loss: 0.3911 - val_accuracy: 0.9031
# Epoch 25/30
# 140/140 [==============================] - 82s 587ms/step - loss: 0.0330 - accuracy: 0.9877 - val_loss: 0.3581 - val_accuracy: 0.9177
# Epoch 26/30
# 140/140 [==============================] - 72s 513ms/step - loss: 0.0403 - accuracy: 0.9842 - val_loss: 0.3623 - val_accuracy: 0.9057
# Epoch 27/30
# 140/140 [==============================] - 72s 512ms/step - loss: 0.0790 - accuracy: 0.9741 - val_loss: 0.3165 - val_accuracy: 0.9089
# Epoch 28/30
# 140/140 [==============================] - 72s 516ms/step - loss: 0.0694 - accuracy: 0.9781 - val_loss: 0.4485 - val_accuracy: 0.8844
# Epoch 29/30
# 140/140 [==============================] - 95s 677ms/step - loss: 0.1448 - accuracy: 0.9516 - val_loss: 0.4688 - val_accuracy: 0.8745
# Epoch 30/30
# 140/140 [==============================] - 86s 612ms/step - loss: 0.0719 - accuracy: 0.9761 - val_loss: 0.8114 - val_accuracy: 0.8521
# 60/60 [==============================] - 6s 90ms/step - loss: 0.3581 - accuracy: 0.9177
# Test Loss: 0.3580796420574188
# Test Accuracy: 0.9177083373069763
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 29, 29, 32)        4128
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 100)               627300
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 4)                 204
#
# =================================================================
# Total params: 656,938
# Trainable params: 656,938
# Non-trainable params: 0
# _________________________________________________________________
