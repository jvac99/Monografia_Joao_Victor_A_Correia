# %%
import import_ipynb
from preprocessing_RGB import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# X:  6400
# X_train:  4480
# X_test:  1280
# X_val:  640
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 627,   45, 2240, 1568], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 627,   45, 2240, 1568], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# Unique Values: [0 1 2 3]
# Frequency Values: [ 627   45 2240 1568]
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo
model = DecisionTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.684375
# accuracy
# 0.684375
#
# f1_macro
# 0.6061552353640262
#
# precision
# 0.620781974261362
#
# recall
# 0.5938157556479833
#
# confusion_matrix
# [[ 89   0  45  45]
#  [  2   6   3   2]
#  [ 36   2 488 114]
#  [ 37   3 115 293]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5427    0.4972    0.5190       179
#  Moderate_Demented     0.5455    0.4615    0.5000        13
#       Non_Demented     0.7496    0.7625    0.7560       640
# Very_Mild_Demented     0.6454    0.6540    0.6497       448
#
#           accuracy                         0.6844      1280
#          macro avg     0.6208    0.5938    0.6062      1280
#       weighted avg     0.6821    0.6844    0.6830      1280
# {'accuracy': 0.684375,
#  'f1_macro': 0.6061552353640262,
#  'precision': 0.620781974261362,
#  'recall': 0.5938157556479833,
#  'confusion_matrix': array([[ 89,   0,  45,  45],
#         [  2,   6,   3,   2],
#         [ 36,   2, 488, 114],
#         [ 37,   3, 115, 293]], dtype=int64)}

# %%
# Criando o modelo
model = ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.67421875
# accuracy
# 0.67421875
#
# f1_macro
# 0.5368033379572101
#
# precision
# 0.5409815828550676
#
# recall
# 0.5330573690450611
#
# confusion_matrix
# [[ 91   1  34  53]
#  [  2   3   4   4]
#  [ 36   3 483 118]
#  [ 41   5 116 286]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5353    0.5084    0.5215       179
#  Moderate_Demented     0.2500    0.2308    0.2400        13
#       Non_Demented     0.7582    0.7547    0.7565       640
# Very_Mild_Demented     0.6204    0.6384    0.6293       448
#
#           accuracy                         0.6742      1280
#          macro avg     0.5410    0.5331    0.5368      1280
#       weighted avg     0.6737    0.6742    0.6738      1280
# {'accuracy': 0.67421875,
#  'f1_macro': 0.5368033379572101,
#  'precision': 0.5409815828550676,
#  'recall': 0.5330573690450611,
#  'confusion_matrix': array([[ 91,   1,  34,  53],
#         [  2,   3,   4,   4],
#         [ 36,   3, 483, 118],
#         [ 41,   5, 116, 286]], dtype=int64)}

# %%
# Criando o modelo de Random Forest
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.89375
# accuracy
# 0.89375
#
# f1_macro
# 0.7227902806211909
#
# precision
# 0.9393531674273086
#
# recall
# 0.6754309369052736
#
# confusion_matrix
# [[125   0  19  35]
#  [  0   2   5   6]
#  [  1   0 628  11]
#  [  0   0  59 389]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9921    0.6983    0.8197       179
#  Moderate_Demented     1.0000    0.1538    0.2667        13
#       Non_Demented     0.8833    0.9812    0.9297       640
# Very_Mild_Demented     0.8821    0.8683    0.8751       448
#
#           accuracy                         0.8938      1280
#          macro avg     0.9394    0.6754    0.7228      1280
#       weighted avg     0.8993    0.8938    0.8885      1280
# {'accuracy': 0.89375,
#  'f1_macro': 0.7227902806211909,
#  'precision': 0.9393531674273086,
#  'recall': 0.6754309369052736,
#  'confusion_matrix': array([[125,   0,  19,  35],
#         [  0,   2,   5,   6],
#         [  1,   0, 628,  11],
#         [  0,   0,  59, 389]], dtype=int64)}

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.95546875
# accuracy
# 0.95546875
#
# f1_macro
# 0.9523937843824881
#
# precision
# 0.9503267617411538
#
# recall
# 0.9557770725259378
#
# confusion_matrix
# [[162   0   9   8]
#  [  0  13   0   0]
#  [  3   1 629   7]
#  [  4   0  25 419]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9586    0.9050    0.9310       179
#  Moderate_Demented     0.9286    1.0000    0.9630        13
#       Non_Demented     0.9487    0.9828    0.9655       640
# Very_Mild_Demented     0.9654    0.9353    0.9501       448
#
#           accuracy                         0.9555      1280
#          macro avg     0.9503    0.9558    0.9524      1280
#       weighted avg     0.9557    0.9555    0.9553      1280
# {'accuracy': 0.95546875,
#  'f1_macro': 0.9523937843824881,
#  'precision': 0.9503267617411538,
#  'recall': 0.9557770725259378,
#  'confusion_matrix': array([[162,   0,   9,   8],
#         [  0,  13,   0,   0],
#         [  3,   1, 629,   7],
#         [  4,   0,  25, 419]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.92890625
# accuracy
# 0.92890625
#
# f1_macro
# 0.9442099780039819
#
# precision
# 0.949579169756821
#
# recall
# 0.9401551900438947
#
# confusion_matrix
# [[164   0   9   6]
#  [  0  13   0   0]
#  [  9   0 619  12]
#  [  3   0  52 393]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9318    0.9162    0.9239       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9103    0.9672    0.9379       640
# Very_Mild_Demented     0.9562    0.8772    0.9150       448
#
#           accuracy                         0.9289      1280
#          macro avg     0.9496    0.9402    0.9442      1280
#       weighted avg     0.9303    0.9289    0.9286      1280
# {'accuracy': 0.92890625,
#  'f1_macro': 0.9442099780039819,
#  'precision': 0.949579169756821,
#  'recall': 0.9401551900438947,
#  'confusion_matrix': array([[164,   0,   9,   6],
#         [  0,  13,   0,   0],
#         [  9,   0, 619,  12],
#         [  3,   0,  52, 393]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.8828125
# accuracy
# 0.8828125
#
# f1_macro
# 0.9057073403499608
#
# precision
# 0.9165799377418168
#
# recall
# 0.8966545914804469
#
# confusion_matrix
# [[145   0  18  16]
#  [  0  13   0   0]
#  [  8   0 587  45]
#  [  5   0  58 385]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9177    0.8101    0.8605       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8854    0.9172    0.9010       640
# Very_Mild_Demented     0.8632    0.8594    0.8613       448
#
#           accuracy                         0.8828      1280
#          macro avg     0.9166    0.8967    0.9057      1280
#       weighted avg     0.8833    0.8828    0.8824      1280
# {'accuracy': 0.8828125,
#  'f1_macro': 0.9057073403499608,
#  'precision': 0.9165799377418168,
#  'recall': 0.8966545914804469,
#  'confusion_matrix': array([[145,   0,  18,  16],
#         [  0,  13,   0,   0],
#         [  8,   0, 587,  45],
#         [  5,   0,  58, 385]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.48671875
# accuracy
# 0.48671875
#
# f1_macro
# 0.3309063893838364
#
# precision
# 0.33007540999049984
#
# recall
# 0.3546588188347965
#
# confusion_matrix
# [[ 89   0  39  51]
#  [  6   0   2   5]
#  [111   0 404 125]
#  [126   0 192 130]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2681    0.4972    0.3483       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.6342    0.6312    0.6327       640
# Very_Mild_Demented     0.4180    0.2902    0.3426       448
#
#           accuracy                         0.4867      1280
#          macro avg     0.3301    0.3547    0.3309      1280
#       weighted avg     0.5009    0.4867    0.4850      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.48671875,
#  'f1_macro': 0.3309063893838364,
#  'precision': 0.33007540999049984,
#  'recall': 0.3546588188347965,
#  'confusion_matrix': array([[ 89,   0,  39,  51],
#         [  6,   0,   2,   5],
#         [111,   0, 404, 125],
#         [126,   0, 192, 130]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.5234375
# accuracy
# 0.5234375
#
# f1_macro
# 0.42334161523190617
#
# precision
# 0.4054706372819362
#
# recall
# 0.5502897373227331
#
# confusion_matrix
# [[ 95  13  18  53]
#  [  4   9   0   0]
#  [ 93  17 426 104]
#  [109  21 178 140]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.3156    0.5307    0.3958       179
#  Moderate_Demented     0.1500    0.6923    0.2466        13
#       Non_Demented     0.6849    0.6656    0.6751       640
# Very_Mild_Demented     0.4714    0.3125    0.3758       448
#
#           accuracy                         0.5234      1280
#          macro avg     0.4055    0.5503    0.4233      1280
#       weighted avg     0.5531    0.5234    0.5270      1280
# {'accuracy': 0.5234375,
#  'f1_macro': 0.42334161523190617,
#  'precision': 0.4054706372819362,
#  'recall': 0.5502897373227331,
#  'confusion_matrix': array([[ 95,  13,  18,  53],
#         [  4,   9,   0,   0],
#         [ 93,  17, 426, 104],
#         [109,  21, 178, 140]], dtype=int64)}

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)

# %%
# Criando o modelo SVM
model = SVC(class_weight = "balanced",  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9751782471391962
#
# precision
# 0.9753001200480192
#
# recall
# 0.9751006958300081
#
# confusion_matrix
# [[172   0   6   1]
#  [  0  13   0   0]
#  [  3   0 627  10]
#  [  5   0  13 430]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.96      0.96      0.96       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.97      0.98      0.98       640
# Very_Mild_Demented       0.98      0.96      0.97       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.98      0.98      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9751782471391962,
#  'precision': 0.9753001200480192,
#  'recall': 0.9751006958300081,
#  'confusion_matrix': array([[172,   0,   6,   1],
#         [  0,  13,   0,   0],
#         [  3,   0, 627,  10],
#         [  5,   0,  13, 430]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.91015625
# accuracy
# 0.91015625
#
# f1_macro
# 0.9227595741042577
#
# precision
# 0.9432957097514689
#
# recall
# 0.9076416600159617
#
# confusion_matrix
# [[141   0  14  24]
#  [  0  13   0   0]
#  [  1   0 618  21]
#  [  3   0  52 393]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9724    0.7877    0.8704       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9035    0.9656    0.9335       640
# Very_Mild_Demented     0.8973    0.8772    0.8871       448
#
#           accuracy                         0.9102      1280
#          macro avg     0.9433    0.9076    0.9228      1280
#       weighted avg     0.9119    0.9102    0.9091      1280
# {'accuracy': 0.91015625,
#  'f1_macro': 0.9227595741042577,
#  'precision': 0.9432957097514689,
#  'recall': 0.9076416600159617,
#  'confusion_matrix': array([[141,   0,  14,  24],
#         [  0,  13,   0,   0],
#         [  1,   0, 618,  21],
#         [  3,   0,  52, 393]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.35625
# accuracy
# 0.35625
#
# f1_macro
# 0.251124082615516
#
# precision
# 0.2506253496179749
#
# recall
# 0.2516978002793296
#
# confusion_matrix
# [[ 51   0 120   8]
#  [  3   0   7   3]
#  [ 46   0 272 322]
#  [ 75   0 240 133]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2914    0.2849    0.2881       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.4257    0.4250    0.4253       640
# Very_Mild_Demented     0.2854    0.2969    0.2910       448
#
#           accuracy                         0.3563      1280
#          macro avg     0.2506    0.2517    0.2511      1280
#       weighted avg     0.3535    0.3563    0.3548      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.35625,
#  'f1_macro': 0.251124082615516,
#  'precision': 0.2506253496179749,
#  'recall': 0.2516978002793296,
#  'confusion_matrix': array([[ 51,   0, 120,   8],
#         [  3,   0,   7,   3],
#         [ 46,   0, 272, 322],
#         [ 75,   0, 240, 133]], dtype=int64)}

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9578125
# accuracy
# 0.9578125
#
# f1_macro
# 0.9197703235021888
#
# precision
# 0.9746193769719854
#
# recall
# 0.8804133780849039
#
# confusion_matrix
# [[160   0   7  12]
#  [  0   9   2   2]
#  [  0   0 633   7]
#  [  1   0  23 424]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.89      0.94       179
#  Moderate_Demented       1.00      0.69      0.82        13
#       Non_Demented       0.95      0.99      0.97       640
# Very_Mild_Demented       0.95      0.95      0.95       448
#
#           accuracy                           0.96      1280
#          macro avg       0.97      0.88      0.92      1280
#       weighted avg       0.96      0.96      0.96      1280
# {'accuracy': 0.9578125,
#  'f1_macro': 0.9197703235021888,
#  'precision': 0.9746193769719854,
#  'recall': 0.8804133780849039,
#  'confusion_matrix': array([[160,   0,   7,  12],
#         [  0,   9,   2,   2],
#         [  0,   0, 633,   7],
#         [  1,   0,  23, 424]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = GradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.87578125
# accuracy
# 0.87578125
#
# f1_macro
# 0.7783652241872472
#
# precision
# 0.8177235291856464
#
# recall
# 0.7539399431748419
#
# confusion_matrix
# [[118   1  11  49]
#  [  0   7   2   4]
#  [  5   4 605  26]
#  [  0   0  57 391]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9593    0.6592    0.7815       179
#  Moderate_Demented     0.5833    0.5385    0.5600        13
#       Non_Demented     0.8963    0.9453    0.9202       640
# Very_Mild_Demented     0.8319    0.8728    0.8519       448
#
#           accuracy                         0.8758      1280
#          macro avg     0.8177    0.7539    0.7784      1280
#       weighted avg     0.8794    0.8758    0.8732      1280
# {'accuracy': 0.87578125,
#  'f1_macro': 0.7783652241872472,
#  'precision': 0.8177235291856464,
#  'recall': 0.7539399431748419,
#  'confusion_matrix': array([[118,   1,  11,  49],
#         [  0,   7,   2,   4],
#         [  5,   4, 605,  26],
#         [  0,   0,  57, 391]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.57890625
# accuracy
# 0.57890625
#
# f1_macro
# 0.5044799911228397
#
# precision
# 0.6386096113301423
#
# recall
# 0.4577148497452268
#
# confusion_matrix
# [[ 42   0  66  71]
#  [  1   5   3   4]
#  [ 28   0 504 108]
#  [ 30   0 228 190]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.4158    0.2346    0.3000       179
#  Moderate_Demented     1.0000    0.3846    0.5556        13
#       Non_Demented     0.6292    0.7875    0.6995       640
# Very_Mild_Demented     0.5094    0.4241    0.4629       448
#
#           accuracy                         0.5789      1280
#          macro avg     0.6386    0.4577    0.5045      1280
#       weighted avg     0.5612    0.5789    0.5594      1280
# {'accuracy': 0.57890625,
#  'f1_macro': 0.5044799911228397,
#  'precision': 0.6386096113301423,
#  'recall': 0.4577148497452268,
#  'confusion_matrix': array([[ 42,   0,  66,  71],
#         [  1,   5,   3,   4],
#         [ 28,   0, 504, 108],
#         [ 30,   0, 228, 190]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = HistGradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96640625
# accuracy
# 0.96640625
#
# f1_macro
# 0.9247670239259262
#
# precision
# 0.9800774607340359
#
# recall
# 0.8852109264687826
#
# confusion_matrix
# [[159   0   6  14]
#  [  0   9   1   3]
#  [  0   0 636   4]
#  [  0   0  15 433]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.8883    0.9408       179
#  Moderate_Demented     1.0000    0.6923    0.8182        13
#       Non_Demented     0.9666    0.9938    0.9800       640
# Very_Mild_Demented     0.9537    0.9665    0.9601       448
#
#           accuracy                         0.9664      1280
#          macro avg     0.9801    0.8852    0.9248      1280
#       weighted avg     0.9671    0.9664    0.9659      1280
# {'accuracy': 0.96640625,
#  'f1_macro': 0.9247670239259262,
#  'precision': 0.9800774607340359,
#  'recall': 0.8852109264687826,
#  'confusion_matrix': array([[159,   0,   6,  14],
#         [  0,   9,   1,   3],
#         [  0,   0, 636,   4],
#         [  0,   0,  15, 433]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = LinearDiscriminantAnalysis()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.83515625
# accuracy
# 0.83515625
#
# f1_macro
# 0.8747940575409934
#
# precision
# 0.8799555540840233
#
# recall
# 0.8704842752394254
#
# confusion_matrix
# [[146   0  13  20]
#  [  0  13   0   0]
#  [ 10   0 545  85]
#  [ 10   0  73 365]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.8795    0.8156    0.8464       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.8637    0.8516    0.8576       640
# Very_Mild_Demented     0.7766    0.8147    0.7952       448
#
#           accuracy                         0.8352      1280
#          macro avg     0.8800    0.8705    0.8748      1280
#       weighted avg     0.8368    0.8352    0.8356      1280
# {'accuracy': 0.83515625,
#  'f1_macro': 0.8747940575409934,
#  'precision': 0.8799555540840233,
#  'recall': 0.8704842752394254,
#  'confusion_matrix': array([[146,   0,  13,  20],
#         [  0,  13,   0,   0],
#         [ 10,   0, 545,  85],
#         [ 10,   0,  73, 365]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = DummyClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.5
# accuracy
# 0.5
#
# f1_macro
# 0.16666666666666666
#
# precision
# 0.125
#
# recall
# 0.25
#
# confusion_matrix
# [[  0   0 179   0]
#  [  0   0  13   0]
#  [  0   0 640   0]
#  [  0   0 448   0]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.0000    0.0000    0.0000       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.5000    1.0000    0.6667       640
# Very_Mild_Demented     0.0000    0.0000    0.0000       448
#
#           accuracy                         0.5000      1280
#          macro avg     0.1250    0.2500    0.1667      1280
#       weighted avg     0.2500    0.5000    0.3333      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.5,
#  'f1_macro': 0.16666666666666666,
#  'precision': 0.125,
#  'recall': 0.25,
#  'confusion_matrix': array([[  0,   0, 179,   0],
#         [  0,   0,  13,   0],
#         [  0,   0, 640,   0],
#         [  0,   0, 448,   0]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = RidgeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96875
# accuracy
# 0.96875
#
# f1_macro
# 0.9721159198571606
#
# precision
# 0.976404827460702
#
# recall
# 0.9681158968475658
#
# confusion_matrix
# [[166   0   5   8]
#  [  0  13   0   0]
#  [  0   0 632   8]
#  [  5   0  14 429]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9708    0.9274    0.9486       179
#  Moderate_Demented     1.0000    1.0000    1.0000        13
#       Non_Demented     0.9708    0.9875    0.9791       640
# Very_Mild_Demented     0.9640    0.9576    0.9608       448
#
#           accuracy                         0.9688      1280
#          macro avg     0.9764    0.9681    0.9721      1280
#       weighted avg     0.9687    0.9688    0.9686      1280
# {'accuracy': 0.96875,
#  'f1_macro': 0.9721159198571606,
#  'precision': 0.976404827460702,
#  'recall': 0.9681158968475658,
#  'confusion_matrix': array([[166,   0,   5,   8],
#         [  0,  13,   0,   0],
#         [  0,   0, 632,   8],
#         [  5,   0,  14, 429]], dtype=int64)}
