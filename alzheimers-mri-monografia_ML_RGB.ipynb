# %%
import import_ipynb
from preprocessing_RGB import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# X:  6400
# X_train:  4480
# X_test:  1280
# X_val:  640
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([ 627,   45, 2240, 1568], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([ 627,   45, 2240, 1568], dtype=int64))
# (array(['Mild_Demented', 'Moderate_Demented', 'Non_Demented',
#        'Very_Mild_Demented'], dtype='<U18'), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# (array([0, 1, 2, 3]), array([179,  13, 640, 448], dtype=int64))
# Unique Values: [0 1 2 3]
# Frequency Values: [ 627   45 2240 1568]
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo de Random Forest
model = DecisionTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.684375
# accuracy
# 0.684375
#
# f1_macro
# 0.6061552353640262
#
# precision
# 0.620781974261362
#
# recall
# 0.5938157556479833
#
# confusion_matrix
# [[ 89   0  45  45]
#  [  2   6   3   2]
#  [ 36   2 488 114]
#  [ 37   3 115 293]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.54      0.50      0.52       179
#  Moderate_Demented       0.55      0.46      0.50        13
#       Non_Demented       0.75      0.76      0.76       640
# Very_Mild_Demented       0.65      0.65      0.65       448
#
#           accuracy                           0.68      1280
#          macro avg       0.62      0.59      0.61      1280
#       weighted avg       0.68      0.68      0.68      1280
# {'accuracy': 0.684375,
#  'f1_macro': 0.6061552353640262,
#  'precision': 0.620781974261362,
#  'recall': 0.5938157556479833,
#  'confusion_matrix': array([[ 89,   0,  45,  45],
#         [  2,   6,   3,   2],
#         [ 36,   2, 488, 114],
#         [ 37,   3, 115, 293]], dtype=int64)}

# %%
# Criando o modelo de Random Forest
model = ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.67421875
# accuracy
# 0.67421875
#
# f1_macro
# 0.5368033379572101
#
# precision
# 0.5409815828550676
#
# recall
# 0.5330573690450611
#
# confusion_matrix
# [[ 91   1  34  53]
#  [  2   3   4   4]
#  [ 36   3 483 118]
#  [ 41   5 116 286]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.54      0.51      0.52       179
#  Moderate_Demented       0.25      0.23      0.24        13
#       Non_Demented       0.76      0.75      0.76       640
# Very_Mild_Demented       0.62      0.64      0.63       448
#
#           accuracy                           0.67      1280
#          macro avg       0.54      0.53      0.54      1280
#       weighted avg       0.67      0.67      0.67      1280
# {'accuracy': 0.67421875,
#  'f1_macro': 0.5368033379572101,
#  'precision': 0.5409815828550676,
#  'recall': 0.5330573690450611,
#  'confusion_matrix': array([[ 91,   1,  34,  53],
#         [  2,   3,   4,   4],
#         [ 36,   3, 483, 118],
#         [ 41,   5, 116, 286]], dtype=int64)}

# %%
# Criando o modelo de Random Forest
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.89375
# accuracy
# 0.89375
#
# f1_macro
# 0.7227902806211909
#
# precision
# 0.9393531674273086
#
# recall
# 0.6754309369052736
#
# confusion_matrix
# [[125   0  19  35]
#  [  0   2   5   6]
#  [  1   0 628  11]
#  [  0   0  59 389]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.70      0.82       179
#  Moderate_Demented       1.00      0.15      0.27        13
#       Non_Demented       0.88      0.98      0.93       640
# Very_Mild_Demented       0.88      0.87      0.88       448
#
#           accuracy                           0.89      1280
#          macro avg       0.94      0.68      0.72      1280
#       weighted avg       0.90      0.89      0.89      1280
# {'accuracy': 0.89375,
#  'f1_macro': 0.7227902806211909,
#  'precision': 0.9393531674273086,
#  'recall': 0.6754309369052736,
#  'confusion_matrix': array([[125,   0,  19,  35],
#         [  0,   2,   5,   6],
#         [  1,   0, 628,  11],
#         [  0,   0,  59, 389]], dtype=int64)}

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.95546875
# accuracy
# 0.95546875
#
# f1_macro
# 0.9523937843824881
#
# precision
# 0.9503267617411538
#
# recall
# 0.9557770725259378
#
# confusion_matrix
# [[162   0   9   8]
#  [  0  13   0   0]
#  [  3   1 629   7]
#  [  4   0  25 419]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.96      0.91      0.93       179
#  Moderate_Demented       0.93      1.00      0.96        13
#       Non_Demented       0.95      0.98      0.97       640
# Very_Mild_Demented       0.97      0.94      0.95       448
#
#           accuracy                           0.96      1280
#          macro avg       0.95      0.96      0.95      1280
#       weighted avg       0.96      0.96      0.96      1280
# {'accuracy': 0.95546875,
#  'f1_macro': 0.9523937843824881,
#  'precision': 0.9503267617411538,
#  'recall': 0.9557770725259378,
#  'confusion_matrix': array([[162,   0,   9,   8],
#         [  0,  13,   0,   0],
#         [  3,   1, 629,   7],
#         [  4,   0,  25, 419]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.92890625
# accuracy
# 0.92890625
#
# f1_macro
# 0.9442099780039819
#
# precision
# 0.949579169756821
#
# recall
# 0.9401551900438947
#
# confusion_matrix
# [[164   0   9   6]
#  [  0  13   0   0]
#  [  9   0 619  12]
#  [  3   0  52 393]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.93      0.92      0.92       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.91      0.97      0.94       640
# Very_Mild_Demented       0.96      0.88      0.92       448
#
#           accuracy                           0.93      1280
#          macro avg       0.95      0.94      0.94      1280
#       weighted avg       0.93      0.93      0.93      1280
# {'accuracy': 0.92890625,
#  'f1_macro': 0.9442099780039819,
#  'precision': 0.949579169756821,
#  'recall': 0.9401551900438947,
#  'confusion_matrix': array([[164,   0,   9,   6],
#         [  0,  13,   0,   0],
#         [  9,   0, 619,  12],
#         [  3,   0,  52, 393]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1, early_stopping = True)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.78359375
# accuracy
# 0.78359375
#
# f1_macro
# 0.7576573139159923
#
# precision
# 0.791637696301925
#
# recall
# 0.7985809058260176
#
# confusion_matrix
# [[ 92   3   9  75]
#  [  0  13   0   0]
#  [  2   3 484 151]
#  [  0   2  32 414]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.98      0.51      0.67       179
#  Moderate_Demented       0.62      1.00      0.76        13
#       Non_Demented       0.92      0.76      0.83       640
# Very_Mild_Demented       0.65      0.92      0.76       448
#
#           accuracy                           0.78      1280
#          macro avg       0.79      0.80      0.76      1280
#       weighted avg       0.83      0.78      0.78      1280
# {'accuracy': 0.78359375,
#  'f1_macro': 0.7576573139159923,
#  'precision': 0.791637696301925,
#  'recall': 0.7985809058260176,
#  'confusion_matrix': array([[ 92,   3,   9,  75],
#         [  0,  13,   0,   0],
#         [  2,   3, 484, 151],
#         [  0,   2,  32, 414]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.8828125
# accuracy
# 0.8828125
#
# f1_macro
# 0.9057073403499608
#
# precision
# 0.9165799377418168
#
# recall
# 0.8966545914804469
#
# confusion_matrix
# [[145   0  18  16]
#  [  0  13   0   0]
#  [  8   0 587  45]
#  [  5   0  58 385]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.92      0.81      0.86       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.89      0.92      0.90       640
# Very_Mild_Demented       0.86      0.86      0.86       448
#
#           accuracy                           0.88      1280
#          macro avg       0.92      0.90      0.91      1280
#       weighted avg       0.88      0.88      0.88      1280
# {'accuracy': 0.8828125,
#  'f1_macro': 0.9057073403499608,
#  'precision': 0.9165799377418168,
#  'recall': 0.8966545914804469,
#  'confusion_matrix': array([[145,   0,  18,  16],
#         [  0,  13,   0,   0],
#         [  8,   0, 587,  45],
#         [  5,   0,  58, 385]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.48671875
# accuracy
# 0.48671875
#
# f1_macro
# 0.3309063893838364
#
# precision
# 0.33007540999049984
#
# recall
# 0.3546588188347965
#
# confusion_matrix
# [[ 89   0  39  51]
#  [  6   0   2   5]
#  [111   0 404 125]
#  [126   0 192 130]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.27      0.50      0.35       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.63      0.63      0.63       640
# Very_Mild_Demented       0.42      0.29      0.34       448
#
#           accuracy                           0.49      1280
#          macro avg       0.33      0.35      0.33      1280
#       weighted avg       0.50      0.49      0.48      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.48671875,
#  'f1_macro': 0.3309063893838364,
#  'precision': 0.33007540999049984,
#  'recall': 0.3546588188347965,
#  'confusion_matrix': array([[ 89,   0,  39,  51],
#         [  6,   0,   2,   5],
#         [111,   0, 404, 125],
#         [126,   0, 192, 130]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.5234375
# accuracy
# 0.5234375
#
# f1_macro
# 0.42334161523190617
#
# precision
# 0.4054706372819362
#
# recall
# 0.5502897373227331
#
# confusion_matrix
# [[ 95  13  18  53]
#  [  4   9   0   0]
#  [ 93  17 426 104]
#  [109  21 178 140]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.32      0.53      0.40       179
#  Moderate_Demented       0.15      0.69      0.25        13
#       Non_Demented       0.68      0.67      0.68       640
# Very_Mild_Demented       0.47      0.31      0.38       448
#
#           accuracy                           0.52      1280
#          macro avg       0.41      0.55      0.42      1280
#       weighted avg       0.55      0.52      0.53      1280
# {'accuracy': 0.5234375,
#  'f1_macro': 0.42334161523190617,
#  'precision': 0.4054706372819362,
#  'recall': 0.5502897373227331,
#  'confusion_matrix': array([[ 95,  13,  18,  53],
#         [  4,   9,   0,   0],
#         [ 93,  17, 426, 104],
#         [109,  21, 178, 140]], dtype=int64)}

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.7453125
# accuracy
# 0.7453125
#
# f1_macro
# 0.4936998549449191
#
# precision
# 0.5876074225947914
#
# recall
# 0.4787098463687151
#
# confusion_matrix
# [[ 53   0  35  91]
#  [  0   0   2  11]
#  [  5   0 586  49]
#  [  1   0 132 315]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.90      0.30      0.45       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.78      0.92      0.84       640
# Very_Mild_Demented       0.68      0.70      0.69       448
#
#           accuracy                           0.75      1280
#          macro avg       0.59      0.48      0.49      1280
#       weighted avg       0.75      0.75      0.72      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.7453125,
#  'f1_macro': 0.4936998549449191,
#  'precision': 0.5876074225947914,
#  'recall': 0.4787098463687151,
#  'confusion_matrix': array([[ 53,   0,  35,  91],
#         [  0,   0,   2,  11],
#         [  5,   0, 586,  49],
#         [  1,   0, 132, 315]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9703125
# accuracy
# 0.9703125
#
# f1_macro
# 0.9751782471391962
#
# precision
# 0.9753001200480192
#
# recall
# 0.9751006958300081
#
# confusion_matrix
# [[172   0   6   1]
#  [  0  13   0   0]
#  [  3   0 627  10]
#  [  5   0  13 430]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.96      0.96      0.96       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.97      0.98      0.98       640
# Very_Mild_Demented       0.98      0.96      0.97       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.98      0.98      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.9703125,
#  'f1_macro': 0.9751782471391962,
#  'precision': 0.9753001200480192,
#  'recall': 0.9751006958300081,
#  'confusion_matrix': array([[172,   0,   6,   1],
#         [  0,  13,   0,   0],
#         [  3,   0, 627,  10],
#         [  5,   0,  13, 430]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.91015625
# accuracy
# 0.91015625
#
# f1_macro
# 0.9227595741042577
#
# precision
# 0.9432957097514689
#
# recall
# 0.9076416600159617
#
# confusion_matrix
# [[141   0  14  24]
#  [  0  13   0   0]
#  [  1   0 618  21]
#  [  3   0  52 393]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.97      0.79      0.87       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.90      0.97      0.93       640
# Very_Mild_Demented       0.90      0.88      0.89       448
#
#           accuracy                           0.91      1280
#          macro avg       0.94      0.91      0.92      1280
#       weighted avg       0.91      0.91      0.91      1280
# {'accuracy': 0.91015625,
#  'f1_macro': 0.9227595741042577,
#  'precision': 0.9432957097514689,
#  'recall': 0.9076416600159617,
#  'confusion_matrix': array([[141,   0,  14,  24],
#         [  0,  13,   0,   0],
#         [  1,   0, 618,  21],
#         [  3,   0,  52, 393]], dtype=int64)}

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.35625
# accuracy
# 0.35625
#
# f1_macro
# 0.251124082615516
#
# precision
# 0.2506253496179749
#
# recall
# 0.2516978002793296
#
# confusion_matrix
# [[ 51   0 120   8]
#  [  3   0   7   3]
#  [ 46   0 272 322]
#  [ 75   0 240 133]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.29      0.28      0.29       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.43      0.42      0.43       640
# Very_Mild_Demented       0.29      0.30      0.29       448
#
#           accuracy                           0.36      1280
#          macro avg       0.25      0.25      0.25      1280
#       weighted avg       0.35      0.36      0.35      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.35625,
#  'f1_macro': 0.251124082615516,
#  'precision': 0.2506253496179749,
#  'recall': 0.2516978002793296,
#  'confusion_matrix': array([[ 51,   0, 120,   8],
#         [  3,   0,   7,   3],
#         [ 46,   0, 272, 322],
#         [ 75,   0, 240, 133]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.7453125
# accuracy
# 0.7453125
#
# f1_macro
# 0.4936998549449191
#
# precision
# 0.5876074225947914
#
# recall
# 0.4787098463687151
#
# confusion_matrix
# [[ 53   0  35  91]
#  [  0   0   2  11]
#  [  5   0 586  49]
#  [  1   0 132 315]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.90      0.30      0.45       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.78      0.92      0.84       640
# Very_Mild_Demented       0.68      0.70      0.69       448
#
#           accuracy                           0.75      1280
#          macro avg       0.59      0.48      0.49      1280
#       weighted avg       0.75      0.75      0.72      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.7453125,
#  'f1_macro': 0.4936998549449191,
#  'precision': 0.5876074225947914,
#  'recall': 0.4787098463687151,
#  'confusion_matrix': array([[ 53,   0,  35,  91],
#         [  0,   0,   2,  11],
#         [  5,   0, 586,  49],
#         [  1,   0, 132, 315]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", class_weight = "balanced", C = 100,  random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.99140625
# accuracy
# 0.99140625
#
# f1_macro
# 0.9921616240064969
#
# precision
# 0.9933366737054061
#
# recall
# 0.9910093899640862
#
# confusion_matrix
# [[175   0   4   0]
#  [  0  13   0   0]
#  [  1   0 637   2]
#  [  1   0   3 444]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.98      0.98       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.99      1.00      0.99       640
# Very_Mild_Demented       1.00      0.99      0.99       448
#
#           accuracy                           0.99      1280
#          macro avg       0.99      0.99      0.99      1280
#       weighted avg       0.99      0.99      0.99      1280
# {'accuracy': 0.99140625,
#  'f1_macro': 0.9921616240064969,
#  'precision': 0.9933366737054061,
#  'recall': 0.9910093899640862,
#  'confusion_matrix': array([[175,   0,   4,   0],
#         [  0,  13,   0,   0],
#         [  1,   0, 637,   2],
#         [  1,   0,   3, 444]], dtype=int64)}

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9578125
# accuracy
# 0.9578125
#
# f1_macro
# 0.9197703235021888
#
# precision
# 0.9746193769719854
#
# recall
# 0.8804133780849039
#
# confusion_matrix
# [[160   0   7  12]
#  [  0   9   2   2]
#  [  0   0 633   7]
#  [  1   0  23 424]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.89      0.94       179
#  Moderate_Demented       1.00      0.69      0.82        13
#       Non_Demented       0.95      0.99      0.97       640
# Very_Mild_Demented       0.95      0.95      0.95       448
#
#           accuracy                           0.96      1280
#          macro avg       0.97      0.88      0.92      1280
#       weighted avg       0.96      0.96      0.96      1280
# {'accuracy': 0.9578125,
#  'f1_macro': 0.9197703235021888,
#  'precision': 0.9746193769719854,
#  'recall': 0.8804133780849039,
#  'confusion_matrix': array([[160,   0,   7,  12],
#         [  0,   9,   2,   2],
#         [  0,   0, 633,   7],
#         [  1,   0,  23, 424]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = GradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.9578125
# accuracy
# 0.9578125
#
# f1_macro
# 0.9197703235021888
#
# precision
# 0.9746193769719854
#
# recall
# 0.8804133780849039
#
# confusion_matrix
# [[160   0   7  12]
#  [  0   9   2   2]
#  [  0   0 633   7]
#  [  1   0  23 424]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.99      0.89      0.94       179
#  Moderate_Demented       1.00      0.69      0.82        13
#       Non_Demented       0.95      0.99      0.97       640
# Very_Mild_Demented       0.95      0.95      0.95       448
#
#           accuracy                           0.96      1280
#          macro avg       0.97      0.88      0.92      1280
#       weighted avg       0.96      0.96      0.96      1280
# {'accuracy': 0.9578125,
#  'f1_macro': 0.9197703235021888,
#  'precision': 0.9746193769719854,
#  'recall': 0.8804133780849039,
#  'confusion_matrix': array([[160,   0,   7,  12],
#         [  0,   9,   2,   2],
#         [  0,   0, 633,   7],
#         [  1,   0,  23, 424]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = AdaBoostClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.57890625
# accuracy
# 0.57890625
#
# f1_macro
# 0.5044799911228397
#
# precision
# 0.6386096113301423
#
# recall
# 0.4577148497452268
#
# confusion_matrix
# [[ 42   0  66  71]
#  [  1   5   3   4]
#  [ 28   0 504 108]
#  [ 30   0 228 190]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.42      0.23      0.30       179
#  Moderate_Demented       1.00      0.38      0.56        13
#       Non_Demented       0.63      0.79      0.70       640
# Very_Mild_Demented       0.51      0.42      0.46       448
#
#           accuracy                           0.58      1280
#          macro avg       0.64      0.46      0.50      1280
#       weighted avg       0.56      0.58      0.56      1280
# {'accuracy': 0.57890625,
#  'f1_macro': 0.5044799911228397,
#  'precision': 0.6386096113301423,
#  'recall': 0.4577148497452268,
#  'confusion_matrix': array([[ 42,   0,  66,  71],
#         [  1,   5,   3,   4],
#         [ 28,   0, 504, 108],
#         [ 30,   0, 228, 190]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = HistGradientBoostingClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96640625
# accuracy
# 0.96640625
#
# f1_macro
# 0.9247670239259262
#
# precision
# 0.9800774607340359
#
# recall
# 0.8852109264687826
#
# confusion_matrix
# [[159   0   6  14]
#  [  0   9   1   3]
#  [  0   0 636   4]
#  [  0   0  15 433]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       1.00      0.89      0.94       179
#  Moderate_Demented       1.00      0.69      0.82        13
#       Non_Demented       0.97      0.99      0.98       640
# Very_Mild_Demented       0.95      0.97      0.96       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.89      0.92      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.96640625,
#  'f1_macro': 0.9247670239259262,
#  'precision': 0.9800774607340359,
#  'recall': 0.8852109264687826,
#  'confusion_matrix': array([[159,   0,   6,  14],
#         [  0,   9,   1,   3],
#         [  0,   0, 636,   4],
#         [  0,   0,  15, 433]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = LinearDiscriminantAnalysis()
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.83515625
# accuracy
# 0.83515625
#
# f1_macro
# 0.8747940575409934
#
# precision
# 0.8799555540840233
#
# recall
# 0.8704842752394254
#
# confusion_matrix
# [[146   0  13  20]
#  [  0  13   0   0]
#  [ 10   0 545  85]
#  [ 10   0  73 365]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.88      0.82      0.85       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.86      0.85      0.86       640
# Very_Mild_Demented       0.78      0.81      0.80       448
#
#           accuracy                           0.84      1280
#          macro avg       0.88      0.87      0.87      1280
#       weighted avg       0.84      0.84      0.84      1280
# {'accuracy': 0.83515625,
#  'f1_macro': 0.8747940575409934,
#  'precision': 0.8799555540840233,
#  'recall': 0.8704842752394254,
#  'confusion_matrix': array([[146,   0,  13,  20],
#         [  0,  13,   0,   0],
#         [ 10,   0, 545,  85],
#         [ 10,   0,  73, 365]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = DummyClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.5
# accuracy
# 0.5
#
# f1_macro
# 0.16666666666666666
#
# precision
# 0.125
#
# recall
# 0.25
#
# confusion_matrix
# [[  0   0 179   0]
#  [  0   0  13   0]
#  [  0   0 640   0]
#  [  0   0 448   0]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.00      0.00      0.00       179
#  Moderate_Demented       0.00      0.00      0.00        13
#       Non_Demented       0.50      1.00      0.67       640
# Very_Mild_Demented       0.00      0.00      0.00       448
#
#           accuracy                           0.50      1280
#          macro avg       0.12      0.25      0.17      1280
#       weighted avg       0.25      0.50      0.33      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.5,
#  'f1_macro': 0.16666666666666666,
#  'precision': 0.125,
#  'recall': 0.25,
#  'confusion_matrix': array([[  0,   0, 179,   0],
#         [  0,   0,  13,   0],
#         [  0,   0, 640,   0],
#         [  0,   0, 448,   0]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
model = RidgeClassifier(random_state = SEED)
model_application(model, X_train_flatten, y_train, X_test_flatten, y_test, target_names)
# Out:
# 0.96875
# accuracy
# 0.96875
#
# f1_macro
# 0.9721159198571606
#
# precision
# 0.976404827460702
#
# recall
# 0.9681158968475658
#
# confusion_matrix
# [[166   0   5   8]
#  [  0  13   0   0]
#  [  0   0 632   8]
#  [  5   0  14 429]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.97      0.93      0.95       179
#  Moderate_Demented       1.00      1.00      1.00        13
#       Non_Demented       0.97      0.99      0.98       640
# Very_Mild_Demented       0.96      0.96      0.96       448
#
#           accuracy                           0.97      1280
#          macro avg       0.98      0.97      0.97      1280
#       weighted avg       0.97      0.97      0.97      1280
# {'accuracy': 0.96875,
#  'f1_macro': 0.9721159198571606,
#  'precision': 0.976404827460702,
#  'recall': 0.9681158968475658,
#  'confusion_matrix': array([[166,   0,   5,   8],
#         [  0,  13,   0,   0],
#         [  0,   0, 632,   8],
#         [  5,   0,  14, 429]], dtype=int64)}
