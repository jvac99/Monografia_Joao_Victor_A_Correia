# %%
import import_ipynb
from preprocessing_RGB import *
from imports.imports_common_models_ML import *
# Out:
# importing Jupyter notebook from preprocessing_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset_RGB.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %% [markdown]
# #### Criando modelos

# %%
# Criando o modelo de Random Forest
model = tree.DecisionTreeClassifier(random_state = SEED)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.703125
# accuracy
# 0.703125
#
# f1_macro
# 0.5755497520749453
#
# precision
# 0.5712128788565396
#
# recall
# 0.5857931173041299
#
# confusion_matrix
# [[145   3  61  67]
#  [  3   7   7   2]
#  [ 50   7 762 141]
#  [ 48  10 171 436]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.59      0.53      0.56       276
#            1       0.26      0.37      0.30        19
#            2       0.76      0.79      0.78       960
#            3       0.67      0.66      0.67       665
#
#     accuracy                           0.70      1920
#    macro avg       0.57      0.59      0.58      1920
# weighted avg       0.70      0.70      0.70      1920
# {'accuracy': 0.703125,
#  'f1_macro': 0.5755497520749453,
#  'precision': 0.5712128788565396,
#  'recall': 0.5857931173041299,
#  'confusion_matrix': array([[145,   3,  61,  67],
#         [  3,   7,   7,   2],
#         [ 50,   7, 762, 141],
#         [ 48,  10, 171, 436]], dtype=int64),
#  'classification_report': '              precision    recall  f1-score   support\n\n           0       0.59      0.53      0.56       276\n           1       0.26      0.37      0.30        19\n           2       0.76      0.79      0.78       960\n           3       0.67      0.66      0.67       665\n\n    accuracy                           0.70      1920\n   macro avg       0.57      0.59      0.58      1920\nweighted avg       0.70      0.70      0.70      1920\n'}

# %%
# Criando o modelo de Random Forest
model = tree.ExtraTreeClassifier(random_state = SEED)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.65625
# {'accuracy': 0.65625,
#  'f1_macro': 0.5902150451275555,
#  'precision': 0.6026029074120056,
#  'recall': 0.5800794445352512,
#  'confusion_matrix': array([[135,   1,  58,  82],
#         [  2,   9,   1,   7],
#         [ 71,   4, 694, 191],
#         [ 60,   2, 181, 422]], dtype=int64)}

# %%
# Criando o modelo de Random Forest
rfc = RandomForestClassifier(random_state = SEED, n_jobs=-1)
model_application(rfc, X_train, y_train, X_test, y_test)
# Out:
# 0.9005208333333333
# {'accuracy': 0.9005208333333333,
#  'f1_macro': 0.7820518650061856,
#  'precision': 0.9443431549391399,
#  'recall': 0.7219042000381388,
#  'confusion_matrix': array([[197,   0,  30,  49],
#         [  0,   6,   4,   9],
#         [  0,   0, 945,  15],
#         [  0,   0,  84, 581]], dtype=int64)}

# %%
# Criando o modelo KNN
model = KNeighborsClassifier(n_jobs=-1)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.9604166666666667
# {'accuracy': 0.9604166666666667,
#  'f1_macro': 0.9480005935923499,
#  'precision': 0.9746636562928743,
#  'recall': 0.9256446993843304,
#  'confusion_matrix': array([[260,   0,  14,   2],
#         [  0,  16,   2,   1],
#         [  5,   0, 951,   4],
#         [  3,   0,  45, 617]], dtype=int64)}

# %%
# Criar modelo SVM
model = SGDClassifier(random_state = SEED, n_jobs = -1)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.9348958333333334
# {'accuracy': 0.9348958333333334,
#  'f1_macro': 0.8628076294280547,
#  'precision': 0.9563144578574981,
#  'recall': 0.816813518170426,
#  'confusion_matrix': array([[253,   0,  13,  10],
#         [  0,   9,   1,   9],
#         [  1,   0, 927,  32],
#         [  7,   0,  52, 606]], dtype=int64)}

# %%
# Criando modelo SVM
model = SVC(kernel = 'rbf', random_state = SEED)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.7520833333333333
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'accuracy': 0.7520833333333333,
#  'f1_macro': 0.5039618172257042,
#  'precision': 0.6093053671098453,
#  'recall': 0.4867167068486434,
#  'confusion_matrix': array([[ 87,   0,  60, 129],
#         [  0,   0,   3,  16],
#         [  2,   0, 885,  73],
#         [  0,   0, 193, 472]], dtype=int64)}

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", random_state = SEED)
model_application(model, X_train, y_train, X_test, y_test)

# %%
# Criando o modelo SVM
model = SVC(gamma = "scale", class_weight = "balanced", C = 100)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.9890625
# {'accuracy': 0.9890625,
#  'f1_macro': 0.9628337913595391,
#  'precision': 0.9924372618229014,
#  'recall': 0.9394356305165087,
#  'confusion_matrix': array([[272,   0,   4,   0],
#         [  0,  15,   0,   4],
#         [  2,   0, 955,   3],
#         [  0,   0,   8, 657]], dtype=int64)}

# %%
# Criando modelo Gradient Boosting
gbc = GradientBoostingClassifier()
model_application(gbc, X_train, y_train, X_test, y_test)

# %%
model = XGBClassifier(random_state = SEED)
model_application(model, X_train, y_train, X_test, y_test)
# Out:
# 0.9578125
# {'accuracy': 0.9578125,
#  'f1_macro': 0.8899081992271508,
#  'precision': 0.9749966283462159,
#  'recall': 0.8427188896153427,
#  'confusion_matrix': array([[252,   0,  13,  11],
#         [  0,  10,   1,   8],
#         [  2,   0, 952,   6],
#         [  0,   0,  40, 625]], dtype=int64)}
