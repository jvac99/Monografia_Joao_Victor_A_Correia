# %% [markdown]
# #### Carregando as importações

# %%
import import_ipynb
from preprocessing import *
from imports.imports_common_models_DL import *
from imports.imports_common_metrics import *
from tensorflow.keras.utils import plot_model

# %%
Modelos =  []
Loss = []
Acuracia =  []
Precisao = []
Revocacao =  []
F1_score =  []

# %%
# Define a arquitetura da CNN
model_1 = Sequential([
    Conv2D(25, (3, 3), activation='relu', input_shape=(*IMAGE_SIZE, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(4, activation='softmax')
])

# %%
model_1.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = METRICS)

# Treina o modelo
history_model_1 = model_1.fit(X_train, y_train_categorical, epochs = EPOCHS, validation_data = dataset_validation_categorical, callbacks=[early_stop])
# Out:
# Epoch 1/30
# 140/140 [==============================] - 45s 312ms/step - loss: 0.0332 - accuracy: 0.9897 - precision: 0.9905 - recall: 0.9901 - f1_score: 0.9935 - val_loss: 0.1474 - val_accuracy: 0.9469 - val_precision: 0.9484 - val_recall: 0.9469 - val_f1_score: 0.9516
# Epoch 2/30
# 140/140 [==============================] - 42s 299ms/step - loss: 0.0401 - accuracy: 0.9855 - precision: 0.9855 - recall: 0.9853 - f1_score: 0.9892 - val_loss: 0.1534 - val_accuracy: 0.9516 - val_precision: 0.9529 - val_recall: 0.9484 - val_f1_score: 0.9590
# Epoch 3/30
# 140/140 [==============================] - 41s 295ms/step - loss: 0.0223 - accuracy: 0.9935 - precision: 0.9944 - recall: 0.9931 - f1_score: 0.9946 - val_loss: 0.2510 - val_accuracy: 0.9203 - val_precision: 0.9218 - val_recall: 0.9203 - val_f1_score: 0.9375
# Epoch 4/30
# 140/140 [==============================] - 41s 294ms/step - loss: 0.0215 - accuracy: 0.9931 - precision: 0.9931 - recall: 0.9926 - f1_score: 0.9945 - val_loss: 0.2420 - val_accuracy: 0.9062 - val_precision: 0.9091 - val_recall: 0.9062 - val_f1_score: 0.9235
# Epoch 5/30
# 140/140 [==============================] - 42s 302ms/step - loss: 0.0249 - accuracy: 0.9908 - precision: 0.9908 - recall: 0.9908 - f1_score: 0.9925 - val_loss: 0.1173 - val_accuracy: 0.9625 - val_precision: 0.9640 - val_recall: 0.9625 - val_f1_score: 0.9621
# Epoch 6/30
# 140/140 [==============================] - 43s 304ms/step - loss: 0.0074 - accuracy: 0.9978 - precision: 0.9978 - recall: 0.9978 - f1_score: 0.9984 - val_loss: 0.2200 - val_accuracy: 0.9281 - val_precision: 0.9296 - val_recall: 0.9281 - val_f1_score: 0.9418
# Epoch 7/30
# 140/140 [==============================] - 43s 304ms/step - loss: 0.0124 - accuracy: 0.9955 - precision: 0.9958 - recall: 0.9955 - f1_score: 0.9972 - val_loss: 0.0945 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_f1_score: 0.9742
# Epoch 8/30
# 140/140 [==============================] - 43s 304ms/step - loss: 0.0154 - accuracy: 0.9946 - precision: 0.9949 - recall: 0.9946 - f1_score: 0.9956 - val_loss: 0.1155 - val_accuracy: 0.9672 - val_precision: 0.9687 - val_recall: 0.9656 - val_f1_score: 0.9752
# Epoch 9/30
# 140/140 [==============================] - 43s 308ms/step - loss: 0.0233 - accuracy: 0.9902 - precision: 0.9902 - recall: 0.9902 - f1_score: 0.9931 - val_loss: 0.1374 - val_accuracy: 0.9625 - val_precision: 0.9625 - val_recall: 0.9625 - val_f1_score: 0.9682
# Epoch 10/30
# 140/140 [==============================] - 43s 309ms/step - loss: 0.0085 - accuracy: 0.9978 - precision: 0.9978 - recall: 0.9978 - f1_score: 0.9981 - val_loss: 0.1875 - val_accuracy: 0.9563 - val_precision: 0.9563 - val_recall: 0.9563 - val_f1_score: 0.9536
# Epoch 11/30
# 140/140 [==============================] - 43s 305ms/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9996 - recall: 0.9996 - f1_score: 0.9997 - val_loss: 0.0912 - val_accuracy: 0.9766 - val_precision: 0.9765 - val_recall: 0.9750 - val_f1_score: 0.9779
# Epoch 12/30
# 140/140 [==============================] - 43s 305ms/step - loss: 3.1102e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9750 - val_precision: 0.9750 - val_recall: 0.9750 - val_f1_score: 0.9777
# Epoch 13/30
# 140/140 [==============================] - 43s 306ms/step - loss: 6.9995e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1184 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9719 - val_f1_score: 0.9762
# Epoch 14/30
# 140/140 [==============================] - 43s 309ms/step - loss: 4.8634e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9750 - val_precision: 0.9765 - val_recall: 0.9734 - val_f1_score: 0.9777
# Epoch 15/30
# 140/140 [==============================] - 43s 306ms/step - loss: 3.8469e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9750 - val_precision: 0.9765 - val_recall: 0.9734 - val_f1_score: 0.9777
# Epoch 16/30
# 140/140 [==============================] - 43s 308ms/step - loss: 3.1441e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9750 - val_precision: 0.9765 - val_recall: 0.9750 - val_f1_score: 0.9780

# %%
# Avaliar o modelo no conjunto de teste
result_model_1 = model_1.evaluate(X_test, y_test_categorical)
print('Test:', result_model_1)
# Out:
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0781 - accuracy: 0.9766 - precision: 0.9766 - recall: 0.9766 - f1_score: 0.9796
# Test: [0.0780622810125351, 0.9765625, 0.9765625, 0.9765625, 0.9796229600906372]

# %%
loss, accuracy, precision, recall, f1_score  = result_model_1
Modelos.append('Modelo01')
Acuracia.append(accuracy)
Loss.append(loss)
Precisao.append(precision)
Revocacao.append(recall)
F1_score.append(f1_score)

# %%
model_1.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 126, 126, 25)      250
#
#  max_pooling2d_16 (MaxPoolin  (None, 63, 63, 25)       0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 61, 61, 64)        14464
#
#  max_pooling2d_17 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 64)        36928
#
#  flatten_8 (Flatten)         (None, 50176)             0
#
#  dense_16 (Dense)            (None, 64)                3211328
#
#  dense_17 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 3,263,230
# Trainable params: 3,263,230
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model_1, to_file = './images/arquitetura01.png', show_shapes = True)

# %%
# Plota os gráficos de perda e acurácia
plt.figure(figsize = (10, 8))
plt.plot(history_model_1.history['loss'], label='Perda treino')
plt.plot(history_model_1.history['val_loss'], label='Perda validação')
plt.plot(history_model_1.history['accuracy'], label='Acurácia treino')
plt.plot(history_model_1.history['val_accuracy'], label='Acurácia validação')
plt.plot(history_model_1.history['precision'], label='Precisão treino')
plt.plot(history_model_1.history['val_precision'], label='Precisão validação')
plt.plot(history_model_1.history['recall'], label='Revocação treino')
plt.plot(history_model_1.history['val_recall'], label='Revocação validação')
plt.plot(history_model_1.history['f1_score'], label='F1-score treino')
plt.plot(history_model_1.history['val_f1_score'], label='F1-score validação')
plt.xlabel('Épocas')
plt.ylabel('Perda / Acurácia / Precisão / Revocação / F1-score')
plt.legend()
plt.savefig('images\modelo01_grafico.png', format='png')
plt.show()

# %%
# Define a arquitetura da CNN
model_2 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(*IMAGE_SIZE, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(4, activation='softmax')
])

# %%
model_2.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = METRICS)

# Treina o modelo
history_model_2 = model_2.fit(X_train, y_train_categorical, epochs = EPOCHS, validation_data = dataset_validation_categorical, callbacks=[early_stop])
# Out:
# Epoch 1/30
# 140/140 [==============================] - 36s 254ms/step - loss: 0.9652 - accuracy: 0.5346 - precision: 0.7389 - recall: 0.5026 - f1_score: 0.4747 - val_loss: 0.8604 - val_accuracy: 0.6109 - val_precision: 0.6490 - val_recall: 0.5172 - val_f1_score: 0.3233
# Epoch 2/30
# 140/140 [==============================] - 35s 253ms/step - loss: 0.7166 - accuracy: 0.6812 - precision: 0.7424 - recall: 0.5926 - f1_score: 0.4459 - val_loss: 0.6151 - val_accuracy: 0.6969 - val_precision: 0.7261 - val_recall: 0.6750 - val_f1_score: 0.4690
# Epoch 3/30
# 140/140 [==============================] - 38s 271ms/step - loss: 0.4038 - accuracy: 0.8395 - precision: 0.8538 - recall: 0.8201 - f1_score: 0.8156 - val_loss: 0.4267 - val_accuracy: 0.8234 - val_precision: 0.8352 - val_recall: 0.8078 - val_f1_score: 0.8152
# Epoch 4/30
# 140/140 [==============================] - 38s 271ms/step - loss: 0.2344 - accuracy: 0.9096 - precision: 0.9160 - recall: 0.9027 - f1_score: 0.9244 - val_loss: 0.4550 - val_accuracy: 0.8234 - val_precision: 0.8285 - val_recall: 0.8078 - val_f1_score: 0.8361
# Epoch 5/30
# 140/140 [==============================] - 38s 271ms/step - loss: 0.1021 - accuracy: 0.9643 - precision: 0.9662 - recall: 0.9632 - f1_score: 0.9738 - val_loss: 0.1848 - val_accuracy: 0.9312 - val_precision: 0.9354 - val_recall: 0.9281 - val_f1_score: 0.9420
# Epoch 6/30
# 140/140 [==============================] - 38s 269ms/step - loss: 0.0409 - accuracy: 0.9857 - precision: 0.9859 - recall: 0.9853 - f1_score: 0.9883 - val_loss: 0.1625 - val_accuracy: 0.9484 - val_precision: 0.9482 - val_recall: 0.9438 - val_f1_score: 0.9346
# Epoch 7/30
# 140/140 [==============================] - 37s 264ms/step - loss: 0.0139 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9967 - f1_score: 0.9978 - val_loss: 0.1142 - val_accuracy: 0.9594 - val_precision: 0.9608 - val_recall: 0.9578 - val_f1_score: 0.9643
# Epoch 8/30
# 140/140 [==============================] - 37s 264ms/step - loss: 0.0370 - accuracy: 0.9859 - precision: 0.9859 - recall: 0.9859 - f1_score: 0.9915 - val_loss: 0.1418 - val_accuracy: 0.9484 - val_precision: 0.9483 - val_recall: 0.9453 - val_f1_score: 0.9546
# Epoch 9/30
# 140/140 [==============================] - 38s 268ms/step - loss: 0.0348 - accuracy: 0.9886 - precision: 0.9891 - recall: 0.9884 - f1_score: 0.9912 - val_loss: 0.1413 - val_accuracy: 0.9609 - val_precision: 0.9609 - val_recall: 0.9609 - val_f1_score: 0.9405
# Epoch 10/30
# 140/140 [==============================] - 38s 269ms/step - loss: 0.0046 - accuracy: 0.9991 - precision: 0.9991 - recall: 0.9991 - f1_score: 0.9995 - val_loss: 0.1657 - val_accuracy: 0.9547 - val_precision: 0.9562 - val_recall: 0.9547 - val_f1_score: 0.9618
# Epoch 11/30
# 140/140 [==============================] - 38s 274ms/step - loss: 0.0028 - accuracy: 0.9996 - precision: 0.9996 - recall: 0.9996 - f1_score: 0.9997 - val_loss: 0.1155 - val_accuracy: 0.9672 - val_precision: 0.9672 - val_recall: 0.9672 - val_f1_score: 0.9722
# Epoch 12/30
# 140/140 [==============================] - 38s 272ms/step - loss: 4.8862e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_f1_score: 0.9739
# Epoch 13/30
# 140/140 [==============================] - 38s 274ms/step - loss: 1.5658e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9719 - val_precision: 0.9719 - val_recall: 0.9719 - val_f1_score: 0.9748
# Epoch 14/30
# 140/140 [==============================] - 39s 277ms/step - loss: 1.1133e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9719 - val_precision: 0.9719 - val_recall: 0.9719 - val_f1_score: 0.9748
# Epoch 15/30
# 140/140 [==============================] - 38s 275ms/step - loss: 8.8370e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9719 - val_precision: 0.9719 - val_recall: 0.9719 - val_f1_score: 0.9748
# Epoch 16/30
# 140/140 [==============================] - 38s 272ms/step - loss: 7.2107e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_f1_score: 0.9758
# Epoch 17/30
# 140/140 [==============================] - 40s 287ms/step - loss: 6.0625e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_f1_score: 0.9758
# Epoch 18/30
# 140/140 [==============================] - 42s 298ms/step - loss: 5.1722e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1130 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_f1_score: 0.9758
# Epoch 19/30
# 140/140 [==============================] - 40s 285ms/step - loss: 4.4741e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9750 - val_precision: 0.9750 - val_recall: 0.9750 - val_f1_score: 0.9767
# Epoch 20/30
# 140/140 [==============================] - 39s 278ms/step - loss: 3.8778e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_f1_score: 0.9757
# Epoch 21/30
# 140/140 [==============================] - 39s 276ms/step - loss: 3.4230e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9750 - val_precision: 0.9750 - val_recall: 0.9750 - val_f1_score: 0.9767
# Epoch 22/30
# 140/140 [==============================] - 39s 278ms/step - loss: 3.0246e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9750 - val_precision: 0.9750 - val_recall: 0.9750 - val_f1_score: 0.9767
# Epoch 23/30
# 140/140 [==============================] - 41s 291ms/step - loss: 2.6873e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_f1_score: 0.9757
# Epoch 24/30
# 140/140 [==============================] - 39s 276ms/step - loss: 2.3997e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_f1_score: 0.9757

# %%
# Avaliar o modelo no conjunto de teste
result_model_2 = model_2.evaluate(X_test, y_test_categorical)
print('Test:', result_model_2)
# Out:
# 40/40 [==============================] - 3s 81ms/step - loss: 0.0965 - accuracy: 0.9789 - precision: 0.9789 - recall: 0.9789 - f1_score: 0.9813
# Test: [0.09645631164312363, 0.9789062738418579, 0.9789062738418579, 0.9789062738418579, 0.9813445210456848]

# %%
loss, accuracy, precision, recall, f1_score  = result_model_2
Modelos.append('Modelo02')
Acuracia.append(accuracy)
Loss.append(loss)
Precisao.append(precision)
Revocacao.append(recall)
F1_score.append(f1_score)

# %%
model_2.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_27 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_18 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_19 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 28, 28, 64)        36928
#
#  flatten_9 (Flatten)         (None, 50176)             0
#
#  dense_18 (Dense)            (None, 64)                3211328
#
#  dense_19 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 3,267,332
# Trainable params: 3,267,332
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model_2, to_file = './images/arquitetura02.png', show_shapes = True)

# %%
# Plota os gráficos de perda e acurácia
plt.figure(figsize = (10, 8))
plt.plot(history_model_2.history['loss'], label='Perda treino')
plt.plot(history_model_2.history['val_loss'], label='Perda validação')
plt.plot(history_model_2.history['accuracy'], label='Acurácia treino')
plt.plot(history_model_2.history['val_accuracy'], label='Acurácia validação')
plt.plot(history_model_2.history['precision'], label='Precisão treino')
plt.plot(history_model_2.history['val_precision'], label='Precisão validação')
plt.plot(history_model_2.history['recall'], label='Revocação treino')
plt.plot(history_model_2.history['val_recall'], label='Revocação validação')
plt.plot(history_model_2.history['f1_score'], label='F1-score treino')
plt.plot(history_model_2.history['val_f1_score'], label='F1-score validação')
plt.xlabel('Épocas')
plt.ylabel('Perda / Acurácia / Precisão / Revocação / F1-score')
plt.legend()
plt.savefig('images\modelo02_grafico.png', format='png')
plt.show()

# %%
# Define a arquitetura da CNN
model_3 = Sequential([
    Conv2D(64, (3,3), activation='relu', input_shape=(*IMAGE_SIZE, 1)),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Conv2D(32, (2,2), activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(50, activation='relu'),
    Dense(4, activation='softmax')
])

# %%
model_3.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = METRICS)

# Treina o modelo
history_model_3 = model_3.fit(X_train, y_train_categorical, epochs = EPOCHS, validation_data = dataset_validation_categorical, callbacks=[early_stop])
# Out:
# Epoch 1/30
# 140/140 [==============================] - 44s 311ms/step - loss: 1.0446 - accuracy: 0.4844 - precision: 0.7023 - recall: 0.4403 - f1_score: 0.4305 - val_loss: 0.9578 - val_accuracy: 0.5422 - val_precision: 0.6942 - val_recall: 0.3016 - val_f1_score: 0.1614
# Epoch 2/30
# 140/140 [==============================] - 41s 290ms/step - loss: 0.9301 - accuracy: 0.5576 - precision: 0.6816 - recall: 0.3460 - f1_score: 0.1983 - val_loss: 0.9318 - val_accuracy: 0.5641 - val_precision: 0.6199 - val_recall: 0.4484 - val_f1_score: 0.2087
# Epoch 3/30
# 140/140 [==============================] - 41s 291ms/step - loss: 0.8223 - accuracy: 0.6181 - precision: 0.7033 - recall: 0.4661 - f1_score: 0.3356 - val_loss: 0.7960 - val_accuracy: 0.6359 - val_precision: 0.7814 - val_recall: 0.4078 - val_f1_score: 0.3286
# Epoch 4/30
# 140/140 [==============================] - 42s 297ms/step - loss: 0.6570 - accuracy: 0.7114 - precision: 0.7573 - recall: 0.6333 - f1_score: 0.4978 - val_loss: 0.6576 - val_accuracy: 0.6969 - val_precision: 0.7244 - val_recall: 0.6531 - val_f1_score: 0.4099
# Epoch 5/30
# 140/140 [==============================] - 42s 297ms/step - loss: 0.4628 - accuracy: 0.8085 - precision: 0.8283 - recall: 0.7783 - f1_score: 0.7404 - val_loss: 0.4793 - val_accuracy: 0.8031 - val_precision: 0.8182 - val_recall: 0.7594 - val_f1_score: 0.8218
# Epoch 6/30
# 140/140 [==============================] - 41s 293ms/step - loss: 0.3162 - accuracy: 0.8752 - precision: 0.8832 - recall: 0.8641 - f1_score: 0.8803 - val_loss: 0.4201 - val_accuracy: 0.8234 - val_precision: 0.8388 - val_recall: 0.8047 - val_f1_score: 0.8608
# Epoch 7/30
# 140/140 [==============================] - 41s 295ms/step - loss: 0.2124 - accuracy: 0.9190 - precision: 0.9233 - recall: 0.9161 - f1_score: 0.9355 - val_loss: 0.4086 - val_accuracy: 0.8313 - val_precision: 0.8375 - val_recall: 0.8297 - val_f1_score: 0.8467
# Epoch 8/30
# 140/140 [==============================] - 41s 295ms/step - loss: 0.1042 - accuracy: 0.9636 - precision: 0.9653 - recall: 0.9625 - f1_score: 0.9746 - val_loss: 0.2225 - val_accuracy: 0.9156 - val_precision: 0.9184 - val_recall: 0.9141 - val_f1_score: 0.9312
# Epoch 9/30
# 140/140 [==============================] - 42s 297ms/step - loss: 0.0766 - accuracy: 0.9725 - precision: 0.9738 - recall: 0.9717 - f1_score: 0.9803 - val_loss: 0.1823 - val_accuracy: 0.9281 - val_precision: 0.9340 - val_recall: 0.9281 - val_f1_score: 0.9409
# Epoch 10/30
# 140/140 [==============================] - 42s 299ms/step - loss: 0.0469 - accuracy: 0.9853 - precision: 0.9855 - recall: 0.9850 - f1_score: 0.9894 - val_loss: 0.2157 - val_accuracy: 0.9312 - val_precision: 0.9327 - val_recall: 0.9312 - val_f1_score: 0.9456
# Epoch 11/30
# 140/140 [==============================] - 43s 307ms/step - loss: 0.0311 - accuracy: 0.9891 - precision: 0.9891 - recall: 0.9886 - f1_score: 0.9915 - val_loss: 0.2111 - val_accuracy: 0.9422 - val_precision: 0.9422 - val_recall: 0.9422 - val_f1_score: 0.9496
# Epoch 12/30
# 140/140 [==============================] - 43s 310ms/step - loss: 0.0181 - accuracy: 0.9960 - precision: 0.9962 - recall: 0.9960 - f1_score: 0.9963 - val_loss: 0.4968 - val_accuracy: 0.8547 - val_precision: 0.8547 - val_recall: 0.8547 - val_f1_score: 0.8868
# Epoch 13/30
# 140/140 [==============================] - 44s 313ms/step - loss: 0.0433 - accuracy: 0.9833 - precision: 0.9835 - recall: 0.9833 - f1_score: 0.9883 - val_loss: 0.1686 - val_accuracy: 0.9500 - val_precision: 0.9515 - val_recall: 0.9500 - val_f1_score: 0.9544
# Epoch 14/30
# 140/140 [==============================] - 44s 318ms/step - loss: 0.0310 - accuracy: 0.9891 - precision: 0.9893 - recall: 0.9891 - f1_score: 0.9890 - val_loss: 0.2676 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_f1_score: 0.9439
# Epoch 15/30
# 140/140 [==============================] - 45s 323ms/step - loss: 0.0277 - accuracy: 0.9908 - precision: 0.9911 - recall: 0.9908 - f1_score: 0.9915 - val_loss: 0.3114 - val_accuracy: 0.9406 - val_precision: 0.9406 - val_recall: 0.9406 - val_f1_score: 0.9388
# Epoch 16/30
# 140/140 [==============================] - 49s 348ms/step - loss: 0.0381 - accuracy: 0.9855 - precision: 0.9859 - recall: 0.9853 - f1_score: 0.9887 - val_loss: 0.2382 - val_accuracy: 0.9250 - val_precision: 0.9277 - val_recall: 0.9219 - val_f1_score: 0.9369
# Epoch 17/30
# 140/140 [==============================] - 49s 351ms/step - loss: 0.0126 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9962 - f1_score: 0.9970 - val_loss: 0.1706 - val_accuracy: 0.9625 - val_precision: 0.9655 - val_recall: 0.9625 - val_f1_score: 0.9681
# Epoch 18/30
# 140/140 [==============================] - 48s 346ms/step - loss: 0.0013 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1701 - val_accuracy: 0.9641 - val_precision: 0.9641 - val_recall: 0.9641 - val_f1_score: 0.9671
# Epoch 19/30
# 140/140 [==============================] - 46s 330ms/step - loss: 3.7966e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9656 - val_precision: 0.9656 - val_recall: 0.9641 - val_f1_score: 0.9685
# Epoch 20/30
# 140/140 [==============================] - 46s 328ms/step - loss: 2.5048e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9656 - val_precision: 0.9656 - val_recall: 0.9641 - val_f1_score: 0.9685
# Epoch 21/30
# 140/140 [==============================] - 46s 330ms/step - loss: 1.9862e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9625 - val_precision: 0.9655 - val_recall: 0.9625 - val_f1_score: 0.9681
# Epoch 22/30
# 140/140 [==============================] - 46s 332ms/step - loss: 1.6666e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9672 - val_precision: 0.9671 - val_recall: 0.9656 - val_f1_score: 0.9694
# Epoch 23/30
# 140/140 [==============================] - 47s 333ms/step - loss: 1.4058e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1700 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_f1_score: 0.9708
# Epoch 24/30
# 140/140 [==============================] - 46s 331ms/step - loss: 1.2098e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9688 - val_precision: 0.9687 - val_recall: 0.9672 - val_f1_score: 0.9704
# Epoch 25/30
# 140/140 [==============================] - 46s 331ms/step - loss: 1.0567e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9688 - val_precision: 0.9687 - val_recall: 0.9672 - val_f1_score: 0.9704
# Epoch 26/30
# 140/140 [==============================] - 48s 341ms/step - loss: 9.2943e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1711 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_f1_score: 0.9708
# Epoch 27/30
# 140/140 [==============================] - 47s 336ms/step - loss: 8.2500e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1718 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_f1_score: 0.9708
# Epoch 28/30
# 140/140 [==============================] - 46s 332ms/step - loss: 7.4753e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1712 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_f1_score: 0.9708

# %%
# Avaliar o modelo no conjunto de teste
result_model_3 = model_3.evaluate(X_test, y_test_categorical)
print('Test:', result_model_3)
# Out:
# 40/40 [==============================] - 3s 79ms/step - loss: 0.1073 - accuracy: 0.9695 - precision: 0.9703 - recall: 0.9695 - f1_score: 0.9736
# Test: [0.10732265561819077, 0.969531238079071, 0.9702892899513245, 0.969531238079071, 0.9735993146896362]

# %%
loss, accuracy, precision, recall, f1_score  = result_model_3
Modelos.append('Modelo03')
Acuracia.append(accuracy)
Loss.append(loss)
Precisao.append(precision)
Revocacao.append(recall)
F1_score.append(f1_score)

# %%
model_3.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_33 (Conv2D)          (None, 126, 126, 64)      640
#
#  max_pooling2d_23 (MaxPoolin  (None, 63, 63, 64)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 61, 61, 32)        18464
#
#  max_pooling2d_24 (MaxPoolin  (None, 30, 30, 32)       0
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 29, 29, 32)        4128
#
#  max_pooling2d_25 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 6272)              0
#
#  dense_23 (Dense)            (None, 100)               627300
#
#  dense_24 (Dense)            (None, 50)                5050
#
#  dense_25 (Dense)            (None, 4)                 204
#
# =================================================================
# Total params: 655,786
# Trainable params: 655,786
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model_3, to_file = './images/arquitetura03.png', show_shapes = True)

# %%
# Plota os gráficos de perda e acurácia
plt.figure(figsize = (10, 8))
plt.plot(history_model_3.history['loss'], label='Perda treino')
plt.plot(history_model_3.history['val_loss'], label='Perda validação')
plt.plot(history_model_3.history['accuracy'], label='Acurácia treino')
plt.plot(history_model_3.history['val_accuracy'], label='Acurácia validação')
plt.plot(history_model_3.history['precision'], label='Precisão treino')
plt.plot(history_model_3.history['val_precision'], label='Precisão validação')
plt.plot(history_model_3.history['recall'], label='Revocação treino')
plt.plot(history_model_3.history['val_recall'], label='Revocação validação')
plt.plot(history_model_3.history['f1_score'], label='F1-score treino')
plt.plot(history_model_3.history['val_f1_score'], label='F1-score validação')
plt.xlabel('Épocas')
plt.ylabel('Perda / Acurácia / Precisão / Revocação / F1-score')
plt.legend()
plt.savefig('images\modelo03_grafico.png', format='png')
plt.show()

# %%
model_4 = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(*IMAGE_SIZE, 1)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='softmax')
])

# %%
model_4.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = METRICS)

# Treina o modelo
history_model_4 = model_4.fit(X_train, y_train_categorical, epochs = EPOCHS, validation_data = dataset_validation_categorical, callbacks=[early_stop])
# Out:
# Epoch 1/30
# 140/140 [==============================] - 51s 355ms/step - loss: 1.0149 - accuracy: 0.5161 - precision: 0.7311 - recall: 0.4507 - f1_score: 0.4459 - val_loss: 0.9206 - val_accuracy: 0.5625 - val_precision: 0.6557 - val_recall: 0.4047 - val_f1_score: 0.1846
# Epoch 2/30
# 140/140 [==============================] - 51s 363ms/step - loss: 0.8835 - accuracy: 0.5866 - precision: 0.6869 - recall: 0.4275 - f1_score: 0.2836 - val_loss: 0.7984 - val_accuracy: 0.6625 - val_precision: 0.7493 - val_recall: 0.4391 - val_f1_score: 0.2715
# Epoch 3/30
# 140/140 [==============================] - 51s 362ms/step - loss: 0.7308 - accuracy: 0.6674 - precision: 0.7321 - recall: 0.5696 - f1_score: 0.4411 - val_loss: 0.6920 - val_accuracy: 0.6750 - val_precision: 0.7205 - val_recall: 0.6000 - val_f1_score: 0.4306
# Epoch 4/30
# 140/140 [==============================] - 51s 364ms/step - loss: 0.5398 - accuracy: 0.7696 - precision: 0.8029 - recall: 0.7203 - f1_score: 0.5664 - val_loss: 0.5147 - val_accuracy: 0.7797 - val_precision: 0.7945 - val_recall: 0.7609 - val_f1_score: 0.5444
# Epoch 5/30
# 140/140 [==============================] - 51s 367ms/step - loss: 0.3334 - accuracy: 0.8692 - precision: 0.8854 - recall: 0.8522 - f1_score: 0.8162 - val_loss: 0.2803 - val_accuracy: 0.8969 - val_precision: 0.9072 - val_recall: 0.8859 - val_f1_score: 0.8919
# Epoch 6/30
# 140/140 [==============================] - 52s 373ms/step - loss: 0.1975 - accuracy: 0.9308 - precision: 0.9351 - recall: 0.9230 - f1_score: 0.9164 - val_loss: 0.2701 - val_accuracy: 0.9016 - val_precision: 0.9128 - val_recall: 0.9000 - val_f1_score: 0.8936
# Epoch 7/30
# 140/140 [==============================] - 51s 367ms/step - loss: 0.1094 - accuracy: 0.9634 - precision: 0.9663 - recall: 0.9614 - f1_score: 0.9604 - val_loss: 0.1591 - val_accuracy: 0.9391 - val_precision: 0.9419 - val_recall: 0.9375 - val_f1_score: 0.9505
# Epoch 8/30
# 140/140 [==============================] - 52s 371ms/step - loss: 0.0948 - accuracy: 0.9681 - precision: 0.9700 - recall: 0.9670 - f1_score: 0.9701 - val_loss: 0.1796 - val_accuracy: 0.9391 - val_precision: 0.9405 - val_recall: 0.9391 - val_f1_score: 0.9479
# Epoch 9/30
# 140/140 [==============================] - 52s 372ms/step - loss: 0.0478 - accuracy: 0.9855 - precision: 0.9864 - recall: 0.9848 - f1_score: 0.9883 - val_loss: 0.1276 - val_accuracy: 0.9578 - val_precision: 0.9592 - val_recall: 0.9563 - val_f1_score: 0.9666
# Epoch 10/30
# 140/140 [==============================] - 53s 376ms/step - loss: 0.0243 - accuracy: 0.9940 - precision: 0.9942 - recall: 0.9937 - f1_score: 0.9925 - val_loss: 0.1655 - val_accuracy: 0.9484 - val_precision: 0.9499 - val_recall: 0.9484 - val_f1_score: 0.9572
# Epoch 11/30
# 140/140 [==============================] - 53s 377ms/step - loss: 0.0377 - accuracy: 0.9864 - precision: 0.9873 - recall: 0.9862 - f1_score: 0.9841 - val_loss: 0.1180 - val_accuracy: 0.9656 - val_precision: 0.9656 - val_recall: 0.9656 - val_f1_score: 0.9727
# Epoch 12/30
# 140/140 [==============================] - 59s 419ms/step - loss: 0.0275 - accuracy: 0.9900 - precision: 0.9902 - recall: 0.9895 - f1_score: 0.9863 - val_loss: 0.1613 - val_accuracy: 0.9547 - val_precision: 0.9562 - val_recall: 0.9547 - val_f1_score: 0.9573
# Epoch 13/30
# 140/140 [==============================] - 75s 534ms/step - loss: 0.0316 - accuracy: 0.9886 - precision: 0.9888 - recall: 0.9882 - f1_score: 0.9859 - val_loss: 0.1350 - val_accuracy: 0.9641 - val_precision: 0.9641 - val_recall: 0.9641 - val_f1_score: 0.9696
# Epoch 14/30
# 140/140 [==============================] - 57s 407ms/step - loss: 0.0185 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9935 - f1_score: 0.9952 - val_loss: 0.1346 - val_accuracy: 0.9609 - val_precision: 0.9609 - val_recall: 0.9594 - val_f1_score: 0.9681
# Epoch 15/30
# 140/140 [==============================] - 58s 417ms/step - loss: 0.0186 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9926 - f1_score: 0.9934 - val_loss: 0.1444 - val_accuracy: 0.9609 - val_precision: 0.9609 - val_recall: 0.9609 - val_f1_score: 0.9677
# Epoch 16/30
# 140/140 [==============================] - 57s 407ms/step - loss: 0.0283 - accuracy: 0.9906 - precision: 0.9911 - recall: 0.9904 - f1_score: 0.9928 - val_loss: 0.1030 - val_accuracy: 0.9719 - val_precision: 0.9719 - val_recall: 0.9719 - val_f1_score: 0.9773
# Epoch 17/30
# 140/140 [==============================] - 55s 393ms/step - loss: 0.0175 - accuracy: 0.9951 - precision: 0.9955 - recall: 0.9949 - f1_score: 0.9929 - val_loss: 0.0828 - val_accuracy: 0.9750 - val_precision: 0.9750 - val_recall: 0.9750 - val_f1_score: 0.9783
# Epoch 18/30
# 140/140 [==============================] - 58s 416ms/step - loss: 0.0199 - accuracy: 0.9944 - precision: 0.9953 - recall: 0.9940 - f1_score: 0.9932 - val_loss: 0.0968 - val_accuracy: 0.9672 - val_precision: 0.9672 - val_recall: 0.9672 - val_f1_score: 0.9737
# Epoch 19/30
# 140/140 [==============================] - 56s 400ms/step - loss: 0.0220 - accuracy: 0.9935 - precision: 0.9935 - recall: 0.9935 - f1_score: 0.9922 - val_loss: 0.1875 - val_accuracy: 0.9547 - val_precision: 0.9547 - val_recall: 0.9547 - val_f1_score: 0.9331
# Epoch 20/30
# 140/140 [==============================] - 58s 416ms/step - loss: 0.0158 - accuracy: 0.9942 - precision: 0.9946 - recall: 0.9942 - f1_score: 0.9953 - val_loss: 0.0786 - val_accuracy: 0.9797 - val_precision: 0.9797 - val_recall: 0.9781 - val_f1_score: 0.9825
# Epoch 21/30
# 140/140 [==============================] - 60s 428ms/step - loss: 0.0341 - accuracy: 0.9888 - precision: 0.9888 - recall: 0.9884 - f1_score: 0.9846 - val_loss: 0.1827 - val_accuracy: 0.9359 - val_precision: 0.9402 - val_recall: 0.9328 - val_f1_score: 0.9416
# Epoch 22/30
# 140/140 [==============================] - 57s 411ms/step - loss: 0.0284 - accuracy: 0.9908 - precision: 0.9913 - recall: 0.9908 - f1_score: 0.9835 - val_loss: 0.0991 - val_accuracy: 0.9750 - val_precision: 0.9750 - val_recall: 0.9734 - val_f1_score: 0.9755
# Epoch 23/30
# 140/140 [==============================] - 61s 433ms/step - loss: 0.0149 - accuracy: 0.9946 - precision: 0.9951 - recall: 0.9944 - f1_score: 0.9955 - val_loss: 0.1502 - val_accuracy: 0.9656 - val_precision: 0.9656 - val_recall: 0.9656 - val_f1_score: 0.9682
# Epoch 24/30
# 140/140 [==============================] - 62s 445ms/step - loss: 0.0118 - accuracy: 0.9964 - precision: 0.9967 - recall: 0.9964 - f1_score: 0.9943 - val_loss: 0.0940 - val_accuracy: 0.9766 - val_precision: 0.9766 - val_recall: 0.9766 - val_f1_score: 0.9791
# Epoch 25/30
# 140/140 [==============================] - 65s 467ms/step - loss: 0.0142 - accuracy: 0.9953 - precision: 0.9953 - recall: 0.9953 - f1_score: 0.9907 - val_loss: 0.1071 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_f1_score: 0.9746

# %%
# Avaliar o modelo no conjunto de teste
result_model_4 = model_4.evaluate(X_test, y_test_categorical)
print('Test:', result_model_4)
# Out:
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0974 - accuracy: 0.9773 - precision: 0.9773 - recall: 0.9758 - f1_score: 0.9802
# Test: [0.09743420779705048, 0.977343738079071, 0.9773082733154297, 0.975781261920929, 0.9801658391952515]

# %%
loss, accuracy, precision, recall, f1_score  = result_model_4
Modelos.append('Modelo04')
Acuracia.append(accuracy)
Loss.append(loss)
Precisao.append(precision)
Revocacao.append(recall)
F1_score.append(f1_score)

# %%
model_4.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 126, 126, 32)      320
#
#  max_pooling2d_26 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_37 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_27 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_28 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 25088)             0
#
#  dense_26 (Dense)            (None, 512)               12845568
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_27 (Dense)            (None, 4)                 2052
#
# =================================================================
# Total params: 12,940,292
# Trainable params: 12,940,292
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model_4, to_file = './images/arquitetura04.png', show_shapes = True)

# %%
# Plota os gráficos de perda e acurácia
plt.figure(figsize = (10, 8))
plt.plot(history_model_4.history['loss'], label='Perda treino')
plt.plot(history_model_4.history['val_loss'], label='Perda validação')
plt.plot(history_model_4.history['accuracy'], label='Acurácia treino')
plt.plot(history_model_4.history['val_accuracy'], label='Acurácia validação')
plt.plot(history_model_4.history['precision'], label='Precisão treino')
plt.plot(history_model_4.history['val_precision'], label='Precisão validação')
plt.plot(history_model_4.history['recall'], label='Revocação treino')
plt.plot(history_model_4.history['val_recall'], label='Revocação validação')
plt.plot(history_model_4.history['f1_score'], label='F1-score treino')
plt.plot(history_model_4.history['val_f1_score'], label='F1-score validação')
plt.xlabel('Épocas')
plt.ylabel('Perda / Acurácia / Precisão / Revocação / F1-score')
plt.legend()
plt.savefig('images\modelo04_grafico.png', format='png')
plt.show()
