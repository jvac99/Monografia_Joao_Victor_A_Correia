# %% [markdown]
# #### Carregando as importações

# %%
import import_ipynb
from preprocessing import *
from imports.imports_common_models_DL import *
from imports.imports_common_metrics import *
# Out:
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb

# %%
# Define a arquitetura da CNN
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(*IMAGE_SIZE, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(4, activation='softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = METRICS)

# Treina o modelo
history = model.fit(X_train, y_train_categorical, epochs = EPOCHS, validation_data = dataset_validation_categorical, callbacks=[early_stop])

# Avaliar o modelo no conjunto de teste
result = model.evaluate(X_test, y_test_categorical)
print('Test:', result)
# Out:
# Epoch 1/30
# 140/140 [==============================] - 56s 392ms/step - loss: 0.9881 - accuracy: 0.5248 - precision: 0.7262 - recall: 0.4743 - f1_score: 0.4548 - val_loss: 0.8773 - val_accuracy: 0.5641 - val_precision: 0.6684 - val_recall: 0.4062 - val_f1_score: 0.1949
# Epoch 2/30
# 140/140 [==============================] - 59s 424ms/step - loss: 0.7652 - accuracy: 0.6545 - precision: 0.7192 - recall: 0.5415 - f1_score: 0.4221 - val_loss: 0.7244 - val_accuracy: 0.6750 - val_precision: 0.7395 - val_recall: 0.5766 - val_f1_score: 0.6674
# Epoch 3/30
# 140/140 [==============================] - 58s 412ms/step - loss: 0.4469 - accuracy: 0.8228 - precision: 0.8448 - recall: 0.7924 - f1_score: 0.8203 - val_loss: 0.4381 - val_accuracy: 0.8188 - val_precision: 0.8336 - val_recall: 0.8062 - val_f1_score: 0.8381
# Epoch 4/30
# ...

# %%
# Plota os gráficos de perda e acurácia
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss / Accuracy')
plt.legend()
plt.show()

# %%
# Define a arquitetura da CNN
model = Sequential([
    Conv2D(64, (3,3), activation='relu', input_shape=(*IMAGE_SIZE, 1)),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Conv2D(32, (2,2), activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(50, activation='relu'),
    Dense(4, activation='softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = METRICS)

# Compila o modelo
#model.compile(optimizer='adam', loss = tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

# Treina o modelo
history = model.fit(X_train, y_train_categorical, epochs = EPOCHS, validation_data = dataset_validation_categorical, callbacks=[early_stop])

# Avaliar o modelo no conjunto de teste
result = model.evaluate(X_test, y_test_categorical)
print('Test:', result)
# Out:
# Epoch 1/30
# 140/140 [==============================] - 53s 368ms/step - loss: 1.0208 - accuracy: 0.5107 - precision: 0.7170 - recall: 0.4469 - f1_score: 0.4338 - val_loss: 0.9282 - val_accuracy: 0.5422 - val_precision: 0.6749 - val_recall: 0.3406 - val_f1_score: 0.2141
# Epoch 2/30
# 140/140 [==============================] - 54s 388ms/step - loss: 0.8828 - accuracy: 0.5842 - precision: 0.7015 - recall: 0.3998 - f1_score: 0.2605 - val_loss: 0.7950 - val_accuracy: 0.6469 - val_precision: 0.7531 - val_recall: 0.4812 - val_f1_score: 0.3058
# Epoch 3/30
# 140/140 [==============================] - 68s 483ms/step - loss: 0.7267 - accuracy: 0.6837 - precision: 0.7421 - recall: 0.5891 - f1_score: 0.4511 - val_loss: 0.7328 - val_accuracy: 0.6687 - val_precision: 0.7019 - val_recall: 0.6328 - val_f1_score: 0.3971
# Epoch 4/30
# ...

# %%
from sklearn.metrics import classification_report

model.summary()

# Prever as classes do conjunto de teste
# dataset_test.reset()
#predictions = model.predict(X_test)

#predicted_classes = np.argmax(predictions, axis=1)
#print(predicted_classes)

# Imprimir o relatório de classificação
#print('Classification Report:')
#print(classification_report(y_test_categorical, predictions)
# Calcular e plotar a matriz de confusão
# confusion_mtx = confusion_matrix(true_classes, predicted_classes)
# plt.figure(figsize=(8, 6))
# plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
# plt.title('Confusion Matrix')
# plt.colorbar()
# tick_marks = np.arange(len(class_labels))
# plt.xticks(tick_marks, class_labels, rotation=45)
# plt.yticks(tick_marks, class_labels)
# plt.xlabel('Predicted Label')
# plt.ylabel('True Label')
# plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 126, 126, 64)      640
#
#  max_pooling2d_5 (MaxPooling  (None, 63, 63, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 61, 61, 32)        18464
#
#  max_pooling2d_6 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 29, 29, 32)        4128
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_5 (Dense)             (None, 100)               627300
#
#  dense_6 (Dense)             (None, 50)                5050
#
#  dense_7 (Dense)             (None, 4)                 204
#
# ...
# Total params: 655,786
# Trainable params: 655,786
# Non-trainable params: 0
# _________________________________________________________________
# ...

# %%
# Plota os gráficos de perda e acurácia
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss / Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 13
#       9 plt.show()
#      12 plt.figure(figsize=(8, 6))
# ---> 13 plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
#      14 plt.title('Confusion Matrix')
#      15 plt.colorbar()
#
# NameError: name 'confusion_mtx' is not defined
