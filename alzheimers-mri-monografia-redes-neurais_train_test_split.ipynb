# %% [markdown]
# #### Carregando as importações

# %%
import import_ipynb
from preprocessing_DL import *
# Out:
# importing Jupyter notebook from preprocessing_DL.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_DL.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb
# importing Jupyter notebook from load_dataset.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb

# %%
# Define a arquitetura da CNN
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(*IMAGE_SIZE, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(4, activation='softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Compila o modelo
#model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

# Treina o modelo}
history = model.fit(X_train, y_train, epochs = EPOCHS, validation_data = validation_data, callbacks=[early_stop])

# Plota os gráficos de perda e acurácia
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss / Accuracy')
plt.legend()
plt.show()


# Avalia o modelo no conjunto de teste
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
# Out:
# Epoch 1/30
# 98/98 [==============================] - 26s 263ms/step - loss: 1.0302 - accuracy: 0.4974 - val_loss: 0.9905 - val_accuracy: 0.5104
# Epoch 2/30
# 98/98 [==============================] - 28s 285ms/step - loss: 0.8778 - accuracy: 0.6017 - val_loss: 0.8440 - val_accuracy: 0.6213
# Epoch 3/30
# 98/98 [==============================] - 29s 291ms/step - loss: 0.6980 - accuracy: 0.7038 - val_loss: 0.8013 - val_accuracy: 0.6287
# Epoch 4/30
# 98/98 [==============================] - 29s 293ms/step - loss: 0.5130 - accuracy: 0.7911 - val_loss: 0.5545 - val_accuracy: 0.7671
# Epoch 5/30
# 98/98 [==============================] - 50s 516ms/step - loss: 0.3175 - accuracy: 0.8715 - val_loss: 0.3941 - val_accuracy: 0.8333
# Epoch 6/30
# 98/98 [==============================] - 51s 524ms/step - loss: 0.1901 - accuracy: 0.9375 - val_loss: 0.3449 - val_accuracy: 0.8586
# Epoch 7/30
# 98/98 [==============================] - 51s 520ms/step - loss: 0.0902 - accuracy: 0.9681 - val_loss: 0.2380 - val_accuracy: 0.9129
# Epoch 8/30
# 98/98 [==============================] - 53s 538ms/step - loss: 0.0489 - accuracy: 0.9860 - val_loss: 0.2036 - val_accuracy: 0.9323
# Epoch 9/30
# 98/98 [==============================] - 52s 536ms/step - loss: 0.0116 - accuracy: 0.9974 - val_loss: 0.2367 - val_accuracy: 0.9211
# Epoch 10/30
# 98/98 [==============================] - 55s 565ms/step - loss: 0.0072 - accuracy: 0.9990 - val_loss: 0.1899 - val_accuracy: 0.9390
# Epoch 11/30
# 98/98 [==============================] - 56s 572ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2743 - val_accuracy: 0.9278
# Epoch 12/30
# 98/98 [==============================] - 59s 607ms/step - loss: 8.8953e-04 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9457
# Epoch 13/30
# 98/98 [==============================] - 57s 580ms/step - loss: 4.5106e-04 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9420
# Epoch 14/30
# 98/98 [==============================] - 61s 621ms/step - loss: 3.1335e-04 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9427
# Epoch 15/30
# 98/98 [==============================] - 62s 634ms/step - loss: 2.4577e-04 - accuracy: 1.0000 - val_loss: 0.2183 - val_accuracy: 0.9435
# Epoch 16/30
# 98/98 [==============================] - 59s 599ms/step - loss: 2.0942e-04 - accuracy: 1.0000 - val_loss: 0.2193 - val_accuracy: 0.9435
# Epoch 17/30
# 98/98 [==============================] - 58s 596ms/step - loss: 1.7785e-04 - accuracy: 1.0000 - val_loss: 0.2169 - val_accuracy: 0.9435
# 60/60 [==============================] - 8s 126ms/step - loss: 0.2824 - accuracy: 0.9344
# Test Loss: 0.28238344192504883
# Test Accuracy: 0.934374988079071

# %%
# Define a arquitetura da CNN
model = Sequential([
    Conv2D(64, (3,3), activation='relu', input_shape=(*IMAGE_SIZE, 1)),
    MaxPooling2D(),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Conv2D(32, (2,2), activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(50, activation='relu'),
    Dense(4, activation='softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = 'accuracy')
# Compila o modelo
#model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

# Treina o modelo}
history = model.fit(X_train, y_train, epochs = EPOCHS, validation_data = validation_data, callbacks=[early_stop])

# Plota os gráficos de perda e acurácia
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss / Accuracy')
plt.legend()
plt.show()


# Avalia o modelo no conjunto de teste
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
# Out:
# Epoch 1/30
# 98/98 [==============================] - 41s 410ms/step - loss: 1.0496 - accuracy: 0.4946 - val_loss: 0.9944 - val_accuracy: 0.5037
# Epoch 2/30
# 98/98 [==============================] - 38s 383ms/step - loss: 0.9529 - accuracy: 0.5453 - val_loss: 0.9241 - val_accuracy: 0.5565
# Epoch 3/30
# 98/98 [==============================] - 31s 321ms/step - loss: 0.8581 - accuracy: 0.5998 - val_loss: 0.8818 - val_accuracy: 0.5863
# Epoch 4/30
# 98/98 [==============================] - 34s 348ms/step - loss: 0.7693 - accuracy: 0.6642 - val_loss: 0.7767 - val_accuracy: 0.6399
# Epoch 5/30
# 98/98 [==============================] - 33s 333ms/step - loss: 0.6196 - accuracy: 0.7462 - val_loss: 0.6388 - val_accuracy: 0.7143
# Epoch 6/30
# 98/98 [==============================] - 33s 337ms/step - loss: 0.4854 - accuracy: 0.8061 - val_loss: 0.5785 - val_accuracy: 0.7493
# Epoch 7/30
# 98/98 [==============================] - 34s 347ms/step - loss: 0.3902 - accuracy: 0.8399 - val_loss: 0.5209 - val_accuracy: 0.7939
# Epoch 8/30
# 98/98 [==============================] - 33s 334ms/step - loss: 0.2512 - accuracy: 0.9024 - val_loss: 0.5062 - val_accuracy: 0.8192
# Epoch 9/30
# 98/98 [==============================] - 33s 335ms/step - loss: 0.1670 - accuracy: 0.9375 - val_loss: 0.3968 - val_accuracy: 0.8571
# Epoch 10/30
# 98/98 [==============================] - 33s 335ms/step - loss: 0.1098 - accuracy: 0.9640 - val_loss: 0.4434 - val_accuracy: 0.8557
# Epoch 11/30
# 98/98 [==============================] - 32s 331ms/step - loss: 0.0959 - accuracy: 0.9691 - val_loss: 0.4355 - val_accuracy: 0.8445
# Epoch 12/30
# 98/98 [==============================] - 33s 334ms/step - loss: 0.0438 - accuracy: 0.9866 - val_loss: 0.3322 - val_accuracy: 0.9033
# Epoch 13/30
# 98/98 [==============================] - 32s 328ms/step - loss: 0.0464 - accuracy: 0.9844 - val_loss: 0.3572 - val_accuracy: 0.9010
# Epoch 14/30
# 98/98 [==============================] - 33s 338ms/step - loss: 0.0254 - accuracy: 0.9911 - val_loss: 0.3977 - val_accuracy: 0.9048
# Epoch 15/30
# 98/98 [==============================] - 34s 350ms/step - loss: 0.0499 - accuracy: 0.9837 - val_loss: 0.3303 - val_accuracy: 0.9100
# Epoch 16/30
# 98/98 [==============================] - 36s 364ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3847 - val_accuracy: 0.9115
# Epoch 17/30
# 98/98 [==============================] - 37s 377ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3796 - val_accuracy: 0.9167
# Epoch 18/30
# 98/98 [==============================] - 38s 385ms/step - loss: 7.0346e-04 - accuracy: 1.0000 - val_loss: 0.3879 - val_accuracy: 0.9167
# Epoch 19/30
# 98/98 [==============================] - 38s 392ms/step - loss: 5.3775e-04 - accuracy: 1.0000 - val_loss: 0.3887 - val_accuracy: 0.9196
# Epoch 20/30
# 98/98 [==============================] - 39s 402ms/step - loss: 4.2229e-04 - accuracy: 1.0000 - val_loss: 0.3983 - val_accuracy: 0.9167
# Epoch 21/30
# 98/98 [==============================] - 40s 409ms/step - loss: 3.3953e-04 - accuracy: 1.0000 - val_loss: 0.4046 - val_accuracy: 0.9189
# Epoch 22/30
# 98/98 [==============================] - 41s 417ms/step - loss: 2.9482e-04 - accuracy: 1.0000 - val_loss: 0.4106 - val_accuracy: 0.9189
# Epoch 23/30
# 98/98 [==============================] - 40s 408ms/step - loss: 2.4549e-04 - accuracy: 1.0000 - val_loss: 0.4106 - val_accuracy: 0.9152
# Epoch 24/30
# 98/98 [==============================] - 40s 410ms/step - loss: 2.1143e-04 - accuracy: 1.0000 - val_loss: 0.4170 - val_accuracy: 0.9182
# 60/60 [==============================] - 6s 95ms/step - loss: 0.4517 - accuracy: 0.9115
# Test Loss: 0.45168209075927734
# Test Accuracy: 0.9114583134651184
