# %%
import import_ipynb
from preprocessing_RGB import *
from imports.imports_common_models_ML import *

# %% [markdown]
# **Validação Cruzada**

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = RandomForestClassifier(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.87946429 0.87834821 0.8515625  0.90290179 0.87946429]
# Mean R^2 for Cross-Validation K-Fold: 0.8783482142857142
# accuracy
# 0.6890625
#
# f1_macro
# 0.4478880079503336
#
# precision
# 0.5660782653498672
#
# recall
# 0.43383130486831606
#
# confusion_matrix
# [[ 45   0  42  92]
#  [  0   0   2  11]
#  [  1   0 574  65]
#  [  2   0 183 263]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.9375    0.2514    0.3965       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.7166    0.8969    0.7967       640
# Very_Mild_Demented     0.6102    0.5871    0.5984       448
#
#           accuracy                         0.6891      1280
#          macro avg     0.5661    0.4338    0.4479      1280
#       weighted avg     0.7030    0.6891    0.6632      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = RandomForestClassifier(random_state = SEED, n_jobs = -1, n_estimators = 250)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.8828125  0.87611607 0.86272321 0.90625    0.88950893]
# Mean R^2 for Cross-Validation K-Fold: 0.8834821428571429
# accuracy
# 0.696875
#
# f1_macro
# 0.45530045736112684
#
# precision
# 0.5850226127776506
#
# recall
# 0.44008286362729454
#
# confusion_matrix
# [[ 46   0  40  93]
#  [  0   0   2  11]
#  [  0   0 575  65]
#  [  0   0 177 271]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     1.0000    0.2570    0.4089       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.7242    0.8984    0.8020       640
# Very_Mild_Demented     0.6159    0.6049    0.6104       448
#
#           accuracy                         0.6969      1280
#          macro avg     0.5850    0.4401    0.4553      1280
#       weighted avg     0.7175    0.6969    0.6718      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = KNeighborsClassifier(n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.92299107 0.93191964 0.92299107 0.92075893 0.921875  ]
# Mean R^2 for Cross-Validation K-Fold: 0.9241071428571429
# accuracy
# 0.6453125
#
# f1_macro
# 0.5101852981394028
#
# precision
# 0.719009280735766
#
# recall
# 0.4761467190281785
#
# confusion_matrix
# [[ 83   0  59  37]
#  [  2   2   4   5]
#  [ 24   0 548  68]
#  [ 34   0 221 193]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.5804    0.4637    0.5155       179
#  Moderate_Demented     1.0000    0.1538    0.2667        13
#       Non_Demented     0.6587    0.8562    0.7446       640
# Very_Mild_Demented     0.6370    0.4308    0.5140       448
#
#           accuracy                         0.6453      1280
#          macro avg     0.7190    0.4761    0.5102      1280
#       weighted avg     0.6436    0.6453    0.6270      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SGDClassifier(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.91741071 0.88616071 0.89732143 0.76004464 0.68526786]
# Mean R^2 for Cross-Validation K-Fold: 0.8292410714285714
# accuracy
# 0.7453125
#
# f1_macro
# 0.6950098958557599
#
# precision
# 0.7974529572696442
#
# recall
# 0.6450730506400025
#
# confusion_matrix
# [[108   0  33  38]
#  [  3   6   1   3]
#  [ 21   0 537  82]
#  [ 21   0 124 303]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7059    0.6034    0.6506       179
#  Moderate_Demented     1.0000    0.4615    0.6316        13
#       Non_Demented     0.7727    0.8391    0.8045       640
# Very_Mild_Demented     0.7113    0.6763    0.6934       448
#
#           accuracy                         0.7453      1280
#          macro avg     0.7975    0.6451    0.6950      1280
#       weighted avg     0.7441    0.7453    0.7423      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = LogisticRegression(random_state = SEED, n_jobs = -1)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.875      0.87165179 0.87946429 0.90736607 0.88058036]
# Mean R^2 for Cross-Validation K-Fold: 0.8828124999999998
# accuracy
# 0.75078125
#
# f1_macro
# 0.6783595669638728
#
# precision
# 0.8019247239125535
#
# recall
# 0.6271195285161766
#
# confusion_matrix
# [[104   0  32  43]
#  [  4   5   1   3]
#  [ 16   0 536  88]
#  [ 21   0 111 316]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7172    0.5810    0.6420       179
#  Moderate_Demented     1.0000    0.3846    0.5556        13
#       Non_Demented     0.7882    0.8375    0.8121       640
# Very_Mild_Demented     0.7022    0.7054    0.7038       448
#
#           accuracy                         0.7508      1280
#          macro avg     0.8019    0.6271    0.6784      1280
#       weighted avg     0.7504    0.7508    0.7478      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = MultinomialNB()
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.50111607 0.46875    0.49107143 0.48883929 0.54241071]
# Mean R^2 for Cross-Validation K-Fold: 0.4984375
# accuracy
# 0.521875
#
# f1_macro
# 0.2830604056986332
#
# precision
# 0.31631358449818264
#
# recall
# 0.30045266360734235
#
# confusion_matrix
# [[  4   0  60 115]
#  [  0   0   4   9]
#  [  3   0 452 185]
#  [  9   0 227 212]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2500    0.0223    0.0410       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.6083    0.7063    0.6537       640
# Very_Mild_Demented     0.4069    0.4732    0.4376       448
#
#           accuracy                         0.5219      1280
#          macro avg     0.3163    0.3005    0.2831      1280
#       weighted avg     0.4816    0.5219    0.4857      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = GaussianNB()
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.49441964 0.48325893 0.48102679 0.52008929 0.53794643]
# Mean R^2 for Cross-Validation K-Fold: 0.5033482142857142
# accuracy
# 0.47890625
#
# f1_macro
# 0.31976049200374096
#
# precision
# 0.3274164325984917
#
# recall
# 0.3734013367916999
#
# confusion_matrix
# [[120   0  23  36]
#  [  7   0   3   3]
#  [137   0 414  89]
#  [179   0 190  79]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.2709    0.6704    0.3859       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.6571    0.6469    0.6520       640
# Very_Mild_Demented     0.3816    0.1763    0.2412       448
#
#           accuracy                         0.4789      1280
#          macro avg     0.3274    0.3734    0.3198      1280
#       weighted avg     0.5000    0.4789    0.4644      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'rbf', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'linear', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.97209821 0.95089286 0.9609375  0.95424107 0.9375    ]
# Mean R^2 for Cross-Validation K-Fold: 0.9551339285714284
# accuracy
# 0.76796875
#
# f1_macro
# 0.7468102939344545
#
# precision
# 0.8097139781718716
#
# recall
# 0.7073224981198969
#
# confusion_matrix
# [[118   0  27  34]
#  [  3   8   0   2]
#  [ 27   0 535  78]
#  [ 21   0 105 322]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.6982    0.6592    0.6782       179
#  Moderate_Demented     1.0000    0.6154    0.7619        13
#       Non_Demented     0.8021    0.8359    0.8187       640
# Very_Mild_Demented     0.7385    0.7188    0.7285       448
#
#           accuracy                         0.7680      1280
#          macro avg     0.8097    0.7073    0.7468      1280
#       weighted avg     0.7673    0.7680    0.7669      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'poly', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.88392857 0.88727679 0.88058036 0.90736607 0.88504464]
# Mean R^2 for Cross-Validation K-Fold: 0.8888392857142857
# accuracy
# 0.7046875
#
# f1_macro
# 0.581863148537024
#
# precision
# 0.7914211597464025
#
# recall
# 0.5285045458207993
#
# confusion_matrix
# [[ 70   0  39  70]
#  [  1   3   0   9]
#  [ 10   0 535  95]
#  [  7   0 147 294]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.7955    0.3911    0.5243       179
#  Moderate_Demented     1.0000    0.2308    0.3750        13
#       Non_Demented     0.7420    0.8359    0.7862       640
# Very_Mild_Demented     0.6282    0.6562    0.6419       448
#
#           accuracy                         0.7047      1280
#          macro avg     0.7914    0.5285    0.5819      1280
#       weighted avg     0.7123    0.7047    0.6949      1280

# %%
# Realiza a validação cruzada usando o método cross_val_score.
model = SVC(kernel = 'sigmoid', random_state = SEED)
metrics = kfold_application(model, k, X_train_flatten, y_train, X_test_flatten, y_test, SEED, target_names)
# Out:
# K-Fold (R^2) Scores: [0.32254464 0.36830357 0.359375   0.34486607 0.33705357]
# Mean R^2 for Cross-Validation K-Fold: 0.3464285714285714
# accuracy
# 0.3734375
#
# f1_macro
# 0.16547835771256827
#
# precision
# 0.1543978500643861
#
# recall
# 0.19542410714285716
#
# confusion_matrix
# [[  0   0 178   1]
#  [  0   0  11   2]
#  [  4   0 426 210]
#  [  0   0 396  52]]
#
#                     precision    recall  f1-score   support
#
#      Mild_Demented     0.0000    0.0000    0.0000       179
#  Moderate_Demented     0.0000    0.0000    0.0000        13
#       Non_Demented     0.4214    0.6656    0.5161       640
# Very_Mild_Demented     0.1962    0.1161    0.1459       448
#
#           accuracy                         0.3734      1280
#          macro avg     0.1544    0.1954    0.1655      1280
#       weighted avg     0.2794    0.3734    0.3091      1280
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
