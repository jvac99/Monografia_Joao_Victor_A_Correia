# %%
# !pip install -q pycaret
#!pip install xgboost

# %%
import import_ipynb
from pycaret import classification
from load_dataset import *
from imports.imports_common_models_ML import *
from imports.imports_common_preprocessing import *
from imports.imports_common_metrics import *
# Out:
# importing Jupyter notebook from load_dataset.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_models_ML.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_metrics.ipynb
# importing Jupyter notebook from c:\Users\joao.correia\Documents\Faculdade\Monografia_Joao_Victor_A_Correia\imports\imports_common_preprocessing.ipynb

# %%
X_cross = np.array(X) / 255.0
# Transformar as imagens em vetores de recursos
X_cross = [np.array(img).flatten() for img in X_cross]

# Converter os rótulos em valores numéricos usando LabelEncoder
label_encoder = LabelEncoder()
y_cross = label_encoder.fit_transform(y)
#tipo_encoded, tipo_categories = pd.factorize(y)

# %%
# Dividir os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = TEST_SIZE, random_state = SEED)

# %%
# Reshape X_train para (4480, 16384) - 128 * 128 = 16384
X_train = np.reshape(X_train, (X_train.shape[0], -1))

# Reshape y_train para (4480, 1)
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# Criação do pandas.DataFrame
X_train = pd.DataFrame(X_train)
y_train = pd.DataFrame(y_train)

# Renomear as colunas de X_train e y_train
X_train = X_train.add_prefix('X_')
y_train = y_train.rename(columns={0: 'target'})

train_data = pd.concat([X_train, y_train], axis=1)

# %%
# Configuração do PyCaret para criação de modelos de classificação
s = classification.setup(data=train_data, target='target', session_id=123, normalize=True, fix_imbalance=True)
# Out:
# <style type="text/css">
# #T_1a0b4_row9_col1, #T_1a0b4_row13_col1, #T_1a0b4_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1a0b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a0b4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1a0b4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a0b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a0b4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1a0b4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a0b4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1a0b4_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1a0b4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1a0b4_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1a0b4_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_1a0b4_row3_col1" class="data row3 col1" >Mild_Demented: 0, Moderate_Demented: 1, Non_Demented: 2, Very_Mild_Demented: 3</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1a0b4_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_1a0b4_row4_col1" class="data row4 col1" >(4480, 16385)</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1a0b4_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_1a0b4_row5_col1" class="data row5 col1" >(7616, 16385)</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1a0b4_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_1a0b4_row6_col1" class="data row6 col1" >(6272, 16385)</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1a0b4_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_1a0b4_row7_col1" class="data row7 col1" >(1344, 16385)</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1a0b4_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_1a0b4_row8_col1" class="data row8 col1" >16384</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1a0b4_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_1a0b4_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1a0b4_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_1a0b4_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1a0b4_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_1a0b4_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1a0b4_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_1a0b4_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1a0b4_row13_col0" class="data row13 col0" >Fix imbalance</td>
#       <td id="T_1a0b4_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1a0b4_row14_col0" class="data row14 col0" >Fix imbalance method</td>
#       <td id="T_1a0b4_row14_col1" class="data row14 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1a0b4_row15_col0" class="data row15 col0" >Normalize</td>
#       <td id="T_1a0b4_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1a0b4_row16_col0" class="data row16 col0" >Normalize method</td>
#       <td id="T_1a0b4_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1a0b4_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_1a0b4_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1a0b4_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_1a0b4_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1a0b4_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_1a0b4_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1a0b4_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_1a0b4_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1a0b4_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_1a0b4_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1a0b4_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_1a0b4_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1a0b4_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1a0b4_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_1a0b4_row23_col1" class="data row23 col1" >92b5</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = classification.compare_models(sort = 'F1')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      18:42:27
# Status     . . . . . . . . . . . . . . . . . .              Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
# <style type="text/css">
# #T_055f8 th {
#   text-align: left;
# }
# #T_055f8_row0_col0, #T_055f8_row0_col1, #T_055f8_row0_col2, #T_055f8_row0_col3, #T_055f8_row0_col4, #T_055f8_row0_col5, #T_055f8_row0_col6, #T_055f8_row0_col7, #T_055f8_row0_col8, #T_055f8_row1_col0, #T_055f8_row1_col1, #T_055f8_row1_col2, #T_055f8_row1_col3, #T_055f8_row1_col4, #T_055f8_row1_col5, #T_055f8_row1_col6, #T_055f8_row1_col7, #T_055f8_row1_col8, #T_055f8_row2_col0, #T_055f8_row2_col1, #T_055f8_row2_col2, #T_055f8_row2_col3, #T_055f8_row2_col4, #T_055f8_row2_col5, #T_055f8_row2_col6, #T_055f8_row2_col7, #T_055f8_row2_col8, #T_055f8_row3_col0, #T_055f8_row3_col1, #T_055f8_row3_col2, #T_055f8_row3_col3, #T_055f8_row3_col4, #T_055f8_row3_col5, #T_055f8_row3_col6, #T_055f8_row3_col7, #T_055f8_row3_col8, #T_055f8_row4_col0, #T_055f8_row4_col1, #T_055f8_row4_col2, #T_055f8_row4_col3, #T_055f8_row4_col4, #T_055f8_row4_col5, #T_055f8_row4_col6, #T_055f8_row4_col7, #T_055f8_row4_col8, #T_055f8_row5_col0, #T_055f8_row5_col1, #T_055f8_row5_col2, #T_055f8_row5_col3, #T_055f8_row5_col4, #T_055f8_row5_col5, #T_055f8_row5_col6, #T_055f8_row5_col7, #T_055f8_row5_col8, #T_055f8_row6_col0, #T_055f8_row6_col1, #T_055f8_row6_col2, #T_055f8_row6_col3, #T_055f8_row6_col4, #T_055f8_row6_col5, #T_055f8_row6_col6, #T_055f8_row6_col7, #T_055f8_row6_col8, #T_055f8_row7_col0, #T_055f8_row7_col1, #T_055f8_row7_col2, #T_055f8_row7_col3, #T_055f8_row7_col4, #T_055f8_row7_col5, #T_055f8_row7_col6, #T_055f8_row7_col7, #T_055f8_row7_col8, #T_055f8_row8_col0, #T_055f8_row8_col1, #T_055f8_row8_col2, #T_055f8_row8_col3, #T_055f8_row8_col4, #T_055f8_row8_col5, #T_055f8_row8_col6, #T_055f8_row8_col7, #T_055f8_row8_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_055f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_055f8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_055f8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_055f8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_055f8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_055f8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_055f8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_055f8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_055f8_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_055f8_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_055f8_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_055f8_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_055f8_row0_col1" class="data row0 col1" >0.8696</td>
#       <td id="T_055f8_row0_col2" class="data row0 col2" >0.9528</td>
#       <td id="T_055f8_row0_col3" class="data row0 col3" >0.8696</td>
#       <td id="T_055f8_row0_col4" class="data row0 col4" >0.8703</td>
#       <td id="T_055f8_row0_col5" class="data row0 col5" >0.8690</td>
#       <td id="T_055f8_row0_col6" class="data row0 col6" >0.7834</td>
#       <td id="T_055f8_row0_col7" class="data row0 col7" >0.7843</td>
#       <td id="T_055f8_row0_col8" class="data row0 col8" >89.0650</td>
#     </tr>
#     <tr>
#       <th id="T_055f8_level0_row1" class="row_heading level0 row1" >svm</th>
#       <td id="T_055f8_row1_col0" class="data row1 col0" >SVM - Linear Kernel</td>
#       <td id="T_055f8_row1_col1" class="data row1 col1" >0.8227</td>
#       <td id="T_055f8_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_055f8_row1_col3" class="data row1 col3" >0.8227</td>
#       <td id="T_055f8_row1_col4" class="data row1 col4" >0.8290</td>
#       <td id="T_055f8_row1_col5" class="data row1 col5" >0.8231</td>
#       <td id="T_055f8_row1_col6" class="data row1 col6" >0.7074</td>
#       <td id="T_055f8_row1_col7" class="data row1 col7" >0.7085</td>
#       <td id="T_055f8_row1_col8" class="data row1 col8" >17.2970</td>
#     </tr>
#     <tr>
#       <th id="T_055f8_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_055f8_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_055f8_row2_col1" class="data row2 col1" >0.7740</td>
#       <td id="T_055f8_row2_col2" class="data row2 col2" >0.8565</td>
#       <td id="T_055f8_row2_col3" class="data row2 col3" >0.7740</td>
#       <td id="T_055f8_row2_col4" class="data row2 col4" >0.7757</td>
#       <td id="T_055f8_row2_col5" class="data row2 col5" >0.7732</td>
#       <td id="T_055f8_row2_col6" class="data row2 col6" >0.6899</td>
#       <td id="T_055f8_row2_col7" class="data row2 col7" >0.6908</td>
#       <td id="T_055f8_row2_col8" class="data row2 col8" >27.0720</td>
#     </tr>
#     <tr>
#       <th id="T_055f8_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_055f8_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_055f8_row3_col1" class="data row3 col1" >0.7568</td>
#       <td id="T_055f8_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_055f8_row3_col3" class="data row3 col3" >0.7568</td>
#       <td id="T_055f8_row3_col4" class="data row3 col4" >0.7593</td>
#       <td id="T_055f8_row3_col5" class="data row3 col5" >0.7571</td>
#       <td id="T_055f8_row3_col6" class="data row3 col6" >0.6638</td>
#       <td id="T_055f8_row3_col7" class="data row3 col7" >0.6644</td>
#       <td id="T_055f8_row3_col8" class="data row3 col8" >22.5010</td>
#     </tr>
#     <tr>
#       <th id="T_055f8_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_055f8_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_055f8_row4_col1" class="data row4 col1" >0.6837</td>
#       <td id="T_055f8_row4_col2" class="data row4 col2" >0.9433</td>
#       <td id="T_055f8_row4_col3" class="data row4 col3" >0.6837</td>
#       <td id="T_055f8_row4_col4" class="data row4 col4" >0.8131</td>
#       <td id="T_055f8_row4_col5" class="data row4 col5" >0.6942</td>
#       <td id="T_055f8_row4_col6" class="data row4 col6" >0.5408</td>
#       <td id="T_055f8_row4_col7" class="data row4 col7" >0.5769</td>
#       <td id="T_055f8_row4_col8" class="data row4 col8" >28.1130</td>
#     </tr>
#     <tr>
#       <th id="T_055f8_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_055f8_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_055f8_row5_col1" class="data row5 col1" >0.6177</td>
#       <td id="T_055f8_row5_col2" class="data row5 col2" >0.6963</td>
#       <td id="T_055f8_row5_col3" class="data row5 col3" >0.6177</td>
#       <td id="T_055f8_row5_col4" class="data row5 col4" >0.6293</td>
#       <td id="T_055f8_row5_col5" class="data row5 col5" >0.6213</td>
#       <td id="T_055f8_row5_col6" class="data row5 col6" >0.3837</td>
#       <td id="T_055f8_row5_col7" class="data row5 col7" >0.3849</td>
#       <td id="T_055f8_row5_col8" class="data row5 col8" >29.3480</td>
#     </tr>
#     <tr>
#       <th id="T_055f8_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_055f8_row6_col0" class="data row6 col0" >Ada Boost Classifier</td>
#       <td id="T_055f8_row6_col1" class="data row6 col1" >0.5035</td>
#       <td id="T_055f8_row6_col2" class="data row6 col2" >0.6101</td>
#       <td id="T_055f8_row6_col3" class="data row6 col3" >0.5035</td>
#       <td id="T_055f8_row6_col4" class="data row6 col4" >0.5288</td>
#       <td id="T_055f8_row6_col5" class="data row6 col5" >0.5092</td>
#       <td id="T_055f8_row6_col6" class="data row6 col6" >0.2103</td>
#       <td id="T_055f8_row6_col7" class="data row6 col7" >0.2131</td>
#       <td id="T_055f8_row6_col8" class="data row6 col8" >119.5600</td>
#     </tr>
#     <tr>
#       <th id="T_055f8_level0_row7" class="row_heading level0 row7" >nb</th>
#       <td id="T_055f8_row7_col0" class="data row7 col0" >Naive Bayes</td>
#       <td id="T_055f8_row7_col1" class="data row7 col1" >0.4697</td>
#       <td id="T_055f8_row7_col2" class="data row7 col2" >0.6654</td>
#       <td id="T_055f8_row7_col3" clas
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# Falha ao interromper o Kernel.
#
# Unable to start Kernel '.conda (Python 3.10.11)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
